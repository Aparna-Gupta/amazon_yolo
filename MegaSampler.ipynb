# %%
# find similar products recurrsively
import json
import pandas as pd

json_data = open('./out/HomeKitchenFinal2.json').read()
HomeKitchenFinalDict = json.loads(json_data)

json_data = open('./out/cleanAsinSimilarProductsPriceBrandImageDict.json').read()
cleanAsinSimilarProductsPriceBrandImageDict = json.loads(json_data)

# Further analysis on HomeKitchenCleanData for now
# lets get the lengths of all description and reviews in this data
goodAsins = []
for asin in cleanAsinSimilarProductsPriceBrandImageDict:
    noOfSimilarProducts = len(cleanAsinSimilarProductsPriceBrandImageDict[asin]["similar"])
    if noOfSimilarProducts == 85:
        goodAsins.append(asin)
        
sample = []

asin = goodAsins[0]
sample.append(asin)

i = 0
for asin2 in cleanAsinSimilarProductsPriceBrandImageDict[asin]["similar"]:
    sample.append(asin2)

# %%
def getNewSamples(exploreSet):
    newSet = set([])
    for asin in exploreSet:
        for asin2 in cleanAsinSimilarProductsPriceBrandImageDict[asin]["similar"]:
            newSet.add(asin2)
    return newSet

# sampleSet = set(sample)
# condition = True
# while condition:
#     # loop body here
#     newSet = sampleSet
#     newSet = newSet.union(getNewSamples(sampleSet))
#     if len(newSet - sampleSet) <= 0:
#         sampleSet = newSet
#         condition = False
#     else:
#         sampleSet = newSet
# len(sampleSet)

# %%
sampleSet = set(sample)
levelsToSearch = 1
while levelsToSearch > 0:
    levelsToSearch = levelsToSearch - 1
    sampleSet = sampleSet.union(getNewSamples(sampleSet))
    
print(len(sampleSet))
# Out:
# 385

# %%
for asin in sampleSet:
    print(asin,HomeKitchenFinalDict[asin]["title"])
# Out:
# B000HJ76HO Grayline 40501, Large Cabinet Rack, White
# B001F51A3U Honey Can Do BRD-01296 Ironing Board
# B0002O9HLC Seville Classics 3 Shelf, 17-1/2-Inch by 7-1/2-Inch by 18-1/2-Inch Cabinet Organizer
# B00AWS7IN2 New Ikea Variera Pot Lid Organizer Stainless Steel Multi-use Adjustable Lenght (1)
# B0009U82S8 Spectrum 65600 Mountable WrapRack, White
# B00310PDNA OXO SteeL Suction Sink Basket
# B002WGHKWQ simplehuman Sink Caddy, Stainless Steel
# B005O0B0QE Spectrum 30670 Over The Cabinet Door Ring Dryer Holder, Chrome
# B001QD5T4W Organize It All Basic Overdoor 6-Basket Unit (17716W)
# B000ILHN4C Whitmor 6056-53 Supreme Laundry Cart, Chrome
# B003VWL6TI simplehuman Slim Sink Caddy, Stainless Steel
# B0000TQIFM Household Essentials Hanging Clear Vinyl 12-Pocket Stocking Organizer
# B002ZNJHZE Seville Classics Expandable Kitchen Counter and Cabinet Shelf
# B006239NXY Honey-Can-Do SRT-01196 Rolling Ironing and Sorter Combo Laundry Center
# ...

# %%
HomeKitchenFinalDict['B000HJ76HO']
# Out:
# {'Best review': 'Measure, measure, measure!  I didn\'t and had to send this little guy back, but a very simple, practical piece.  I just measured the whole door, not where the screws would go.  Big mistake.  Measure what you want the basket to cover, then take a 1/4" off of each side, as thats where the screws will sit, and you don\'t want to screw through your cabinet MDF.',
#  'description': 'The Large Cabinet Rack can be used for a number of applications in the kitchen, laundry room, or closet. It is ideal for storing soaps, sponges, cleansers, and other bottled products. By utilizing space inside cabinet or closet doors, it saves valuable space in drawers and cupboards.',
#  'descriptionBow': ['large',
#   'cabinet',
#   'rack',
#   'used',
[1506 , 2671],'B000KKMNAU' : [41124 , 271],'B00310P99S' : [49564 , 222],'B0087N6P74' : [6675 ,  1132],'B003PBJSZ4' : [38862 , 287],'B00307UU14' : [59302 , 182],'B000USP95I' : [736 ,  4003],'B00002NBSO' : [33495 , 331],'B00622FGH2' : [35739 , 311],'B0002E35VU' : [55715 ,  195],'B0035JL2ZA' : [19606 ,  530],'B0037LWSEK' : [2461 ,  2031],'B002QCHSZA' : [18256 ,  561],'B001BVQJ7A' : [15192 , 646],'B004TB9NFE' : [26205 , 415],'B00K75U6IE' : [5508 , 1274],'B004K6L8HO' : [5337 , 1298],'B000I1UU56' : [5913 , 1220],'B00013KAG0' : [1999 , 2281],'B003VMW0HU' : [8481 , 971],'B009L4CX7E' : [11010 , 815],'B001MY6A3E' : [21318 , 495],'B001B11ZV0' : [6628 , 1137],'B006F62UAQ' : [32262 , 343],'B0002EXYMA' : [11007 , 815],'B002XISHF2' : [4186 , 1499],'B003VQQGI0' : [20902 , 503],'B00021RESS' : [13801 , 694],'B00004XSF7' : [204 , 8713],'B0007YDV2I' : [19303 , 537],'B003YVSOOQ' : [29583 , 372],'B006MON3XE' : [3065 , 1794],'B00004XSFA' : [6685 , 1131],'B000MM7DEW' : [20981 , 502],'B003CLMWWS' : [32721 , 339],'B009A3HTXY' : [633 , 4368],'B0085J6RZA' : [6284 , 1175],'B00013KABK' : [1960 , 2306],'B001JYMAA4' : [42636 , 261],'B000LNQF82' : [22130 , 480],'B001D762J2' : [142224 , 55],'B002OJHRCO' : [26923 , 405],'B0037LUO32' : [13301 , 713],'B009SBENG4' : [173346 ,40]}

# %%
sampleDict = {}
for asin in list(sampleSet):
    sampleDict[asin] = {}
    
    sampleDict[asin]['reviewPoliteness'] = HomeKitchenFinalDict[asin]["reviewPoliteness"]
    sampleDict[asin]['descriptionPoliteness'] = HomeKitchenFinalDict[asin]["descriptionPoliteness"]
    
    sampleDict[asin]['readabilityIndexDescription'] = HomeKitchenFinalDict[asin]["readability_index_description"]
    sampleDict[asin]['readabilityIndexReview'] = HomeKitchenFinalDict[asin]["readability_index_review"]
    
    sampleDict[asin]['reviewSentimentNeg'] = HomeKitchenFinalDict[asin]["reviewSentiment"]['neg']
    sampleDict[asin]['reviewSentimentNeu'] = HomeKitchenFinalDict[asin]["reviewSentiment"]['neu']
    sampleDict[asin]['reviewSentimentPos'] = HomeKitchenFinalDict[asin]["reviewSentiment"]['pos']
    sampleDict[asin]['reviewSentimentCom'] = HomeKitchenFinalDict[asin]["reviewSentiment"]['compound']
    
    sampleDict[asin]['descriptionSentimentNeg'] = HomeKitchenFinalDict[asin]["descriptionSentiment"]['neg']
    sampleDict[asin]['descriptionSentimentNeu'] = HomeKitchenFinalDict[asin]["descriptionSentiment"]['neu']
    sampleDict[asin]['descriptionSentimentPos'] = HomeKitchenFinalDict[asin]["descriptionSentiment"]['pos']
    sampleDict[asin]['descriptionSentimentCom'] = HomeKitchenFinalDict[asin]["descriptionSentiment"]['compound']
    
    for empath_key in HomeKitchenFinalDict[asin]["empath_description"]:
        sampleDict[asin]['empath_description_'+str(empath_key)] = HomeKitchenFinalDict[asin]["empath_description"][empath_key]
        
    for empath_key in HomeKitchenFinalDict[asin]["empath_review"]:
        sampleDict[asin]['empath_review_'+str(empath_key)] = HomeKitchenFinalDict[asin]["empath_review"][empath_key]

#      add estimated sales

    if asin in salesDict:
        sampleDict[asin]["sales"] = salesDict[asin]['sales']
    elif len(s[asin]) > 1:
        sampleDict[asin]["sales"] = s[asin][1]
    else:
        print(asin)
    #sampleDict[asin]['SR'] = HomeKitchenFinalDict[asin]['salesRank']['Home &amp; Kitchen']
    
sampleDf = pd.DataFrame.from_dict(sampleDict, orient='index')
# sampleDf.sort_values(by=['sales'])

# %%
with open('./out/385sampleDict.json', 'w') as outfile:
    json.dump(sampleDict, outfile)

# %%
x = sampleDf.loc[:, sampleDf.columns != 'sales']
y = sampleDf.loc[:, sampleDf.columns == 'sales']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


plt.figure(figsize = (25,25))
corr = x.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True, annot=True, linewidths=.5)

plt.show()

# %%
json_data=open('./out/sales.json').read()
salesDict = json.loads(json_data)

salesAvailable = []
for asin in sampleDict:
    if asin in salesDict:
        salesAvailable.append(asin)
len(salesAvailable)
# Out:
# 180

# %%
print("{")
for asin in list(set([*sampleDict.keys()]) - set(salesAvailable)):
    print("'",asin,"':",HomeKitchenFinalDict[asin]['salesRank']['Home &amp; Kitchen'],", ")
print("}")
# Out:
# {
# ' B000MM8T2W ': 12009 ,
# ' B00AWS7IN2 ': 1675 ,
# ' B001F51ALW ': 3919 ,
# ' B005D6PYPM ': 36603 ,
# ' B002BDTET2 ': 11341 ,
# ' B00013KAHO ': 15265 ,
# ' B00BGJMD36 ': 7617 ,
# ' B001QD5T4W ': 17687 ,
# ' B006239NXY ': 11051 ,
# ' B002Q7ABU4 ': 38132 ,
# ' B003VWL6TI ': 2744 ,
# ' B0000TQIFM ': 19566 ,
# ' B002GP7TT2 ': 8347 ,
# ' B002ZNJHZE ': 1404 ,
# ' B000079XWA ': 3259 ,
# ' B0024AKCTS ': 2207 ,
# ' B00BHLDCUG ': 5031 ,
# ' B004M3UWX6 ': 2143 ,
# ' B007LJPBLG ': 7555 ,
# ' B000QA2IJ0 ': 4315 ,
# ' B00EJU3SWY ': 1204 ,
# ' B000KM4Z5O ': 4995 ,
# ' B00ANRA546 ': 39874 ,
# ' B002OEUINE ': 8708 ,
# ' B0000TQGTA ': 32544 ,
# ' B003I5J186 ': 27891 ,
# ' B00772HUR0 ': 12783 ,
# ' B000KKMN00 ': 11874 ,
# ' B000GPVDLE ': 891 ,
# ' B002OEJ77W ': 1796 ,
# ' B0000E1VXW ': 45692 ,
# ' B001E8GL4G ': 21106 ,
# ' B00COC9P4E ': 2077 ,
# ' B001E22F2O ': 91229 ,
# ' B000NBV9CO ': 1037 ,
# ' B000HJ99RO ': 2051 ,
# ' B002BA5F0W ': 7644 ,
# ' B00068M52C ': 2517 ,
# ' B000IF6SMQ ': 4489 ,
# ...

# %%
# now train and test using sampleDf
import statsmodels.formula.api as sm
formulaStr = "sales ~ "
for col in sampleDf:
    if col != 'sales':
        formulaStr = formulaStr+col+" + "

result = sm.ols(formula=formulaStr[:-3], data=sampleDf).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     5.108
# Date:                Tue, 20 Mar 2018   Prob (F-statistic):             0.0595
# Time:                        00:58:15   Log-Likelihood:                -2250.5
# No. Observations:                 385   AIC:                             5263.
# Df Residuals:                       4   BIC:                             6769.
# Df Model:                         380
# Covariance Type:            nonrobust
# ...
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# ...
