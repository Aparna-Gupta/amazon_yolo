# %%
# change kernel to 2.7 and run these cells to add politeness
# scores to the data
import sys
import os
import cPickle
import nltk.data
import json, requests
from politeness.features.vectorizer import PolitenessFeatureVectorizer

"""
This file provides an interface to 
a pre-trained politeness SVM. 
"""

#####
# Ensure the proper python dependencies exist

try:
    import numpy as np
except:
    sys.stderr.write("Package not found: Politeness model requires python package numpy\n")
    sys.exit(2)

try:
    import scipy
    from scipy.sparse import csr_matrix
except:
    sys.stderr.write("Package not found: Politeness model requires python package scipy\n")
    sys.exit(2)

try:
    import sklearn
except:
    sys.stderr.write("Package not found: Politeness model requires python package scikit-learn\n")
    sys.exit(2)

try:
    import nltk
except:
    sys.stderr.write("Package not found: Politeness model requires python package nltk\n")
    sys.exit(2)

####
# Check versions for sklearn, scipy, numpy, nltk
# Don't error out, just notify

packages2versions = [("scikit-learn", sklearn, "0.15.1"), ("numpy", np, "1.9.0"), ("nltk", nltk, "3.0.0"), ("scipy", scipy, "0.12.0")]

for name, package, expected_v in packages2versions:
    if package.__version__ < expected_v:
        sys.stderr.write("Warning: package '%s', expected version >= %s, detected %s. Code functionality not guaranteed.\n" % (name, expected_v, package.__version__))

####

####
# Serialized model filename

MODEL_FILENAME = 'politeness/politeness-svm.p'
####
# Load model, initialize vectorizer

clf = cPickle.load(open(MODEL_FILENAME))
vectorizer = PolitenessFeatureVectorizer()
sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')

def score(request):
    """
    :param request - The request document to score
    :type request - dict with 'sentences' and 'parses' field
        sample (taken from test_documents.py)--
        {
            'sentences': [
                "Have you found the answer for your question?", 
                "If yes would you please share it?"
            ],
            'parses': [
                ["csubj(found-3, Have-1)", "dobj(Have-1, you-2)", "root(ROOT-0, found-3)", "det(answer-5, the-4)", "dobj(found-3, answer-5)", "poss(question-8, your-7)", "prep_for(found-3, question-8)"], 
                ["prep_if(would-3, yes-2)", "root(ROOT-0, would-3)", "nsubj(would-3, you-4)", "ccomp(would-3, please-5)", "nsubj(it-7, share-6)", "xcomp(please-5, it-7)"]
            ]
        } 

    returns class probabilities as a dict
        {
            'polite': float, 
            'impolite': float
        }
    """
    # vectorizer returns {feature-name: value} dict
    features = vectorizer.features(request)
    fv = [features[f] for f in sorted(features.iterkeys())]
    # Single-row sparse matrix
    X = csr_matrix(np.asarray([fv]))
    probs = clf.predict_proba(X)
    # Massage return format
    probs = {"polite": probs[0][1], "impolite": probs[0][0]}
    return probs

class StanfordCoreNLP:
    """
    Modified from https://github.com/smilli/py-corenlp
    """
 
    def __init__(self, server_url):
        # TODO: Error handling? More checking on the url?
        if server_url[-1] == '/':
            server_url = server_url[:-1]
        self.server_url = server_url
 
    def annotate(self, text, properties=None):
        assert isinstance(text, str)
        if properties is None:
            properties = {}
        else:
            assert isinstance(properties, dict)
 
        # Checks that the Stanford CoreNLP server is started.
        try:
            requests.get(self.server_url)
        except requests.exceptions.ConnectionError:
            raise Exception('Check whether you have started the CoreNLP server e.g.\n'
                            '$ cd <path_to_core_nlp_folder>/stanford-corenlp-full-2016-10-31/ \n'
                            '$ java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port <port> -timeout <timeout_in_ms>')
 
        data = text.encode()
        r = requests.post(
            self.server_url, params={
                'properties': str(properties)
            }, data=data, headers={'Connection': 'close'})
        output = r.text
        if ('outputFormat' in properties
            and properties['outputFormat'] == 'json'):
            try:
                output = json.loads(output, encoding='utf-8', strict=True)
            except:
                pass
        return output

def dep_parse_sentence(sentence):
    # The StanfordCoreNLP server is running on http://127.0.0.1:9000
    nlp = StanfordCoreNLP('http://127.0.0.1:9000')
    # Json response of all the annotations
    output = nlp.annotate(sentence, properties={
        "annotators": "parse,sentiment",
        "outputFormat": "json"
        # Only split the sentence at End Of Line. We assume that this method only takes in one single sentence.
        #"ssplit.eolonly": "true",
        # Setting enforceRequirements to skip some annotators and make the process faster
        #"enforceRequirements": "false"
    }
                         )
    # Only care about the result of the first sentence because we assume we only annotate a single sentence in this method.
    return output

def getpoliteImpoliteScores(text):
    dataDict = {}
    dataDict["text"] = text
    sentences = sent_detector.tokenize(dataDict["text"].strip())
    dataDict["sentences"] = sentences
    parses = []
    for sentence in sentences:
        out = dep_parse_sentence(sentence)
        depsList = []
        deps = out['sentences'][0]['basicDependencies']
        for dep in deps:
            d = dep
            newDepFmt = d['dep'].lower() + "(" + d['governorGloss']+"-"+str(d['governor'])+", "+d['dependentGloss']+"-"+str(d['dependent'])+")"
            depsList.append(newDepFmt)
        parses.append(depsList)
    dataDict["parses"] = parses
    return score(dataDict)

def addPolitenessScoresToProducts(furl):
    cleanerProducts = json.load(open(furl))
    productsProsessed = 0
    for asin in cleanerProducts:
        productsProsessed += 1
        try:
            descriptionPoliteImpoliteScores = getpoliteImpoliteScores(str(cleanerProducts[asin]['description']))
            cleanerProducts[asin]['descriptionPoliteness'] = descriptionPoliteImpoliteScores['polite']
            reviewPoliteImpoliteScores = getpoliteImpoliteScores(str(cleanerProducts[asin]['Best review']))
            cleanerProducts[asin]['reviewPoliteness'] = reviewPoliteImpoliteScores['polite']
        except Exception:
            print('description or review too big for computing politeness for the asin: ',asin)
            pass
        if productsProsessed % (len(cleanerProducts)//10) == 0:
                print("products processed: ",productsProsessed)
    with open(furl, 'w') as outfile:
        json.dump(cleanerProducts, outfile)
    print("done!")
#    return cleanerProducts

# %%
# addPolitenessScoresToProducts("./out/reviews_Beauty_5_Beauty_clean.json")
# addPolitenessScoresToProducts("./out/reviews_Health_and_Personal_Care_5_Health & Personal Care_clean.json")
# addPolitenessScoresToProducts("./out/reviews_Grocery_and_Gourmet_Food_5_Grocery & Gourmet Food_clean.json")
addPolitenessScoresToProducts("./out/reviews_Tools_and_Home_Improvement_5_Sports &amp; Outdoors_clean.json")
# Out:
# ('products processed: ', 16)
# ('products processed: ', 32)
# ('products processed: ', 48)
# ('products processed: ', 64)
# ('products processed: ', 80)
# ('products processed: ', 96)
# ('products processed: ', 112)
# ('products processed: ', 128)
# ('products processed: ', 144)
# ('products processed: ', 160)
# {u'B00008BFS8': {u'Best review': u'I have become a huge fan of this light.  I used to only use the SureFire and Streamlight "Lithium Battery" type lights, but after a hundred dollars worth of replacement batteries I thought I should find something that doesnt take $15-$20 worth of batteries at a shot. I then found a major disapointment in the LED/Regular bulb selectable setup of another Streamlight I purchased.  My next option was this one, I am completely satasfied and now have two for around the house and one for my wifes car and another for my car.  These are small, sturdy, easy to manipulate, have a long battery life and give out a fantastic amount of light.As the actual light goes, it is very crisp and bluish white colored.  It lights up a large area nicely.  It does not travel a long distace but easily provides enough light to light up a room or trail, or to work on a car at night.Another great thing about this light, funny as it sounds, is that the handle is not round, it is oblong shaped.  Sounds odd until you have to hold it in your mouth while using both your hands to change a tire on your car, then you understand how handly that handle really is.This is a great light, bright, compact, inexpensive, long battery life.  Almost everything you could ask for in a light for around the house or to keep in the car.',
#   u'Rating': 5.0,
#   u'brand': u'Streamlight',
#   u'description': u'The Streamlight Propolymer Xenon Flashlight was truly built to last! This handheld flashlight features a high density super tough nylon construction with a rubber face cap. Its waterproof and shock resistant making it the perfect companion on any of your outdoor adventures! The Propolymer flashlight features 7 bright LED lights (available in blue or white) and a tail switch for momentary blink or constant on settings. A wrist lanyard a 4 AA batteries are included.',
#   u'descriptionARI': 64.71,
#   u'descriptionEmpath': {u'achievement': 0.0,
#    u'affection': 0.0,
#    u'aggression': 0.0,
#    u'air_travel': 0.0,
#    u'alcohol': 0.0,
#    u'ancient': 0.0,
#    u'anger': 0.0,
#    u'animal': 0.0,
#    u'anonymity': 0.0,
#    u'anticipation': 0.0,
#    u'appearance': 0.013333333333333334,
#    u'art': 0.0,
#    u'attractive': 0.02666666666666667,
#    u'banking': 0.0,
#    u'beach': 0.0,
#    u'beauty': 0.02666666666666667,
#    u'blue_collar_job': 0.0,
#    u'body': 0.02666666666666667,
#    u'breaking': 0.0,
#    u'business': 0.0,
#    u'car': 0.0,
#    u'celebration': 0.0,
#    u'cheerfulness': 0.0,
#    u'childish': 0.0,
#    u'children': 0.0,
#    u'cleaning': 0.0,
#    u'clothing': 0.013333333333333334,
#    u'cold': 0.0,
#    u'college': 0.0,
#    u'communication': 0.0,
#    u'competing': 0.0,
#    u'computer': 0.013333333333333334,
#    u'confusion': 0.013333333333333334,
#    u'contentment': 0.013333333333333334,
#    u'cooking': 0.0,
#    u'crime': 0.0,
#    u'dance': 0.0,
#    u'death': 0.0,
#    u'deception': 0.0,
#    u'disappointment': 0.0,
#    u'disgust': 0.0,
#    u'dispute': 0.0,
#    u'divine': 0.0,
#    u'domestic_work': 0.0,
#    u'dominant_heirarchical': 0.0,
#    u'dominant_personality': 0.0,
#    u'driving': 0.0,
#    u'eating': 0.0,
#    u'economics': 0.0,
#    u'emotional': 0.0,
#    u'envy': 0.0,
#    u'exasperation': 0.0,
#    u'exercise': 0.0,
#    u'exotic': 0.0,
#    u'fabric': 0.013333333333333334,
#    u'family': 0.0,
#    u'farming': 0.0,
#    u'fashion': 0.0,
#    u'fear': 0.013333333333333334,
#    u'feminine': 0.0,
#    u'fight': 0.0,
#    u'fire': 0.0,
#    u'friends': 0.0,
#    u'fun': 0.0,
#    u'furniture': 0.0,
#    u'gain': 0.0,
#    u'giving': 0.0,
#    u'government': 0.0,
#    u'hate': 0.0,
#    u'healing': 0.0,
#    u'health': 0.0,
#    u'hearing': 0.0,
#    u'help': 0.0,
#    u'heroic': 0.0,
#    u'hiking': 0.0,
#    u'hipster': 0.0,
#    u'home': 0.0,
#    u'horror': 0.013333333333333334,
#    u'hygiene': 0.0,
#    u'independence': 0.0,
#    u'injury': 0.0,
#    u'internet': 0.0,
#    u'irritability': 0.0,
#    u'journalism': 0.0,
#    u'joy': 0.0,
#    u'kill': 0.0,
#    u'law': 0.0,
#    u'leader': 0.0,
#    u'legend': 0.0,
#    u'leisure': 0.013333333333333334,
#    u'liquid': 0.0,
#    u'listen': 0.0,
#    u'love': 0.0,
#    u'lust': 0.0,
#    u'magic': 0.0,
#    u'masculine': 0.0,
#    u'medical_emergency': 0.0,
#    u'medieval': 0.0,
#    u'meeting': 0.0,
#    u'messaging': 0.0,
#    u'military': 0.0,
#    u'money': 0.0,
#    u'monster': 0.0,
#    u'morning': 0.0,
#    u'movement': 0.0,
#    u'music': 0.0,
#    u'musical': 0.0,
#    u'negative_emotion': 0.0,
#    u'neglect': 0.0,
#    u'negotiate': 0.0,
#    u'nervousness': 0.0,
#    u'night': 0.0,
#    u'noise': 0.0,
#    u'occupation': 0.0,
#    u'ocean': 0.013333333333333334,
#    u'office': 0.0,
#    u'optimism': 0.0,
#    u'order': 0.0,
#    u'pain': 0.0,
#    u'party': 0.0,
#    u'payment': 0.0,
#    u'pet': 0.0,
#    u'philosophy': 0.0,
#    u'phone': 0.013333333333333334,
#    u'plant': 0.0,
#    u'play': 0.0,
#    u'politeness': 0.0,
#    u'politics': 0.0,
#    u'poor': 0.0,
#    u'positive_emotion': 0.0,
#    u'power': 0.0,
#    u'pride': 0.0,
#    u'prison': 0.0,
#    u'programming': 0.0,
#    u'rage': 0.0,
#    u'reading': 0.0,
#    u'real_estate': 0.0,
#    u'religion': 0.0,
#    u'restaurant': 0.0,
#    u'ridicule': 0.0,
#    u'royalty': 0.0,
#    u'rural': 0.0,
#    u'sadness': 0.0,
#    u'sailing': 0.0,
#    u'school': 0.0,
#    u'science': 0.0,
#    u'sexual': 0.0,
#    u'shame': 0.013333333333333334,
#    u'shape_and_size': 0.0,
#    u'ship': 0.0,
#    u'shopping': 0.0,
#    u'sleep': 0.0,
#    u'smell': 0.0,
#    u'social_media': 0.0,
#    u'sound': 0.0,
#    u'speaking': 0.0,
#    u'sports': 0.013333333333333334,
#    u'stealing': 0.0,
#    u'strength': 0.013333333333333334,
#    u'suffering': 0.0,
#    u'superhero': 0.0,
#    u'surprise': 0.013333333333333334,
#    u'swearing_terms': 0.0,
#    u'swimming': 0.013333333333333334,
#    u'sympathy': 0.0,
#    u'technology': 0.013333333333333334,
#    u'terrorism': 0.0,
#    u'timidity': 0.0,
#    u'tool': 0.04,
#    u'torment': 0.0,
#    u'tourism': 0.0,
#    u'toy': 0.0,
#    u'traveling': 0.0,
#    u'trust': 0.0,
#    u'ugliness': 0.0,
#    u'urban': 0.0,
#    u'vacation': 0.0,
#    u'valuable': 0.0,
#    u'vehicle': 0.0,
#    u'violence': 0.013333333333333334,
#    u'war': 0.0,
#    u'warmth': 0.0,
#    u'water': 0.0,
#    u'weakness': 0.0,
#    u'wealthy': 0.0,
#    u'weapon': 0.0,
#    u'weather': 0.0,
#    u'wedding': 0.0,
#    u'white_collar_job': 0.0,
#    u'work': 0.013333333333333334,
#    u'worship': 0.0,
#    u'writing': 0.0,
#    u'youth': 0.0,
#    u'zest': 0.0},
#   'descriptionPoliteness': 0.71209298414498701,
#   u'descriptionSentiment': {u'compound': 0.9229,
#    u'neg': 0.05,
#    u'neu': 0.749,
#    u'pos': 0.201},
#   u'imUrl': u'http://ecx.images-amazon.com/images/I/41F03gG%2B34L._SY300_.jpg',
#   u'price': 25.45,
#   u'reviewARI': 76.56,
#   u'reviewEmpath': {u'achievement': 0.008333333333333333,
#    u'affection': 0.0,
#    u'aggression': 0.0,
#    u'air_travel': 0.004166666666666667,
#    u'alcohol': 0.0,
#    u'ancient': 0.0,
#    u'anger': 0.0,
#    u'animal': 0.0,
#    u'anonymity': 0.0,
#    u'anticipation': 0.0,
#    u'appearance': 0.0,
#    u'art': 0.0,
#    u'attractive': 0.004166666666666667,
#    u'banking': 0.0,
#    u'beach': 0.0,
#    u'beauty': 0.0,
#    u'blue_collar_job': 0.0,
#    u'body': 0.004166666666666667,
#    u'breaking': 0.0,
#    u'business': 0.004166666666666667,
#    u'car': 0.0125,
#    u'celebration': 0.0,
#    u'cheerfulness': 0.0,
#    u'childish': 0.004166666666666667,
#    u'children': 0.0,
#    u'cleaning': 0.0,
#    u'clothing': 0.004166666666666667,
#    u'cold': 0.004166666666666667,
#    u'college': 0.0,
#    u'communication': 0.0125,
#    u'competing': 0.0,
#    u'computer': 0.016666666666666666,
#    u'confusion': 0.0,
#    u'contentment': 0.0,
#    u'cooking': 0.0,
#    u'crime': 0.0,
#    u'dance': 0.0,
#    u'death': 0.004166666666666667,
#    u'deception': 0.0,
#    u'disappointment': 0.0,
#    u'disgust': 0.0,
#    u'dispute': 0.0,
#    u'divine': 0.0,
#    u'domestic_work': 0.008333333333333333,
#    u'dominant_heirarchical': 0.0,
#    u'dominant_personality': 0.004166666666666667,
#    u'driving': 0.0125,
#    u'eating': 0.0,
#    u'economics': 0.0,
#    u'emotional': 0.0,
#    u'envy': 0.0,
#    u'exasperation': 0.0,
#    u'exercise': 0.0,
#    u'exotic': 0.0,
#    u'fabric': 0.0,
#    u'family': 0.0,
#    u'farming': 0.0,
#    u'fashion': 0.0,
#    u'fear': 0.0,
#    u'feminine': 0.0,
#    u'fight': 0.0,
#    u'fire': 0.016666666666666666,
#    u'friends': 0.0,
#    u'fun': 0.0,
#    u'furniture': 0.004166666666666667,
#    u'gain': 0.004166666666666667,
#    u'giving': 0.004166666666666667,
#    u'government': 0.0,
#    u'hate': 0.0,
#    u'healing': 0.0,
#    u'health': 0.0,
#    u'hearing': 0.0,
#    u'help': 0.0,
#    u'heroic': 0.0,
#    u'hiking': 0.0,
#    u'hipster': 0.0,
#    u'home': 0.0125,
#    u'horror': 0.0,
#    u'hygiene': 0.0,
#    u'independence': 0.0,
#    u'injury': 0.0,
#    u'internet': 0.0,
#    u'irritability': 0.0,
#    u'journalism': 0.0,
#    u'joy': 0.0,
#    u'kill': 0.0,
#    u'law': 0.0,
#    u'leader': 0.0,
#    u'legend': 0.0,
#    u'leisure': 0.0,
#    u'liquid': 0.0,
#    u'listen': 0.0,
#    u'love': 0.0,
#    u'lust': 0.0,
#    u'magic': 0.0,
#    u'masculine': 0.0,
#    u'medical_emergency': 0.0,
#    u'medieval': 0.0,
#    u'meeting': 0.0,
#    u'messaging': 0.004166666666666667,
#    u'military': 0.0,
#    u'money': 0.016666666666666666,
#    u'monster': 0.0,
#    u'morning': 0.0,
#    u'movement': 0.004166666666666667,
#    u'music': 0.0,
#    u'musical': 0.0,
#    u'negative_emotion': 0.0,
#    u'neglect': 0.0,
#    u'negotiate': 0.0,
#    u'nervousness': 0.0,
#    u'night': 0.0,
#    u'noise': 0.0,
#    u'occupation': 0.0,
#    u'ocean': 0.0,
#    u'office': 0.008333333333333333,
#    u'optimism': 0.0,
#    u'order': 0.0,
#    u'pain': 0.0,
#    u'party': 0.008333333333333333,
#    u'payment': 0.008333333333333333,
#    u'pet': 0.0,
#    u'philosophy': 0.0,
#    u'phone': 0.0,
#    u'plant': 0.0,
#    u'play': 0.0,
#    u'politeness': 0.0,
#    u'politics': 0.0,
#    u'poor': 0.0,
#    u'positive_emotion': 0.0125,
#    u'power': 0.0,
#    u'pride': 0.0,
#    u'prison': 0.0,
#    u'programming': 0.0,
#    u'rage': 0.0,
#    u'reading': 0.0,
#    u'real_estate': 0.008333333333333333,
#    u'religion': 0.0,
#    u'restaurant': 0.0,
#    u'ridicule': 0.0,
#    u'royalty': 0.0,
#    u'rural': 0.0,
#    u'sadness': 0.0,
#    u'sailing': 0.0,
#    u'school': 0.0,
#    u'science': 0.0,
#    u'sexual': 0.0,
#    u'shame': 0.0,
#    u'shape_and_size': 0.0125,
#    u'ship': 0.0,
#    u'shopping': 0.0,
#    u'sleep': 0.0,
#    u'smell': 0.0,
#    u'social_media': 0.004166666666666667,
#    u'sound': 0.0,
#    u'speaking': 0.008333333333333333,
#    u'sports': 0.0,
#    u'stealing': 0.0,
#    u'strength': 0.0,
#    u'suffering': 0.0,
#    u'superhero': 0.0,
#    u'surprise': 0.0,
#    u'swearing_terms': 0.0,
#    u'swimming': 0.0,
#    u'sympathy': 0.0,
#    u'technology': 0.008333333333333333,
#    u'terrorism': 0.0,
#    u'timidity': 0.0,
#    u'tool': 0.0,
#    u'torment': 0.0,
#    u'tourism': 0.004166666666666667,
#    u'toy': 0.0,
#    u'traveling': 0.008333333333333333,
#    u'trust': 0.0,
#    u'ugliness': 0.0,
#    u'urban': 0.0,
#    u'vacation': 0.004166666666666667,
#    u'valuable': 0.004166666666666667,
#    u'vehicle': 0.0125,
#    u'violence': 0.0,
#    u'war': 0.0,
#    u'warmth': 0.0,
#    u'water': 0.0,
#    u'weakness': 0.0,
#    u'wealthy': 0.0,
#    u'weapon': 0.0,
#    u'weather': 0.0,
#    u'wedding': 0.0,
#    u'white_collar_job': 0.0,
#    u'work': 0.004166666666666667,
#    u'worship': 0.0,
#    u'writing': 0.0,
#    u'youth': 0.0,
#    u'zest': 0.0},
#   'reviewPoliteness': 0.91970183337081823,
#   u'reviewSentiment': {u'compound': 0.9913,
#    u'neg': 0.012,
#    u'neu': 0.814,
#    u'pos': 0.175},
#   u'salesRank': {u'Sports &amp; Outdoors': 1557529},
#   u'title': u'Streamlight ProPolymer 4 AA LED Flashlight'},
#  u'B0000950Q9': {u'Best review': u'I live in the Northeast and run all year long in a local park with no lighting on the running path. During the winter months it can be tricky to run by just moonlight. I needed a lightweight, stable, and effective headlamp. After doing much research I bought the Tikka Plus, and am very happy with it.Unlike other models, there are no wires dangling. It is easily adjustable to fit around my head and does not slip or bounce around at all while I run. This is also one of the lightest headlamps, and is barely noticeable on my head. The tilt feature and adjustable light easily illumine the running path. Usually the medium setting is sufficient(there are high, medium, and low settings, a strobe, and also a high intensity setting).The direction brochure is not the best, but with a little experimenting you will see that you do not have to cycle through all of the settings each time you use this.This product does everything it is supposed to and I highly recommend it.',
#   u'Rating': 5.0,
#   u'description': u"The Tikka headlamp features three super-bright white LEDs each offering a different brightness setting of high, medium, and low. A fourth bulb functions as a long-lasting strobe light perfect for roadside emergencies and as reliable bike light that evening commute. The Tikka Plus is water resistant and won't short out even if submerged. Burn times for the four light settings (High, Medium, and Low) are: 80 hours, 120 hours, and 150 hours on a single battery pack. And, the strobe light burns for up to 400 hours. Best of all, the Tikka Plus is small enough for the pocket, the glove box, or the toolbox for convenient, reliable lighting when you need it most. More great features: A tilting lamp let's you aim the beam at the trail in front of you, so you don't have to keep your neck cocked at an uncomfortable angle. A large anti-glare lip lets you aim the light where you want without blinding your buddy with peripheral glare. And, an easy access, push-button switch is recessed so that it doesn't accidentally turn on as you slam the suitcase shut. Your purchase includes three AAA batteries.",
#   u'descriptionARI': 77.47,
#   u'descriptionEmpath': {u'achievement': 0.005235602094240838,
#    u'affection': 0.0,
#    u'aggression': 0.0,
#    u'air_travel': 0.005235602094240838,
#    u'alcohol': 0.0,
#    u'ancient': 0.0,
#    u'anger': 0.0,
#    u'animal': 0.0,
#    u'anonymity': 0.0,
#    u'anticipation': 0.0,
#    u'appearance': 0.005235602094240838,
#    u'art': 0.0,
#    u'attractive': 0.005235602094240838,
#    u'banking': 0.0,
#    u'beach': 0.005235602094240838,
#    u'beauty': 0.005235602094240838,
#    u'blue_collar_job': 0.0,
#    u'body': 0.010471204188481676,
#    u'breaking': 0.005235602094240838,
#    u'business': 0.005235602094240838,
#    u'car': 0.0,
#    u'celebration': 0.0,
#    u'cheerfulness': 0.0,
#    u'childish': 0.0,
#    u'children': 0.0,
#    u'cleaning': 0.005235602094240838,
#    u'clothing': 0.010471204188481676,
#    u'cold': 0.0,
#    u'college': 0.0,
#    u'communication': 0.0,
#    u'competing': 0.0,
#    u'computer': 0.005235602094240838,
#    u'confusion': 0.0,
#    u'contentment': 0.0,
#    u'cooking': 0.0,
#    u'crime': 0.0,
#    u'dance': 0.0,
#    u'death': 0.0,
#    u'deception': 0.0,
#    u'disappointment': 0.0,
#    u'disgust': 0.0,
#    u'dispute': 0.0,
#    u'divine': 0.0,
#    u'domestic_work': 0.0,
#    u'dominant_heirarchical': 0.0,
#    u'dominant_personality': 0.0,
#    u'driving': 0.0,
#    u'eating': 0.0,
#    u'economics': 0.0,
#    u'emotional': 0.0,
#    u'envy': 0.0,
#    u'exasperation': 0.0,
#    u'exercise': 0.0,
#    u'exotic': 0.0,
#    u'fabric': 0.005235602094240838,
#    u'family': 0.0,
#    u'farming': 0.0,
#    u'fashion': 0.0,
#    u'fear': 0.0,
#    u'feminine': 0.0,
#    u'fight': 0.0,
#    u'fire': 0.02617801047120419,
#    u'friends': 0.005235602094240838,
#    u'fun': 0.0,
#    u'furniture': 0.0,
#    u'gain': 0.0,
#    u'giving': 0.010471204188481676,
#    u'government': 0.0,
#    u'hate': 0.0,
#    u'healing': 0.0,
#    u'health': 0.0,
#    u'hearing': 0.0,
#    u'help': 0.0,
#    u'heroic': 0.0,
#    u'hiking': 0.0,
#    u'hipster': 0.0,
#    u'home': 0.0,
#    u'horror': 0.0,
#    u'hygiene': 0.0,
#    u'independence': 0.0,
#    u'injury': 0.0,
#    u'internet': 0.0,
#    u'irritability': 0.0,
#    u'journalism': 0.0,
#    u'joy': 0.0,
#    u'kill': 0.0,
#    u'law': 0.0,
#    u'leader': 0.0,
#    u'legend': 0.0,
#    u'leisure': 0.005235602094240838,
#    u'liquid': 0.005235602094240838,
#    u'listen': 0.0,
#    u'love': 0.0,
#    u'lust': 0.0,
#    u'magic': 0.0,
#    u'masculine': 0.0,
#    u'medical_emergency': 0.0,
#    u'medieval': 0.0,
#    u'meeting': 0.0,
#    u'messaging': 0.0,
#    u'military': 0.0,
#    u'money': 0.005235602094240838,
#    u'monster': 0.0,
#    u'morning': 0.0,
#    u'movement': 0.010471204188481676,
#    u'music': 0.0,
#    u'musical': 0.0,
#    u'negative_emotion': 0.0,
#    u'neglect': 0.0,
#    u'negotiate': 0.0,
#    u'nervousness': 0.0,
#    u'night': 0.0,
#    u'noise': 0.0,
#    u'occupation': 0.0,
#    u'ocean': 0.005235602094240838,
#    u'office': 0.0,
#    u'optimism': 0.0,
#    u'order': 0.0,
#    u'pain': 0.0,
#    u'party': 0.005235602094240838,
#    u'payment': 0.010471204188481676,
#    u'pet': 0.005235602094240838,
#    u'philosophy': 0.0,
#    u'phone': 0.005235602094240838,
#    u'plant': 0.0,
#    u'play': 0.005235602094240838,
#    u'politeness': 0.0,
#    u'politics': 0.0,
#    u'poor': 0.0,
#    u'positive_emotion': 0.010471204188481676,
#    u'power': 0.0,
#    u'pride': 0.0,
#    u'prison': 0.0,
#    u'programming': 0.0,
#    u'rage': 0.0,
#    u'reading': 0.0,
#    u'real_estate': 0.005235602094240838,
#    u'religion': 0.005235602094240838,
#    u'restaurant': 0.0,
#    u'ridicule': 0.0,
#    u'royalty': 0.0,
#    u'rural': 0.0,
#    u'sadness': 0.0,
#    u'sailing': 0.005235602094240838,
#    u'school': 0.0,
#    u'science': 0.0,
#    u'sexual': 0.0,
#    u'shame': 0.0,
#    u'shape_and_size': 0.010471204188481676,
#    u'ship': 0.0,
#    u'shopping': 0.010471204188481676,
#    u'sleep': 0.0,
#    u'smell': 0.0,
#    u'social_media': 0.0,
#    u'sound': 0.0,
#    u'speaking': 0.0,
#    u'sports': 0.0,
#    u'stealing': 0.0,
#    u'strength': 0.0,
#    u'suffering': 0.0,
#    u'superhero': 0.0,
#    u'surprise': 0.0,
#    u'swearing_terms': 0.0,
#    u'swimming': 0.005235602094240838,
#    u'sympathy': 0.0,
#    u'technology': 0.005235602094240838,
#    u'terrorism': 0.0,
#    u'timidity': 0.005235602094240838,
#    u'tool': 0.0,
#    u'torment': 0.0,
#    u'tourism': 0.0,
#    u'toy': 0.005235602094240838,
#    u'traveling': 0.005235602094240838,
#    u'trust': 0.0,
#    u'ugliness': 0.0,
#    u'urban': 0.0,
#    u'vacation': 0.0,
#    u'valuable': 0.005235602094240838,
#    u'vehicle': 0.0,
#    u'violence': 0.0,
#    u'war': 0.0,
#    u'warmth': 0.0,
#    u'water': 0.005235602094240838,
#    u'weakness': 0.0,
#    u'wealthy': 0.0,
#    u'weapon': 0.0,
#    u'weather': 0.0,
#    u'wedding': 0.0,
#    u'white_collar_job': 0.0,
#    u'work': 0.0,
#    u'worship': 0.0,
#    u'writing': 0.0,
#    u'youth': 0.0,
#    u'zest': 0.0},
#   'descriptionPoliteness': 0.30569240541491838,
#   u'descriptionSentiment': {u'compound': 0.9338,
#    u'neg': 0.036,
#    u'neu': 0.859,
#    u'pos': 0.105},
#   u'imUrl': u'http://ecx.images-amazon.com/images/I/41GVZPBT27L._SY300_.jpg',
#   u'reviewARI': 72.36,
#   u'reviewEmpath': {u'achievement': 0.0,
#    u'affection': 0.0,
#    u'aggression': 0.005747126436781609,
#    u'air_travel': 0.0,
#    u'alcohol': 0.0,
#    u'ancient': 0.0,
#    u'anger': 0.005747126436781609,
#    u'animal': 0.0,
#    u'anonymity': 0.0,
#    u'anticipation': 0.0,
#    u'appearance': 0.0,
#    u'art': 0.0,
#    u'attractive': 0.0,
#    u'banking': 0.0,
#    u'beach': 0.0,
#    u'beauty': 0.0,
#    u'blue_collar_job': 0.0,
#    u'body': 0.005747126436781609,
#    u'breaking': 0.0,
#    u'business': 0.005747126436781609,
#    u'car': 0.0,
#    u'celebration': 0.005747126436781609,
#    u'cheerfulness': 0.005747126436781609,
#    u'childish': 0.011494252873563218,
#    u'children': 0.005747126436781609,
#    u'cleaning': 0.0,
#    u'clothing': 0.005747126436781609,
#    u'cold': 0.005747126436781609,
#    u'college': 0.005747126436781609,
#    u'communication': 0.0,
#    u'competing': 0.0,
#    u'computer': 0.0,
#    u'confusion': 0.0,
#    u'contentment': 0.0,
#    u'cooking': 0.0,
#    u'crime': 0.0,
#    u'dance': 0.005747126436781609,
#    u'death': 0.0,
#    u'deception': 0.0,
#    u'disappointment': 0.0,
#    u'disgust': 0.0,
#    u'dispute': 0.0,
#    u'divine': 0.0,
#    u'domestic_work': 0.0,
#    u'dominant_heirarchical': 0.0,
#    u'dominant_personality': 0.0,
#    u'driving': 0.005747126436781609,
#    u'eating': 0.0,
#    u'economics': 0.005747126436781609,
#    u'emotional': 0.0,
#    u'envy': 0.0,
#    u'exasperation': 0.0,
#    u'exercise': 0.011494252873563218,
#    u'exotic': 0.0,
#    u'fabric': 0.0,
#    u'family': 0.0,
#    u'farming': 0.0,
#    u'fashion': 0.005747126436781609,
#    u'fear': 0.0,
#    u'feminine': 0.0,
#    u'fight': 0.0,
#    u'fire': 0.005747126436781609,
#    u'friends': 0.0,
#    u'fun': 0.0,
#    u'furniture': 0.0,
#    u'gain': 0.0,
#    u'giving': 0.0,
#    u'government': 0.0,
#    u'hate': 0.0,
#    u'healing': 0.0,
#    u'health': 0.0,
#    u'hearing': 0.005747126436781609,
#    u'help': 0.0,
#    u'heroic': 0.0,
#    u'hiking': 0.0,
#    u'hipster': 0.0,
#    u'home': 0.005747126436781609,
#    u'horror': 0.0,
#    u'hygiene': 0.0,
#    u'independence': 0.0,
#    u'injury': 0.0,
#    u'internet': 0.005747126436781609,
#    u'irritability': 0.0,
#    u'journalism': 0.005747126436781609,
#    u'joy': 0.0,
#    u'kill': 0.0,
#    u'law': 0.0,
#    u'leader': 0.0,
#    u'legend': 0.0,
#    u'leisure': 0.0,
#    u'liquid': 0.0,
#    u'listen': 0.0,
#    u'love': 0.0,
#    u'lust': 0.005747126436781609,
#    u'magic': 0.0,
#    u'masculine': 0.0,
#    u'medical_emergency': 0.0,
#    u'medieval': 0.0,
#    u'meeting': 0.0,
#    u'messaging': 0.0,
#    u'military': 0.0,
#    u'money': 0.0,
#    u'monster': 0.0,
#    u'morning': 0.0,
#    u'movement': 0.017241379310344827,
#    u'music': 0.0,
#    u'musical': 0.0,
#    u'negative_emotion': 0.0,
#    u'neglect': 0.0,
#    u'negotiate': 0.0,
#    u'nervousness': 0.0,
#    u'night': 0.0,
#    u'noise': 0.0,
#    u'occupation': 0.0,
#    u'ocean': 0.0,
#    u'office': 0.0,
#    u'optimism': 0.005747126436781609,
#    u'order': 0.0,
#    u'pain': 0.0,
#    u'party': 0.005747126436781609,
#    u'payment': 0.0,
#    u'pet': 0.0,
#    u'philosophy': 0.0,
#    u'phone': 0.0,
#    u'plant': 0.0,
#    u'play': 0.0,
#    u'politeness': 0.0,
#    u'politics': 0.0,
#    u'poor': 0.0,
#    u'positive_emotion': 0.005747126436781609,
#    u'power': 0.0,
#    u'pride': 0.0,
#    u'prison': 0.0,
#    u'programming': 0.0,
#    u'rage': 0.005747126436781609,
#    u'reading': 0.005747126436781609,
#    u'real_estate': 0.005747126436781609,
#    u'religion': 0.0,
#    u'restaurant': 0.0,
#    u'ridicule': 0.0,
#    u'royalty': 0.0,
#    u'rural': 0.005747126436781609,
#    u'sadness': 0.0,
#    u'sailing': 0.0,
#    u'school': 0.005747126436781609,
#    u'science': 0.005747126436781609,
#    u'sexual': 0.0,
#    u'shame': 0.0,
#    u'shape_and_size': 0.005747126436781609,
#    u'ship': 0.0,
#    u'shopping': 0.005747126436781609,
#    u'sleep': 0.0,
#    u'smell': 0.0,
#    u'social_media': 0.0,
#    u'sound': 0.0,
#    u'speaking': 0.0,
#    u'sports': 0.011494252873563218,
#    u'stealing': 0.0,
#    u'strength': 0.0,
#    u'suffering': 0.0,
#    u'superhero': 0.0,
#    u'surprise': 0.0,
#    u'swearing_terms': 0.0,
#    u'swimming': 0.0,
#    u'sympathy': 0.0,
#    u'technology': 0.005747126436781609,
#    u'terrorism': 0.0,
#    u'timidity': 0.0,
#    u'tool': 0.0,
#    u'torment': 0.0,
#    u'tourism': 0.005747126436781609,
#    u'toy': 0.005747126436781609,
#    u'traveling': 0.005747126436781609,
#    u'trust': 0.0,
#    u'ugliness': 0.0,
#    u'urban': 0.005747126436781609,
#    u'vacation': 0.005747126436781609,
#    u'valuable': 0.0,
#    u'vehicle': 0.0,
#    u'violence': 0.0,
#    u'war': 0.0,
#    u'warmth': 0.0,
#    u'water': 0.0,
#    u'weakness': 0.0,
#    u'wealthy': 0.0,
#    u'weapon': 0.0,
#    u'weather': 0.0,
#    u'wedding': 0.005747126436781609,
#    u'white_collar_job': 0.0,
#    u'work': 0.0,
#    u'worship': 0.0,
#    u'writing': 0.005747126436781609,
#    u'youth': 0.0,
#    u'zest': 0.0},
#   'reviewPoliteness': 0.71365308764060398,
#   u'reviewSentiment': {u'compound': 0.7752,
#    u'neg': 0.047,
#    u'neu': 0.867,
#    u'pos': 0.086},
#   u'salesRank': {u'Sports &amp; Outdoors': 501514},
#   u'title': u'Petzl Tikka Plus 4-LED Headlamp #E47P'},
#  u'B0001LMBMS': {u'Best review': u"i love not having to worry about leaving my hearing protection behind.  When I hang it on my duty weapon during practice sometimes  it falls off.  putting it around the neck is uncomfortable so having this holder is handy.  Don't know why I never thought of getting one.",
#   u'Rating': 5.0,
#   u'brand': u'Safariland',
#   u'description': u'The Safariland 075-2 Hearing Protection Holder is constructed of  molded polymer and slips over a belt to hold most standard earmuff style hearing protection. Keeps your hearing protection at arms length when not in use.',
#   u'descriptionARI': 53.71,
#   u'descriptionEmpath': {u'achievement': 0.0,
#    u'affection': 0.0,
#    u'aggression': 0.0,
#    u'air_travel': 0.0,
#    u'alcohol': 0.0,
#    u'ancient': 0.0,
#    u'anger': 0.0,
#    u'animal': 0.0,
#    u'anonymity': 0.0,
#    u'anticipation': 0.0,
#    u'appearance': 0.02857142857142857,
#    u'art': 0.0,
#    u'attractive': 0.0,
#    u'banking': 0.0,
#    u'beach': 0.0,
#    u'beauty': 0.0,
#    u'blue_collar_job': 0.0,
#    u'body': 0.0,
#    u'breaking': 0.0,
#    u'business': 0.0,
#    u'car': 0.0,
#    u'celebration': 0.0,
#    u'cheerfulness': 0.0,
#    u'childish': 0.0,
#    u'children': 0.0,
#    u'cleaning': 0.0,
#    u'clothing': 0.0,
#    u'cold': 0.0,
#    u'college': 0.0,
#    u'communication': 0.0,
#    u'competing': 0.0,
#    u'computer': 0.0,
#    u'confusion': 0.0,
#    u'contentment': 0.0,
#    u'cooking': 0.0,
#    u'crime': 0.0,
#    u'dance': 0.0,
#    u'death': 0.0,
#    u'deception': 0.0,
#    u'disappointment': 0.0,
#    u'disgust': 0.0,
#    u'dispute': 0.0,
#    u'divine': 0.0,
#    u'domestic_work': 0.0,
#    u'dominant_heirarchical': 0.0,
#    u'dominant_personality': 0.0,
#    u'driving': 0.0,
#    u'eating': 0.0,
#    u'economics': 0.0,
#    u'emotional': 0.0,
#    u'envy': 0.0,
#    u'exasperation': 0.0,
#    u'exercise': 0.0,
#    u'exotic': 0.0,
#    u'fabric': 0.0,
#    u'family': 0.0,
#    u'farming': 0.0,
#    u'fashion': 0.0,
#    u'fear': 0.0,
#    u'feminine': 0.0,
#    u'fight': 0.0,
#    u'fire': 0.0,
#    u'friends': 0.0,
#    u'fun': 0.0,
#    u'furniture': 0.0,
#    u'gain': 0.0,
#    u'giving': 0.0,
#    u'government': 0.0,
#    u'hate': 0.0,
#    u'healing': 0.0,
#    u'health': 0.0,
#    u'hearing': 0.05714285714285714,
#    u'help': 0.02857142857142857,
#    u'heroic': 0.0,
#    u'hiking': 0.0,
#    u'hipster': 0.0,
#    u'home': 0.0,
#    u'horror': 0.0,
#    u'hygiene': 0.0,
#    u'independence': 0.0,
#    u'injury': 0.0,
#    u'internet': 0.0,
#    u'irritability': 0.0,
#    u'journalism': 0.0,
#    u'joy': 0.0,
#    u'kill': 0.0,
#    u'law': 0.0,
#    u'leader': 0.0,
#    u'legend': 0.0,
#    u'leisure': 0.0,
#    u'liquid': 0.0,
#    u'listen': 0.05714285714285714,
#    u'love': 0.0,
#    u'lust': 0.0,
#    u'magic': 0.0,
#    u'masculine': 0.0,
#    u'medical_emergency': 0.0,
#    u'medieval': 0.0,
#    u'meeting': 0.0,
#    u'messaging': 0.0,
#    u'military': 0.0,
#    u'money': 0.0,
#    u'monster': 0.0,
#    u'morning': 0.0,
#    u'movement': 0.0,
#    u'music': 0.0,
#    u'musical': 0.0,
#    u'negative_emotion': 0.0,
#    u'neglect': 0.0,
#    u'negotiate': 0.0,
#    u'nervousness': 0.0,
#    u'night': 0.0,
#    u'noise': 0.05714285714285714,
#    u'occupation': 0.0,
#    u'ocean': 0.0,
#    u'office': 0.0,
#    u'optimism': 0.0,
#    u'order': 0.0,
#    u'pain': 0.0,
#    u'party': 0.0,
#    u'payment': 0.0,
#    u'pet': 0.0,
#    u'philosophy': 0.0,
#    u'phone': 0.0,
#    u'plant': 0.0,
#    u'play': 0.0,
#    u'politeness': 0.0,
#    u'politics': 0.0,
#    u'poor': 0.0,
#    u'positive_emotion': 0.0,
#    u'power': 0.0,
#    u'pride': 0.0,
#    u'prison': 0.0,
#    u'programming': 0.0,
#    u'rage': 0.0,
#    u'reading': 0.0,
#    u'real_estate': 0.0,
#    u'religion': 0.0,
#    u'restaurant': 0.0,
#    u'ridicule': 0.0,
#    u'royalty': 0.0,
#    u'rural': 0.0,
#    u'sadness': 0.0,
#    u'sailing': 0.0,
#    u'school': 0.0,
#    u'science': 0.0,
#    u'sexual': 0.0,
#    u'shame': 0.0,
#    u'shape_and_size': 0.0,
#    u'ship': 0.0,
#    u'shopping': 0.0,
#    u'sleep': 0.0,
#    u'smell': 0.0,
#    u'social_media': 0.0,
#    u'sound': 0.0,
#    u'speaking': 0.0,
#    u'sports': 0.0,
#    u'stealing': 0.0,
#    u'strength': 0.0,
#    u'suffering': 0.0,
#    u'superhero': 0.0,
#    u'surprise': 0.0,
#    u'swearing_terms': 0.0,
#    u'swimming': 0.0,
#    u'sympathy': 0.0,
#    u'technology': 0.0,
#    u'terrorism': 0.0,
#    u'timidity': 0.0,
#    u'tool': 0.02857142857142857,
#    u'torment': 0.0,
#    u'tourism': 0.0,
#    u'toy': 0.0,
#    u'traveling': 0.0,
#    u'trust': 0.0,
#    u'ugliness': 0.0,
#    u'urban': 0.0,
#    u'vacation': 0.0,
#    u'valuable': 0.0,
#    u'vehicle': 0.0,
#    u'violence': 0.0,
#    u'war': 0.0,
#    u'warmth': 0.0,
#    u'water': 0.0,
#    u'weakness': 0.0,
#    u'wealthy': 0.0,
#    u'weapon': 0.0,
#    u'weather': 0.0,
#    u'wedding': 0.0,
#    u'white_collar_job': 0.0,
#    u'work': 0.0,
#    u'worship': 0.0,
#    u'writing': 0.0,
#    u'youth': 0.0,
#    u'zest': 0.0},
#   'descriptionPoliteness': 0.19879736618334787,
#   u'descriptionSentiment': {u'compound': 0.0,
#    u'neg': 0.0,
#    u'neu': 1.0,
#    u'pos': 0.0},
#   u'imUrl': u'http://ecx.images-amazon.com/images/I/31AV7s-sk2L._SY300_.jpg',
#   u'price': 5.26,
#   u'reviewARI': 67.76,
#   u'reviewEmpath': {u'achievement': 0.0,
#    u'affection': 0.020833333333333332,
#    u'aggression': 0.0,
#    u'air_travel': 0.0,
#    u'alcohol': 0.0,
#    u'ancient': 0.0,
#    u'anger': 0.0,
#    u'animal': 0.0,
#    u'anonymity': 0.0,
#    u'anticipation': 0.0,
#    u'appearance': 0.0,
#    u'art': 0.0,
#    u'attractive': 0.0,
#    u'banking': 0.0,
#    u'beach': 0.0,
#    u'beauty': 0.0,
#    u'blue_collar_job': 0.0,
#    u'body': 0.020833333333333332,
#    u'breaking': 0.0,
#    u'business': 0.0,
#    u'car': 0.0,
#    u'celebration': 0.0,
#    u'cheerfulness': 0.0,
#    u'childish': 0.0,
#    u'children': 0.0,
#    u'cleaning': 0.0,
#    u'clothing': 0.0,
#    u'cold': 0.0,
#    u'college': 0.0,
#    u'communication': 0.0,
#    u'competing': 0.0,
#    u'computer': 0.0,
#    u'confusion': 0.020833333333333332,
#    u'contentment': 0.0,
#    u'cooking': 0.0,
#    u'crime': 0.0,
#    u'dance': 0.020833333333333332,
#    u'death': 0.0,
#    u'deception': 0.0,
#    u'disappointment': 0.0,
#    u'disgust': 0.0,
#    u'dispute': 0.0,
#    u'divine': 0.0,
#    u'domestic_work': 0.0,
#    u'dominant_heirarchical': 0.0,
#    u'dominant_personality': 0.0,
#    u'driving': 0.0,
#    u'eating': 0.0,
#    u'economics': 0.0,
#    u'emotional': 0.0,
#    u'envy': 0.0,
#    u'exasperation': 0.0,
#    u'exercise': 0.020833333333333332,
#    u'exotic': 0.0,
#    u'fabric': 0.0,
#    u'family': 0.0,
#    u'farming': 0.0,
#    u'fashion': 0.0,
#    u'fear': 0.0,
#    u'feminine': 0.0,
#    u'fight': 0.020833333333333332,
#    u'fire': 0.0,
#    u'friends': 0.020833333333333332,
#    u'fun': 0.0,
#    u'furniture': 0.0,
#    u'gain': 0.0,
#    u'giving': 0.0,
#    u'government': 0.0,
#    u'hate': 0.0,
#    u'healing': 0.0,
#    u'health': 0.0,
#    u'hearing': 0.020833333333333332,
#    u'help': 0.041666666666666664,
#    u'heroic': 0.0,
#    u'hiking': 0.0,
#    u'hipster': 0.0,
#    u'home': 0.0,
#    u'horror': 0.0,
#    u'hygiene': 0.0,
#    u'independence': 0.0,
#    u'injury': 0.0,
#    u'internet': 0.0,
#    u'irritability': 0.0,
#    u'journalism': 0.0,
#    u'joy': 0.0,
#    u'kill': 0.020833333333333332,
#    u'law': 0.0,
#    u'leader': 0.020833333333333332,
#    u'legend': 0.0,
#    u'leisure': 0.0,
#    u'liquid': 0.0,
#    u'listen': 0.020833333333333332,
#    u'love': 0.020833333333333332,
#    u'lust': 0.0,
#    u'magic': 0.0,
#    u'masculine': 0.0,
#    u'medical_emergency': 0.0,
#    u'medieval': 0.0,
#    u'meeting': 0.0,
#    u'messaging': 0.0,
#    u'military': 0.020833333333333332,
#    u'money': 0.0,
#    u'monster': 0.0,
#    u'morning': 0.0,
#    u'movement': 0.0,
#    u'music': 0.020833333333333332,
#    u'musical': 0.0,
#    u'negative_emotion': 0.0,
#    u'neglect': 0.0,
#    u'negotiate': 0.0,
#    u'nervousness': 0.020833333333333332,
#    u'night': 0.0,
#    u'noise': 0.020833333333333332,
#    u'occupation': 0.0,
#    u'ocean': 0.0,
#    u'office': 0.0,
#    u'optimism': 0.020833333333333332,
#    u'order': 0.020833333333333332,
#    u'pain': 0.0,
#    u'party': 0.0,
#    u'payment': 0.0,
#    u'pet': 0.0,
#    u'philosophy': 0.0,
#    u'phone': 0.0,
#    u'plant': 0.0,
#    u'play': 0.0,
#    u'politeness': 0.0,
#    u'politics': 0.0,
#    u'poor': 0.0,
#    u'positive_emotion': 0.020833333333333332,
#    u'power': 0.0,
#    u'pride': 0.0,
#    u'prison': 0.0,
#    u'programming': 0.0,
#    u'rage': 0.0,
#    u'reading': 0.0,
#    u'real_estate': 0.0,
#    u'religion': 0.0,
#    u'restaurant': 0.0,
#    u'ridicule': 0.0,
#    u'royalty': 0.020833333333333332,
#    u'rural': 0.0,
#    u'sadness': 0.0,
#    u'sailing': 0.0,
#    u'school': 0.0,
#    u'science': 0.0,
#    u'sexual': 0.0,
#    u'shame': 0.020833333333333332,
#    u'shape_and_size': 0.0,
#    u'ship': 0.0,
#    u'shopping': 0.0,
#    u'sleep': 0.0,
#    u'smell': 0.0,
#    u'social_media': 0.0,
#    u'sound': 0.0,
#    u'speaking': 0.0,
#    u'sports': 0.020833333333333332,
#    u'stealing': 0.0,
#    u'strength': 0.0,
#    u'suffering': 0.0,
#    u'superhero': 0.0,
#    u'surprise': 0.0,
#    u'swearing_terms': 0.0,
#    u'swimming': 0.0,
#    u'sympathy': 0.0,
#    u'technology': 0.0,
#    u'terrorism': 0.0,
#    u'timidity': 0.020833333333333332,
#    u'tool': 0.020833333333333332,
#    u'torment': 0.0,
#    u'tourism': 0.0,
#    u'toy': 0.0,
#    u'traveling': 0.0,
#    u'trust': 0.0,
#    u'ugliness': 0.0,
#    u'urban': 0.0,
#    u'vacation': 0.0,
#    u'valuable': 0.0,
#    u'vehicle': 0.0,
#    u'violence': 0.0,
#    u'war': 0.020833333333333332,
#    u'warmth': 0.0,
#    u'water': 0.0,
#    u'weakness': 0.0,
#    u'wealthy': 0.0,
#    u'weapon': 0.020833333333333332,
#    u'weather': 0.0,
#    u'wedding': 0.0,
#    u'white_collar_job': 0.0,
#    u'work': 0.0,
#    u'worship': 0.0,
#    u'writing': 0.0,
#    u'youth': 0.0,
#    u'zest': 0.0},
#   'reviewPoliteness': 0.333051272143984,
#   u'reviewSentiment': {u'compound': 0.4226,
#    u'neg': 0.092,
#    u'neu': 0.782,
#    u'pos': 0.126},
#   u'salesRank': {u'Sports &amp; Outdoors': 11043},
#   u'title': u'Safariland 075-2 Hearing Protector Holder'},
#  u'B0001WP5Z2': {u'Best review': u"The Surefire E1E I own probably gets more use than any other flashlight. It is not bright enough for defense, running about 15 lumens, but as a handy go anywhere flashlight it is superb. I have carried mine for hour long patrols in the rain in Japan and all over the middle east and it has never hiccuped. And if it did I know from experience that Surefire's customer service is second to none. You will pay more for this light then an el cheapo from the local superstore but what you get is a good run time and utter reliability. It won't fall apart of fail you when you need it most, the only down point this light has is the bulb which like all bulbs burns out eventually. Surefire has remedied this with their new LED version though. You can't go wrong with this one.",
#   u'Rating': 5.0,
#   u'description': u'The E1E is an ultra compact flashlight. A special incandescent lamp assembly and a precision micro-textured reflector produce a smooth 15-lumen beam&#x2014;the same output as many big two-D-cell flashlights. The pushbutton tailcap switch provides secure, ergonomic activation control: press for momentary-on, press further to click constant-on. Lightweight enough to clip to the brim of a cap for hands-free operation.',
#   u'descriptionARI': 47.99,
#   u'descriptionEmpath': {u'achievement': 0.0,
#    u'affection': 0.0,
#    u'aggression': 0.0,
#    u'air_travel': 0.0,
#    u'alcohol': 0.0,
#    u'ancient': 0.0,
#    u'anger': 0.0,
#    u'animal': 0.0,
#    u'anonymity': 0.0,
#    u'anticipation': 0.0,
#    u'appearance': 0.0,
#    u'art': 0.0,
#    u'attractive': 0.0,
#    u'banking': 0.0,
#    u'beach': 0.0,
#    u'beauty': 0.0,
#    u'blue_collar_job': 0.0,
#    u'body': 0.0,
#    u'breaking': 0.0,
#    u'business': 0.0,
#    u'car': 0.0,
#    u'celebration': 0.01694915254237288,
#    u'cheerfulness': 0.0,
#    u'childish': 0.0,
#    u'children': 0.0,
#    u'cleaning': 0.0,
#    u'clothing': 0.0,
#    u'cold': 0.0,
#    u'college': 0.0,
#    u'communication': 0.0,
#    u'competing': 0.0,
#    u'computer': 0.01694915254237288,
#    u'confusion': 0.0,
#    u'contentment': 0.0,
#    u'cooking': 0.0,
#    u'crime': 0.0,
#    u'dance': 0.0,
#    u'death': 0.0,
#    u'deception': 0.0,
#    u'disappointment': 0.0,
#    u'disgust': 0.0,
#    u'dispute': 0.0,
#    u'divine': 0.0,
#    u'domestic_work': 0.0,
#    u'dominant_heirarchical': 0.0,
#    u'dominant_personality': 0.0,
#    u'driving': 0.0,
#    u'eating': 0.0,
#    u'economics': 0.0,
#    u'emotional': 0.0,
#    u'envy': 0.0,
#    u'exasperation': 0.0,
#    u'exercise': 0.0,
#    u'exotic': 0.0,
#    u'fabric': 0.01694915254237288,
#    u'family': 0.0,
#    u'farming': 0.0,
#    u'fashion': 0.0,
#    u'fear': 0.0,
#    u'feminine': 0.0,
#    u'fight': 0.0,
#    u'fire': 0.0,
#    u'friends': 0.0,
#    u'fun': 0.0,
#    u'furniture': 0.0,
#    u'gain': 0.0,
#    u'giving': 0.0,
#    u'government': 0.0,
#    u'hate': 0.0,
#    u'healing': 0.0,
#    u'health': 0.0,
#    u'hearing': 0.0,
#    u'help': 0.0,
#    u'heroic': 0.0,
#    u'hiking': 0.0,
#    u'hipster': 0.0,
#    u'home': 0.0,
#    u'horror': 0.0,
#    u'hygiene': 0.0,
#    u'independence': 0.0,
#    u'injury': 0.0,
#    u'internet': 0.01694915254237288,
#    u'irritability': 0.0,
#    u'journalism': 0.0,
#    u'joy': 0.0,
#    u'kill': 0.0,
#    u'law': 0.0,
#    u'leader': 0.0,
#    u'legend': 0.0,
#    u'leisure': 0.0,
#    u'liquid': 0.0,
#    u'listen': 0.0,
#    u'love': 0.0,
#    u'lust': 0.0,
#    u'magic': 0.0,
#    u'masculine': 0.0,
#    u'medical_emergency': 0.0,
#    u'medieval': 0.0,
#    u'meeting': 0.01694915254237288,
#    u'messaging': 0.0,
#    u'military': 0.0,
#    u'money': 0.0,
#    u'monster': 0.0,
#    u'morning': 0.0,
#    u'movement': 0.0,
#    u'music': 0.0,
#    u'musical': 0.0,
#    u'negative_emotion': 0.0,
#    u'neglect': 0.0,
#    u'negotiate': 0.0,
#    u'nervousness': 0.0,
#    u'night': 0.0,
#    u'noise': 0.0,
#    u'occupation': 0.0,
#    u'ocean': 0.0,
#    u'office': 0.0,
#    u'optimism': 0.0,
#    u'order': 0.0,
#    u'pain': 0.0,
#    u'party': 0.01694915254237288,
#    u'payment': 0.0,
#    u'pet': 0.0,
#    u'philosophy': 0.0,
#    u'phone': 0.01694915254237288,
#    u'plant': 0.0,
#    u'play': 0.0,
#    u'politeness': 0.0,
#    u'politics': 0.0,
#    u'poor': 0.0,
#    u'positive_emotion': 0.0,
#    u'power': 0.0,
#    u'pride': 0.0,
#    u'prison': 0.0,
#    u'programming': 0.01694915254237288,
#    u'rage': 0.0,
#    u'reading': 0.0,
#    u'real_estate': 0.0,
#    u'religion': 0.0,
#    u'restaurant': 0.0,
#    u'ridicule': 0.0,
#    u'royalty': 0.0,
#    u'rural': 0.0,
#    u'sadness': 0.0,
#    u'sailing': 0.0,
#    u'school': 0.0,
#    u'science': 0.0,
#    u'sexual': 0.0,
#    u'shame': 0.0,
#    u'shape_and_size': 0.03389830508474576,
#    u'ship': 0.0,
#    u'shopping': 0.0,
#    u'sleep': 0.0,
#    u'smell': 0.0,
#    u'social_media': 0.0,
#    u'sound': 0.0,
#    u'speaking': 0.0,
#    u'sports': 0.0,
#    u'stealing': 0.0,
#    u'strength': 0.0,
#    u'suffering': 0.0,
#    u'superhero': 0.0,
#    u'surprise': 0.0,
#    u'swearing_terms': 0.0,
#    u'swimming': 0.0,
#    u'sympathy': 0.0,
#    u'technology': 0.0,
#    u'terrorism': 0.0,
#    u'timidity': 0.0,
#    u'tool': 0.01694915254237288,
#    u'torment': 0.0,
#    u'tourism': 0.0,
#    u'toy': 0.0,
#    u'traveling': 0.0,
#    u'trust': 0.0,
#    u'ugliness': 0.0,
#    u'urban': 0.0,
#    u'vacation': 0.0,
#    u'valuable': 0.0,
#    u'vehicle': 0.0,
#    u'violence': 0.0,
#    u'war': 0.0,
#    u'warmth': 0.0,
#    u'water': 0.0,
#    u'weakness': 0.0,
#    u'wealthy': 0.0,
#    u'weapon': 0.01694915254237288,
#    u'weather': 0.0,
#    u'wedding': 0.0,
#    u'white_collar_job': 0.0,
#    u'work': 0.0,
#    u'worship': 0.0,
#    u'writing': 0.0,
#    u'youth': 0.0,
#    u'zest': 0.0},
#   'descriptionPoliteness': 0.27099185072819942,
#   u'descriptionSentiment': {u'compound': 0.6249,
#    u'neg': 0.0,
#    u'neu': 0.912,
#    u'pos': 0.088},
#   u'imUrl': u'http://ecx.images-amazon.com/images/I/41pYMBQuyrL._SX300_.jpg',
#   u'reviewARI': 78.18,
#   u'reviewEmpath': {u'achievement': 0.0,
#    u'affection': 0.0,
#    u'aggression': 0.0,
#    u'air_travel': 0.0,
#    u'alcohol': 0.0,
#    u'ancient': 0.0,
#    u'anger': 0.0,
#    u'animal': 0.0,
#    u'anonymity': 0.0,
#    u'anticipation': 0.0,
#    u'appearance': 0.0,
#    u'art': 0.0,
#    u'attractive': 0.0,
#    u'banking': 0.006802721088435374,
#    u'beach': 0.0,
#    u'beauty': 0.006802721088435374,
#    u'blue_collar_job': 0.0,
#    u'body': 0.0,
#    u'breaking': 0.013605442176870748,
#    u'business': 0.034013605442176874,
#    u'car': 0.0,
#    u'celebration': 0.0,
#    u'cheerfulness': 0.0,
#    u'childish': 0.0,
#    u'children': 0.0,
#    u'cleaning': 0.0,
#    u'clothing': 0.0,
#    u'cold': 0.0,
#    u'college': 0.0,
#    u'communication': 0.0,
#    u'competing': 0.0,
#    u'computer': 0.0,
#    u'confusion': 0.0,
#    u'contentment': 0.0,
#    u'cooking': 0.0,
#    u'crime': 0.0,
#    u'dance': 0.0,
#    u'death': 0.0,
#    u'deception': 0.0,
#    u'disappointment': 0.0,
#    u'disgust': 0.0,
#    u'dispute': 0.0,
#    u'divine': 0.0,
#    u'domestic_work': 0.0,
#    u'dominant_heirarchical': 0.0,
#    u'dominant_personality': 0.0,
#    u'driving': 0.0,
#    u'eating': 0.0,
#    u'economics': 0.0,
#    u'emotional': 0.0,
#    u'envy': 0.0,
#    u'exasperation': 0.0,
#    u'exercise': 0.006802721088435374,
#    u'exotic': 0.0,
#    u'fabric': 0.0,
#    u'family': 0.0,
#    u'farming': 0.0,
#    u'fashion': 0.0,
#    u'fear': 0.0,
#    u'feminine': 0.0,
#    u'fight': 0.0,
#    u'fire': 0.013605442176870748,
#    u'friends': 0.0,
#    u'fun': 0.0,
#    u'furniture': 0.0,
#    u'gain': 0.0,
#    u'giving': 0.02040816326530612,
#    u'government': 0.0,
#    u'hate': 0.0,
#    u'healing': 0.0,
#    u'health': 0.0,
#    u'hearing': 0.0,
#    u'help': 0.0,
#    u'heroic': 0.0,
#    u'hiking': 0.0,
#    u'hipster': 0.0,
#    u'home': 0.006802721088435374,
#    u'horror': 0.0,
#    u'hygiene': 0.0,
#    u'independence': 0.0,
#    u'injury': 0.013605442176870748,
#    u'internet': 0.0,
#    u'irritability': 0.0,
#    u'journalism': 0.0,
#    u'joy': 0.0,
#    u'kill': 0.0,
#    u'law': 0.0,
#    u'leader': 0.0,
#    u'legend': 0.0,
#    u'leisure': 0.0,
#    u'liquid': 0.0,
#    u'listen': 0.0,
#    u'love': 0.006802721088435374,
#    u'lust': 0.0,
#    u'magic': 0.0,
#    u'masculine': 0.0,
#    u'medical_emergency': 0.0,
#    u'medieval': 0.0,
#    u'meeting': 0.0,
#    u'messaging': 0.0,
#    u'military': 0.0,
#    u'money': 0.006802721088435374,
#    u'monster': 0.0,
#    u'morning': 0.006802721088435374,
#    u'movement': 0.006802721088435374,
#    u'music': 0.0,
#    u'musical': 0.0,
#    u'negative_emotion': 0.006802721088435374,
#    u'neglect': 0.0,
#    u'negotiate': 0.0,
#    u'nervousness': 0.0,
#    u'night': 0.0,
#    u'noise': 0.0,
#    u'occupation': 0.006802721088435374,
#    u'ocean': 0.0,
#    u'office': 0.0,
#    u'optimism': 0.0,
#    u'order': 0.0,
#    u'pain': 0.006802721088435374,
#    u'party': 0.0,
#    u'payment': 0.013605442176870748,
#    u'pet': 0.0,
#    u'philosophy': 0.0,
#    u'phone': 0.006802721088435374,
#    u'plant': 0.0,
#    u'play': 0.0,
#    u'politeness': 0.0,
#    u'politics': 0.0,
#    u'poor': 0.0,
#    u'positive_emotion': 0.0,
#    u'power': 0.0,
#    u'pride': 0.0,
#    u'prison': 0.0,
#    u'programming': 0.0,
#    u'rage': 0.0,
#    u'reading': 0.0,
#    u'real_estate': 0.006802721088435374,
#    u'religion': 0.0,
#    u'restaurant': 0.006802721088435374,
#    u'ridicule': 0.0,
#    u'royalty': 0.0,
#    u'rural': 0.0,
#    u'sadness': 0.0,
#    u'sailing': 0.0,
#    u'school': 0.0,
#    u'science': 0.0,
#    u'sexual': 0.0,
#    u'shame': 0.0,
#    u'shape_and_size': 0.0,
#    u'ship': 0.0,
#    u'shopping': 0.006802721088435374,
#    u'sleep': 0.0,
#    u'smell': 0.0,
#    u'social_media': 0.0,
#    u'sound': 0.0,
#    u'speaking': 0.0,
#    u'sports': 0.006802721088435374,
#    u'stealing': 0.0,
#    u'strength': 0.0,
#    u'suffering': 0.0,
#    u'superhero': 0.0,
#    u'surprise': 0.006802721088435374,
#    u'swearing_terms': 0.0,
#    u'swimming': 0.0,
#    u'sympathy': 0.0,
#    u'technology': 0.0,
#    u'terrorism': 0.0,
#    u'timidity': 0.0,
#    u'tool': 0.006802721088435374,
#    u'torment': 0.0,
#    u'tourism': 0.0,
#    u'toy': 0.0,
#    u'traveling': 0.0,
#    u'trust': 0.006802721088435374,
#    u'ugliness': 0.0,
#    u'urban': 0.006802721088435374,
#    u'vacation': 0.0,
#    u'valuable': 0.006802721088435374,
#    u'vehicle': 0.0,
#    u'violence': 0.0,
#    u'war': 0.0,
#    u'warmth': 0.0,
#    u'water': 0.006802721088435374,
#    u'weakness': 0.0,
#    u'wealthy': 0.006802721088435374,
#    u'weapon': 0.0,
#    u'weather': 0.006802721088435374,
#    u'wedding': 0.0,
#    u'white_collar_job': 0.0,
#    u'work': 0.0,
#    u'worship': 0.0,
#    u'writing': 0.0,
#    u'youth': 0.0,
#    u'zest': 0.0},
#   'reviewPoliteness': 0.53755363913757015,
#   u'reviewSentiment': {u'compound': 0.9363,
#    u'neg': 0.04,
#    u'neu': 0.819,
#    u'pos': 0.141},
#   u'salesRank': {u'Sports &amp; Outdoors': 544739},
#   u'title': u'Surefire E1E Executive Elite Single-Output Incandescent Flashlight, Black'},
#  u'B0002IXQLK': {u'Best review': u"I bought this to sharpen profiled plane blades; mostly for plane blades used in Stanley's combination planes. They have been excellent for that purpose.  I bought them at a specialty retail store for the same price offered here.  I would recommend them for this purpose as the triangular file and round file are perfect fits for the profiles I have sharpened so far. It is a good idea to get your hand honing skills up to speed when using these as you can't really use a jig because of their size and the profiles of the blades I sharpen.  I bought the fine grade set, and I'd like to see a medium and extra fine set as well.  The addition of the two sets would make sharpening much faster.The files cut quickly in the steel used for the plane blades. I was surprised.  I've never used ceramic before just oil and water stones, sandpaper and diamonds. I have a diamond hone, but it didn't work as well as the files did on these plane blades, and it was too large for some of the profiles (it's a 600 grit thing with a red plastic handle).The produce a near mirror finish on the bevels of the blades I've been sharpening.  I think the extra fine would yield a mirror finish.",
#   u'Rating': 4.0,
#   u'brand': u'Spyderco',
#   u'description': u"New files can also be purchased in Spyderco four-packs (sold separately).This set of four fine-grit ceramic files, stored neatly in an included leather carrying pouch, helps maintain your cutlery and debur hardened tools, molds, and even carbide. The set includes a round, square, triangular, and slip-shaped -- or teardrop -- file, which can be easily cleaned with a plastic scouring pad and powdered abrasive cleaner. Made in the USA, the set is autoclave safe.WarrantySypderco products include a limited manufacturer's warranty against defects in materials and workmanship. Details are included with your purchase.About SpydercoThinking beyond established knife industry practices has allowed Spyderco to introduce new innovations, including one-hand opening, serrations on a folder, and a clip to attach a knife to a pocket. Spyderco remains dedicated to researching and developing improved, better-performing materials with function and reliability, and its unique cutlery line is a result of designing ergonomic, functional tools. The company puts its new products through rigorous testing prior to release, examining edge retention with a CATRA machine, looking for rust development with Q-FOG, checking the force needed to open and close a knife, and analyzing numerous other technical details.",
#   u'descriptionARI': 33.34,
#   u'descriptionEmpath': {u'achievement': 0.0,
#    u'affection': 0.0,
#    u'aggression': 0.005263157894736842,
#    u'air_travel': 0.0,
#    u'alcohol': 0.0,
#    u'ancient': 0.0,
#    u'anger': 0.0,
#    u'animal': 0.0,
#    u'anonymity': 0.0,
#    u'anticipation': 0.0,
#    u'appearance': 0.0,
#    u'art': 0.005263157894736842,
#    u'attractive': 0.005263157894736842,
#    u'banking': 0.005263157894736842,
#    u'beach': 0.0,
#    u'beauty': 0.005263157894736842,
#    u'blue_collar_job': 0.0,
#    u'body': 0.0,
#    u'breaking': 0.0,
#    u'business': 0.015789473684210527,
#    u'car': 0.0,
#    u'celebration': 0.0,
#    u'cheerfulness': 0.0,
#    u'childish': 0.0,
#    u'children': 0.0,
#    u'cleaning': 0.005263157894736842,
#    u'clothing': 0.005263157894736842,
#    u'cold': 0.0,
#    u'college': 0.0,
#    u'communication': 0.005263157894736842,
#    u'competing': 0.0,
#    u'computer': 0.005263157894736842,
#    u'confusion': 0.0,
#    u'contentment': 0.0,
#    u'cooking': 0.0,
#    u'crime': 0.0,
#    u'dance': 0.0,
#    u'death': 0.0,
#    u'deception': 0.0,
#    u'disappointment': 0.0,
#    u'disgust': 0.0,
#    u'dispute': 0.0,
#    u'divine': 0.0,
#    u'domestic_work': 0.005263157894736842,
#    u'dominant_heirarchical': 0.0,
#    u'dominant_personality': 0.0,
#    u'driving': 0.0,
#    u'eating': 0.0,
#    u'economics': 0.010526315789473684,
#    u'emotional': 0.0,
#    u'envy': 0.0,
#    u'exasperation': 0.0,
#    u'exercise': 0.005263157894736842,
#    u'exotic': 0.0,
#    u'fabric': 0.0,
#    u'family': 0.0,
#    u'farming': 0.0,
#    u'fashion': 0.0,
#    u'fear': 0.0,
#    u'feminine': 0.0,
#    u'fight': 0.005263157894736842,
#    u'fire': 0.0,
#    u'friends': 0.0,
# ...
#    u'competing': 0.006711409395973154,
#    u'computer': 0.0,
#    u'confusion': 0.0,
#    u'contentment': 0.0,
#    u'cooking': 0.0,
#    u'crime': 0.0,
#    u'dance': 0.0,
#    u'death': 0.0,
#    u'deception': 0.0,
#    u'disappointment': 0.0,
#    u'disgust': 0.0,
#    u'dispute': 0.0,
#    u'divine': 0.0,
#    u'domestic_work': 0.0,
#    u'dominant_heirarchical': 0.0,
#    u'dominant_personality': 0.0,
#    u'driving': 0.0,
#    u'eating': 0.0,
#    u'economics': 0.0,
#    u'emotional': 0.0,
#    u'envy': 0.0,
#    u'exasperation': 0.0,
#    u'exercise': 0.0,
#    u'exotic': 0.0,
#    u'fabric': 0.006711409395973154,
#    u'family': 0.0,
#    u'farming': 0.0,
#    u'fashion': 0.0,
#    u'fear': 0.0,
#    u'feminine': 0.0,
#    u'fight': 0.0,
#    u'fire': 0.013422818791946308,
#    u'friends': 0.0,
#    u'fun': 0.0,
#    u'furniture': 0.006711409395973154,
#    u'gain': 0.0,
#    u'giving': 0.013422818791946308,
#    u'government': 0.0,
#    u'hate': 0.0,
#    u'healing': 0.0,
#    u'health': 0.0,
#    u'hearing': 0.0,
#    u'help': 0.006711409395973154,
#    u'heroic': 0.0,
#    u'hiking': 0.0,
#    u'hipster': 0.0,
#    u'home': 0.006711409395973154,
#    u'horror': 0.0,
#    u'hygiene': 0.0,
#    u'independence': 0.0,
#    u'injury': 0.0,
#    u'internet': 0.0,
#    u'irritability': 0.0,
#    u'journalism': 0.0,
#    u'joy': 0.0,
#    u'kill': 0.006711409395973154,
#    u'law': 0.0,
#    u'leader': 0.0,
#    u'legend': 0.0,
#    u'leisure': 0.0,
#    u'liquid': 0.0,
#    u'listen': 0.0,
#    u'love': 0.0,
#    u'lust': 0.0,
#    u'magic': 0.0,
#    u'masculine': 0.0,
#    u'medical_emergency': 0.0,
#    u'medieval': 0.0,
#    u'meeting': 0.0,
#    u'messaging': 0.0,
#    u'military': 0.0,
#    u'money': 0.0,
#    u'monster': 0.0,
#    u'morning': 0.0,
#    u'movement': 0.0,
#    u'music': 0.0,
#    u'musical': 0.0,
#    u'negative_emotion': 0.006711409395973154,
#    u'neglect': 0.0,
#    u'negotiate': 0.0,
#    u'nervousness': 0.0,
#    u'night': 0.006711409395973154,
#    u'noise': 0.0,
#    u'occupation': 0.0,
#    u'ocean': 0.0,
#    u'office': 0.006711409395973154,
#    u'optimism': 0.006711409395973154,
#    u'order': 0.0,
#    u'pain': 0.0,
#    u'party': 0.0,
#    u'payment': 0.0,
#    u'pet': 0.0,
#    u'philosophy': 0.0,
#    u'phone': 0.0,
#    u'plant': 0.0,
#    u'play': 0.0,
#    u'politeness': 0.0,
#    u'politics': 0.0,
#    u'poor': 0.0,
#    u'positive_emotion': 0.013422818791946308,
#    u'power': 0.0,
#    u'pride': 0.0,
#    u'prison': 0.0,
#    u'programming': 0.0,
#    u'rage': 0.0,
#    u'reading': 0.0,
#    u'real_estate': 0.0,
#    u'religion': 0.0,
#    u'restaurant': 0.0,
#    u'ridicule': 0.0,
#    u'royalty': 0.0,
#    u'rural': 0.0,
#    u'sadness': 0.0,
#    u'sailing': 0.0,
#    u'school': 0.0,
#    u'science': 0.0,
#    u'sexual': 0.0,
#    u'shame': 0.0,
#    u'shape_and_size': 0.020134228187919462,
#    u'ship': 0.0,
#    u'shopping': 0.0,
#    u'sleep': 0.0,
#    u'smell': 0.0,
#    u'social_media': 0.0,
#    u'sound': 0.0,
#    u'speaking': 0.0,
#    u'sports': 0.0,
#    u'stealing': 0.0,
#    u'strength': 0.006711409395973154,
#    u'suffering': 0.0,
#    u'superhero': 0.0,
#    u'surprise': 0.0,
#    u'swearing_terms': 0.0,
#    u'swimming': 0.0,
#    u'sympathy': 0.0,
#    u'technology': 0.0,
#    u'terrorism': 0.0,
#    u'timidity': 0.0,
#    u'tool': 0.020134228187919462,
#    u'torment': 0.0,
#    u'tourism': 0.0,
#    u'toy': 0.0,
#    u'traveling': 0.0,
#    u'trust': 0.006711409395973154,
#    u'ugliness': 0.0,
#    u'urban': 0.0,
#    u'vacation': 0.0,
#    u'valuable': 0.0,
#    u'vehicle': 0.0,
#    u'violence': 0.0,
#    u'war': 0.0,
#    u'warmth': 0.0,
#    u'water': 0.0,
#    u'weakness': 0.0,
#    u'wealthy': 0.0,
#    u'weapon': 0.006711409395973154,
#    u'weather': 0.0,
#    u'wedding': 0.0,
#    u'white_collar_job': 0.0,
#    u'work': 0.0,
#    u'worship': 0.0,
#    u'writing': 0.0,
#    u'youth': 0.0,
#    u'zest': 0.0},
#   'reviewPoliteness': 0.67916978130163463,
#   u'reviewSentiment': {u'compound': 0.9547,
#    u'neg': 0.069,
#    u'neu': 0.77,
#    u'pos': 0.16},
#   u'salesRank': {u'Sports &amp; Outdoors': 191855},
#   u'title': u'Mudder&reg; Multifunction LED Torch Emergency Flashlight (3 Modes (7 LED Flashlight&gt;18 LED Work Light &gt; 6 Red LED Light), with Magnetic Bottom to Stick to Any Metal Surface) Waterproof Fits in Glove Box Great Tool to Keep in Car Boat'},
#  u'B00KGNZBM8': {u'Best review': u'Paracord bracelets are all the rage. They are now the new "in" outdoor accessory and fashion statement. And they are actually useful, one can do so many, many things with paracord.This one also comes with a couple of fire starters and a "key" to use as a striker.You can also make a monkey fist knot keychain, watch fob, etc.What is nice is that The Friendly Swede uses all first quality materials. No cheap junk here.  Good colors.This might be a nice Scout project.I rcvd a sample for review.',
#   u'Rating': 5.0,
#   u'description': u'The Friendly Swede Premium Paracord KitAlways be prepared - never be without paracord!CONTENTSThis kit contains three lengths of military grade 350lb paracord and is packed with a selection of the Friendly Swede\'s premium quality accessories!3 x 12 foot 350lb ParacordQuick Release Plastic BuckleCarabinerLarge O RingMetal ToggleLarge Metal ShackleSmall Metal ShackleFriendly Swede Fire Knife and Fire Ring2 x FiresticksCork BallPLUS - a Friendly Swede instruction manual containing two different paracord design ideas (bracelet and keychain) and details of how to find new designs and enter our paracord competitions!SUITABLE FORPerfect as a gift for survivalists, crafters, hunters, outdoorsman, campers, sports fishers, DIY enthusiasts... Not recommended for children under 7 years old due to small parts.Notes:Avoid forest fires and protect our countryside - only use firesticks in a controlled environment and take care in wooded/dry conditions. Use under adult supervisionCarabineer not intended for climbing/load bearingOUR PROMISE TO YOUWe are totally obsessive about quality and customer service - if you have any questions please get in touch and we will do everything we can to solve them. This Product is sold withThe Friendly Swede Lifetime Warranty.Please see our Amazon Storefront Page for more information about our Lifetime Warranty.There\'s a reason they call us "The Friendly Swede"',
#   u'descriptionARI': 42.92,
#   u'descriptionEmpath': {u'achievement': 0.0,
#    u'affection': 0.0,
#    u'aggression': 0.0,
#    u'air_travel': 0.0,
#    u'alcohol': 0.0,
#    u'ancient': 0.0049504950495049506,
#    u'anger': 0.0,
#    u'animal': 0.0,
#    u'anonymity': 0.0,
#    u'anticipation': 0.0,
#    u'appearance': 0.0,
#    u'art': 0.0049504950495049506,
#    u'attractive': 0.0,
#    u'banking': 0.0,
#    u'beach': 0.0,
#    u'beauty': 0.0,
#    u'blue_collar_job': 0.0,
#    u'body': 0.009900990099009901,
#    u'breaking': 0.0,
#    u'business': 0.009900990099009901,
#    u'car': 0.0,
#    u'celebration': 0.0049504950495049506,
#    u'cheerfulness': 0.0,
#    u'childish': 0.0,
#    u'children': 0.0049504950495049506,
#    u'cleaning': 0.0,
#    u'clothing': 0.0,
#    u'cold': 0.0049504950495049506,
#    u'college': 0.0049504950495049506,
#    u'communication': 0.009900990099009901,
#    u'competing': 0.0,
#    u'computer': 0.0,
#    u'confusion': 0.0,
#    u'contentment': 0.0,
#    u'cooking': 0.0,
#    u'crime': 0.0,
#    u'dance': 0.0,
#    u'death': 0.0,
#    u'deception': 0.0,
#    u'disappointment': 0.0,
#    u'disgust': 0.0,
#    u'dispute': 0.0,
#    u'divine': 0.0,
#    u'domestic_work': 0.0,
#    u'dominant_heirarchical': 0.0,
#    u'dominant_personality': 0.0,
#    u'driving': 0.0,
#    u'eating': 0.0,
#    u'economics': 0.0,
#    u'emotional': 0.0,
#    u'envy': 0.0,
#    u'exasperation': 0.0,
#    u'exercise': 0.0,
#    u'exotic': 0.0,
#    u'fabric': 0.0,
#    u'family': 0.0,
#    u'farming': 0.009900990099009901,
#    u'fashion': 0.0,
#    u'fear': 0.0,
#    u'feminine': 0.0,
#    u'fight': 0.0049504950495049506,
#    u'fire': 0.0,
#    u'friends': 0.0,
#    u'fun': 0.0,
#    u'furniture': 0.0,
#    u'gain': 0.0,
#    u'giving': 0.009900990099009901,
#    u'government': 0.0,
#    u'hate': 0.0,
#    u'healing': 0.0049504950495049506,
#    u'health': 0.0,
#    u'hearing': 0.0049504950495049506,
#    u'help': 0.0049504950495049506,
#    u'heroic': 0.0,
#    u'hiking': 0.01485148514851485,
#    u'hipster': 0.0049504950495049506,
#    u'home': 0.0,
#    u'horror': 0.0,
#    u'hygiene': 0.0,
#    u'independence': 0.0,
#    u'injury': 0.0,
#    u'internet': 0.0049504950495049506,
#    u'irritability': 0.0,
#    u'journalism': 0.0,
#    u'joy': 0.0,
#    u'kill': 0.0,
#    u'law': 0.0,
#    u'leader': 0.0,
#    u'legend': 0.0,
#    u'leisure': 0.0,
#    u'liquid': 0.0,
#    u'listen': 0.0049504950495049506,
#    u'love': 0.0,
#    u'lust': 0.0,
#    u'magic': 0.0,
#    u'masculine': 0.0,
#    u'medical_emergency': 0.0,
#    u'medieval': 0.0,
#    u'meeting': 0.0049504950495049506,
#    u'messaging': 0.0,
#    u'military': 0.0049504950495049506,
#    u'money': 0.0,
#    u'monster': 0.0,
#    u'morning': 0.0,
#    u'movement': 0.0,
#    u'music': 0.0,
#    u'musical': 0.0,
#    u'negative_emotion': 0.009900990099009901,
#    u'neglect': 0.0,
#    u'negotiate': 0.0,
#    u'nervousness': 0.0,
#    u'night': 0.0,
#    u'noise': 0.0,
#    u'occupation': 0.0049504950495049506,
#    u'ocean': 0.0,
#    u'office': 0.0049504950495049506,
#    u'optimism': 0.0,
#    u'order': 0.0049504950495049506,
#    u'pain': 0.0,
#    u'party': 0.0049504950495049506,
#    u'payment': 0.0049504950495049506,
#    u'pet': 0.0,
#    u'philosophy': 0.0,
#    u'phone': 0.009900990099009901,
#    u'plant': 0.0049504950495049506,
#    u'play': 0.0,
#    u'politeness': 0.0,
#    u'politics': 0.0,
#    u'poor': 0.0,
#    u'positive_emotion': 0.009900990099009901,
#    u'power': 0.0,
#    u'pride': 0.0,
#    u'prison': 0.0,
#    u'programming': 0.0049504950495049506,
#    u'rage': 0.0,
#    u'reading': 0.0049504950495049506,
#    u'real_estate': 0.0,
#    u'religion': 0.0,
#    u'restaurant': 0.0049504950495049506,
#    u'ridicule': 0.0,
#    u'royalty': 0.0,
#    u'rural': 0.009900990099009901,
#    u'sadness': 0.0,
#    u'sailing': 0.0,
#    u'school': 0.0049504950495049506,
#    u'science': 0.0,
#    u'sexual': 0.0,
#    u'shame': 0.0,
#    u'shape_and_size': 0.0049504950495049506,
#    u'ship': 0.0,
#    u'shopping': 0.009900990099009901,
#    u'sleep': 0.0,
#    u'smell': 0.0,
#    u'social_media': 0.0,
#    u'sound': 0.0,
#    u'speaking': 0.0049504950495049506,
#    u'sports': 0.0,
#    u'stealing': 0.0,
#    u'strength': 0.0,
#    u'suffering': 0.0,
#    u'superhero': 0.0,
#    u'surprise': 0.0,
#    u'swearing_terms': 0.0,
#    u'swimming': 0.0,
#    u'sympathy': 0.0,
#    u'technology': 0.0,
#    u'terrorism': 0.0,
#    u'timidity': 0.0,
#    u'tool': 0.0,
#    u'torment': 0.0,
#    u'tourism': 0.0,
#    u'toy': 0.0,
#    u'traveling': 0.0049504950495049506,
#    u'trust': 0.0049504950495049506,
#    u'ugliness': 0.0,
#    u'urban': 0.0,
#    u'vacation': 0.0049504950495049506,
#    u'valuable': 0.01485148514851485,
#    u'vehicle': 0.0,
#    u'violence': 0.0,
#    u'war': 0.0,
#    u'warmth': 0.0,
#    u'water': 0.0,
#    u'weakness': 0.0,
#    u'wealthy': 0.0,
#    u'weapon': 0.0,
#    u'weather': 0.0049504950495049506,
#    u'wedding': 0.0049504950495049506,
#    u'white_collar_job': 0.0,
#    u'work': 0.0,
#    u'worship': 0.0,
#    u'writing': 0.0049504950495049506,
#    u'youth': 0.0,
#    u'zest': 0.0},
#   'descriptionPoliteness': 0.7700851543642836,
#   u'descriptionSentiment': {u'compound': 0.982,
#    u'neg': 0.032,
#    u'neu': 0.792,
#    u'pos': 0.176},
#   u'imUrl': u'http://ecx.images-amazon.com/images/I/51-K0UhX2dL._SY300_.jpg',
#   u'price': 14.99,
#   u'reviewARI': 78.45,
#   u'reviewEmpath': {u'achievement': 0.0,
#    u'affection': 0.0,
#    u'aggression': 0.0,
#    u'air_travel': 0.0,
#    u'alcohol': 0.0,
#    u'ancient': 0.0,
#    u'anger': 0.0,
#    u'animal': 0.011363636363636364,
#    u'anonymity': 0.0,
#    u'anticipation': 0.0,
#    u'appearance': 0.0,
#    u'art': 0.0,
#    u'attractive': 0.0,
#    u'banking': 0.0,
#    u'beach': 0.0,
#    u'beauty': 0.0,
#    u'blue_collar_job': 0.0,
#    u'body': 0.0,
#    u'breaking': 0.0,
#    u'business': 0.0,
#    u'car': 0.0,
#    u'celebration': 0.0,
#    u'cheerfulness': 0.0,
#    u'childish': 0.0,
#    u'children': 0.0,
#    u'cleaning': 0.0,
#    u'clothing': 0.022727272727272728,
#    u'cold': 0.0,
#    u'college': 0.0,
#    u'communication': 0.0,
#    u'competing': 0.0,
#    u'computer': 0.0,
#    u'confusion': 0.0,
#    u'contentment': 0.0,
#    u'cooking': 0.0,
#    u'crime': 0.0,
#    u'dance': 0.0,
#    u'death': 0.0,
#    u'deception': 0.0,
#    u'disappointment': 0.0,
#    u'disgust': 0.0,
#    u'dispute': 0.0,
#    u'divine': 0.0,
#    u'domestic_work': 0.0,
#    u'dominant_heirarchical': 0.0,
#    u'dominant_personality': 0.0,
#    u'driving': 0.0,
#    u'eating': 0.011363636363636364,
#    u'economics': 0.011363636363636364,
#    u'emotional': 0.0,
#    u'envy': 0.0,
#    u'exasperation': 0.0,
#    u'exercise': 0.0,
#    u'exotic': 0.0,
#    u'fabric': 0.0,
#    u'family': 0.0,
#    u'farming': 0.0,
#    u'fashion': 0.011363636363636364,
#    u'fear': 0.0,
#    u'feminine': 0.022727272727272728,
#    u'fight': 0.0,
#    u'fire': 0.011363636363636364,
#    u'friends': 0.022727272727272728,
#    u'fun': 0.0,
#    u'furniture': 0.0,
#    u'gain': 0.0,
#    u'giving': 0.0,
#    u'government': 0.0,
#    u'hate': 0.0,
#    u'healing': 0.0,
#    u'health': 0.0,
#    u'hearing': 0.0,
#    u'help': 0.0,
#    u'heroic': 0.0,
#    u'hiking': 0.0,
#    u'hipster': 0.011363636363636364,
#    u'home': 0.0,
#    u'horror': 0.0,
#    u'hygiene': 0.0,
#    u'independence': 0.0,
#    u'injury': 0.0,
#    u'internet': 0.0,
#    u'irritability': 0.0,
#    u'journalism': 0.0,
#    u'joy': 0.0,
#    u'kill': 0.0,
#    u'law': 0.0,
#    u'leader': 0.0,
#    u'legend': 0.0,
#    u'leisure': 0.011363636363636364,
#    u'liquid': 0.0,
#    u'listen': 0.0,
#    u'love': 0.0,
#    u'lust': 0.0,
#    u'magic': 0.0,
#    u'masculine': 0.0,
#    u'medical_emergency': 0.0,
#    u'medieval': 0.0,
#    u'meeting': 0.0,
#    u'messaging': 0.0,
#    u'military': 0.0,
#    u'money': 0.0,
#    u'monster': 0.0,
#    u'morning': 0.0,
#    u'movement': 0.0,
#    u'music': 0.0,
#    u'musical': 0.0,
#    u'negative_emotion': 0.0,
#    u'neglect': 0.0,
#    u'negotiate': 0.0,
#    u'nervousness': 0.0,
#    u'night': 0.0,
#    u'noise': 0.0,
#    u'occupation': 0.0,
#    u'ocean': 0.0,
#    u'office': 0.0,
#    u'optimism': 0.0,
#    u'order': 0.0,
#    u'pain': 0.0,
#    u'party': 0.0,
#    u'payment': 0.011363636363636364,
#    u'pet': 0.0,
#    u'philosophy': 0.0,
#    u'phone': 0.0,
#    u'plant': 0.0,
#    u'play': 0.011363636363636364,
#    u'politeness': 0.022727272727272728,
#    u'politics': 0.0,
#    u'poor': 0.0,
#    u'positive_emotion': 0.0,
#    u'power': 0.0,
#    u'pride': 0.0,
#    u'prison': 0.0,
#    u'programming': 0.0,
#    u'rage': 0.0,
#    u'reading': 0.0,
#    u'real_estate': 0.011363636363636364,
#    u'religion': 0.0,
#    u'restaurant': 0.0,
#    u'ridicule': 0.0,
#    u'royalty': 0.0,
#    u'rural': 0.0,
#    u'sadness': 0.0,
#    u'sailing': 0.0,
#    u'school': 0.0,
#    u'science': 0.011363636363636364,
#    u'sexual': 0.0,
#    u'shame': 0.0,
#    u'shape_and_size': 0.0,
#    u'ship': 0.0,
#    u'shopping': 0.011363636363636364,
#    u'sleep': 0.0,
#    u'smell': 0.0,
#    u'social_media': 0.0,
#    u'sound': 0.0,
#    u'speaking': 0.0,
#    u'sports': 0.011363636363636364,
#    u'stealing': 0.0,
#    u'strength': 0.011363636363636364,
#    u'suffering': 0.0,
#    u'superhero': 0.0,
#    u'surprise': 0.0,
#    u'swearing_terms': 0.0,
#    u'swimming': 0.011363636363636364,
#    u'sympathy': 0.0,
#    u'technology': 0.0,
#    u'terrorism': 0.0,
#    u'timidity': 0.0,
#    u'tool': 0.0,
#    u'torment': 0.0,
#    u'tourism': 0.0,
#    u'toy': 0.0,
#    u'traveling': 0.0,
#    u'trust': 0.0,
#    u'ugliness': 0.0,
#    u'urban': 0.0,
#    u'vacation': 0.0,
#    u'valuable': 0.011363636363636364,
#    u'vehicle': 0.0,
#    u'violence': 0.0,
#    u'war': 0.0,
#    u'warmth': 0.011363636363636364,
#    u'water': 0.0,
#    u'weakness': 0.0,
#    u'wealthy': 0.0,
#    u'weapon': 0.011363636363636364,
#    u'weather': 0.0,
#    u'wedding': 0.0,
#    u'white_collar_job': 0.0,
#    u'work': 0.0,
#    u'worship': 0.0,
#    u'writing': 0.0,
#    u'youth': 0.0,
#    u'zest': 0.0},
#   'reviewPoliteness': 0.67949670113036054,
#   u'reviewSentiment': {u'compound': 0.7506,
#    u'neg': 0.085,
#    u'neu': 0.764,
#    u'pos': 0.151},
#   u'salesRank': {u'Sports &amp; Outdoors': 35600},
#   u'title': u'Premium Paracord Kit - DIY Paracord Bundle includes 3 x 350lb military grade paracord (total 36 feet), more than ten accessories, including steel shackles, buckles, carabiner, firestarters AND instructions for making paracord bracelets and keychains - Lifetime Warranty by The Friendly Swede'}}
