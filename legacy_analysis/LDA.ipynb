# %%
import json
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# html img map
json_data_sales = open('./out/cleanAsinSimilarProductsPriceBrandImageDict.json').read()
json_data = open('./out/HomeKitchenFinal2.json').read()
sales_data = json.loads(json_data_sales)
review_description_data = json.loads(json_data)

# %%
len( json_data_sales )
# Out:
# 2065484

# %%
for key in sales_data :
    print(  sales_data[key].keys()  )
# Out:
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# ...
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])
# dict_keys(['similar', 'brand', 'imUrl', 'price'])

# %%
from collections import defaultdict

# %%
def reverse_asin_price_function( data ) :
    reverse_price_asin = defaultdict( list )
    for key in data :  #some data don't have price
        sales_keyword = None
        if 'price' in data[key] :
            sales_keyword = 'price'
        elif 'sales' in data[key]:
            sales_keyword = 'sales'
        if sales_keyword is not None :
            price = data[key][ sales_keyword ]
            reverse_price_asin[ price ].append( key )
    return reverse_price_asin

reverse_price_asin = reverse_asin_price_function( sales_data )
reverse_price_asin
# Out:
# defaultdict(list,
#             {69.95: ['B0093SLXD8',
#               'B004R952PI',
#               'B0040M4D0W',
#               'B000LTPF96',
#               'B003S8KLPU',
#               'B001ICUNSI'],
#              4.69: ['B000H6AESK',
#               'B003OR3H7Y',
#               'B000H6CA46',
#               'B000H6H44M',
#               'B000H6C5PK'],
#              167.0: ['B000NPTZY4', 'B005OYC4BU'],
#              11.22: ['B00352LOKA'],
#              49.06: ['B000J4MIHK'],
#              148.75: ['B000MRV7QM'],
#              109.34: ['B003IB5TZE'],
#              64.43: ['B0046EC0LS'],
#              5.57: ['B003O9GH56', 'B0006L7KY2'],
#              31.49: ['B000BKBJWW', 'B004XOOGUY', 'B00027EXLI', 'B006IJ3XB0'],
#              20.12: ['B005HER56G'],
#              23.97: ['B0000CNQX2', 'B00GXJMWUI', 'B003JKL444', 'B004GXAJ4Y'],
#              59.99: ['B0027EMTD8',
#               'B000FHF2Q0',
#               'B004FTOTUY',
#               'B00HVC7ZP8',
#               'B0096JYGME',
#               'B004FTOTS6',
#               'B000I84QZ4',
#               'B000BQRD0I',
#               'B008Z9A3YG',
#               'B004D95U0E',
#               'B00004VWIO',
#               'B003TV4PDA',
#               'B004NIVX24',
#               'B005CK0Z08',
#               'B005DNOZJ6',
#               'B004VG9KG4',
#               'B000F1FL9E',
#               'B0071IP5MW',
#               'B00DDH756O',
#               'B002HWR598',
#               'B004SOG1V6',
#               'B001WAKFHA',
#               'B004FKBPB4',
#               'B0027FFMYU',
#               'B003RWTKJA',
#               'B0000SW02S',
#               'B004VMTJ4G',
#               'B0049DUFQI',
#               'B004E7BJ32',
#               'B0085J6RZA',
#               'B001EX44C2',
#               'B002XQ7YNK',
#               'B0071IP6P8',
#               'B003G2ZVZ8'],
#              17.28: ['B0000TQHUS'],
#              16.0: ['B00345WZLK',
#               'B000H8CPK8',
#               'B004TMMV3Y',
#               'B009SZ2P4C',
#               'B003BED03Q',
#               'B009SZ2PQA',
#               'B002H9XCCK',
#               'B0083WN9ZA',
#               'B003EV6D3U',
#               'B000QGLB7Y'],
#              34.0: ['B000YQBN6K', 'B004494A1S', 'B008BOC2JY'],
#              9.25: ['B002YI6R5I', 'B001L19TUE'],
#              93.0: ['B00CZITJDY', 'B0018SJPQI'],
#              3.49: ['B003PGQHRG', 'B000IF6SMQ', 'B002MWAB9E', 'B000WY4FY6'],
#              124.8: ['B005YR24GC'],
#              9.99: ['B001L7U4Y8',
#               'B0001E839U',
#               'B008OLR5VO',
#               'B004ZIXO8S',
#               'B001J4BYSS',
#               'B002FK4PU4',
#               'B004IMFAOC',
#               'B009L3LTG6',
#               'B004Y15U3I',
#               'B00EDSPJIS',
#               'B00280HM7Y',
#               'B000GHZEX0',
#               'B0055OG68Q',
#               'B00020V92Q',
#               'B00725E9KS',
#               'B0053UBHQS',
#               'B0067HFQJ0',
#               'B00EJU3SWY',
#               'B00D3NXQ98',
#               'B000KJZ2J0',
#               'B004BIQVXW',
#               'B0052WG37K',
#               'B00192PL9I',
#               'B00A48DF00',
#               'B00022NGHA',
#               'B007KL22LC',
#               'B0014RB3CW',
#               'B009NSW5VC',
#               'B0086S76O6',
#               'B003MR036O',
#               'B008H6DC36',
#               'B00EHYKIMU',
#               'B0000E1VQV',
#               'B000QSGEO2',
#               'B000KKIR1Y',
#               'B007F1OFQM',
#               'B000079XWA',
#               'B00C0DZS4S',
#               'B002AS9NC6',
#               'B003EYUZLI',
#               'B006HNPJ5K',
#               'B006GPX7VM',
#               'B001IUBFIW',
#               'B001L57EKM',
#               'B003SIAWWC',
#               'B004GSQLQE',
#               'B004GXAIFE',
#               'B003TYAUMC',
#               'B003UDUH5W',
#               'B002OJI8LI',
#               'B003XNGPF0',
#               'B004GXAIFY',
#               'B002H9W9U6',
#               'B0068PXFIA',
#               'B00FDXD448',
#               'B00GIZDJK4',
#               'B008OLVWJU',
#               'B002GP7TX8',
#               'B007M6GM1Q',
#               'B0047GP328',
#               'B00004YK54',
#               'B003VCKL4O',
#               'B0052WG104',
#               'B002M37W4U',
#               'B004IK82R6',
#               'B000095ZGB',
#               'B004JKLN76',
#               'B003NGDBTU',
#               'B003V05NRG',
#               'B000B5HJX0',
#               'B0067HFQA4',
#               'B008MWKNLY',
#               'B002UBOFQM',
#               'B0067HFQ3Q'],
#              102.0: ['B00B2QU5YW'],
#              169.0: ['B005N87DUO', 'B002RV57KS', 'B002RRFBWG', 'B000GLRG1E'],
#              361.2: ['B000LO8NVI'],
#              9.36: ['B003NYFF1O', 'B001F51AQW'],
#              80.99: ['B00C4Y5RQ2', 'B0046EC0MW'],
#              152.67: ['B0002DUQDG', 'B004NBXUWC'],
#              12.99: ['B003M8GMYK',
#               'B000JTFTJO',
#               'B00E0H2TKI',
#               'B003CLMWWS',
#               'B000063SB4',
#               'B000L1KN1O',
#               'B000ND7A5M',
#               'B0013G1CZM',
#               'B001VEJBAY',
#               'B000X1JZR0',
#               'B003PBW7C0',
#               'B003GUTYAI',
#               'B00I5NGFGW',
#               'B009WVFSQE',
#               'B00668IZNE',
#               'B006PNVTFQ',
#               'B005YNSRPI',
#               'B009SAJO14',
#               'B0052WG0DM',
#               'B001HOIQ7W',
#               'B0049O92N4',
#               'B0009XB8FO',
#               'B005IGVM6C',
#               'B00I3JXDRM',
#               'B005KS2U96',
#               'B001HOMYX4',
#               'B000KFSOOY',
#               'B00310PDNA',
#               'B005FW1WQE',
#               'B0045U2MUM',
#               'B004SF2IUI',
#               'B003O5H0BA',
#               'B001048V8I',
#               'B0006B465I',
#               'B001HON046',
#               'B002IUCPQW',
#               'B005DTYMMA',
#               'B004PJLW0E',
#               'B00FSREEZM',
#               'B00IPBNTEA',
#               'B007IUJMMM',
#               'B000FHFHTC',
#               'B0077AZZ1K',
#               'B00CPYYNQQ',
#               'B006OYX2BU',
#               'B0035LMG1W',
#               'B000ZOFV8W',
#               'B009IQFPLQ',
#               'B004BQQWOM',
#               'B009TK66KU',
#               'B0007W4X7C',
#               'B00G3C06KI',
#               'B000MGGG0U',
#               'B005IGVCYY'],
#              139.0: ['B0014E6DOI', 'B000Z3UF7A', 'B00B4EIWD8', 'B0000DF0RB'],
#              218.0: ['B0045EOZTO'],
#              156.27: ['B003EQ4AAI'],
#              29.99: ['B0070O5UGI',
#               'B0002EXYMA',
#               'B004P1I2V4',
#               'B00AIYH1EG',
#               'B00DM8J06M',
#               'B0009WG32S',
#               'B00H17U1QS',
#               'B002T06LD4',
#               'B009UZ88YG',
#               'B00DG81IV8',
#               'B00CPG8194',
#               'B0051946DW',
#               'B005TP8SZK',
#               'B000RGVPTC',
#               'B002M3SP4Q',
#               'B00D6OZNRM',
#               'B00IT26M8K',
#               'B00GSKT2CI',
#               'B003EQ3CUC',
#               'B007BQIOA4',
#               'B005TP8LJS',
#               'B003VQQLAI',
#               'B000M8JA6U',
#               'B001B1JE72',
#               'B0012OMHP4',
#               'B00DT79BK6',
#               'B006UMI2W0',
#               'B00467352I',
#               'B000SOT5V8',
#               'B009MBUZYO',
#               'B002XNHXOS',
#               'B000MC19YC',
#               'B001PICMWA',
#               'B009YBK2FO',
#               'B004EPXKKE',
#               'B006321J8G',
#               'B002QB1DE8',
#               'B000GX4CI2',
#               'B008MWKGH0',
#               'B003F77SM8',
#               'B003XFWS7M',
#               'B00462QSKE',
#               'B007M6G9XC',
#               'B007JCHAL4',
#               'B00B3L5BFE',
#               'B00AMQJSYG',
#               'B008QW0TF0',
#               'B00D3PHZXE',
#               'B00KMXNJPI',
#               'B000N90JPY',
#               'B005X5SHJS',
#               'B002LHP9HY',
#               'B001799PHM',
#               'B006BQV1R8',
#               'B005TH6H38',
#               'B0026SNTUW',
#               'B002EQB7IM',
#               'B004G91ZOG',
#               'B006IJ4A1M',
#               'B001PIKPGA',
#               'B00066XULO'],
#              150.8: ['B003FJJNFQ'],
#              6.37: ['B000CRB3V6', 'B003PB90U2'],
#              7.0: ['B000KJRRES',
#               'B000L1F2CO',
#               'B005THZGTY',
#               'B004IK82P8',
#               'B00304WW36'],
#              79.95: ['B00007E7IK',
#               'B001Z0OZGE',
#               'B001CE9N74',
#               'B007VEQ5I4',
#               'B000AO1G1I',
#               'B0034Z1EJO'],
#              14.97: ['B007ZF638G',
#               'B0026RI0BG',
#               'B002X6PTIC',
#               'B004Z9151K',
#               'B001E2GB0Q',
#               'B003O3RAIK',
#               'B0058DN8LW'],
#              199.99: ['B001EV5P1I',
#               'B002PY7PV6',
#               'B000ASB3QM',
#               'B0069JNY40',
#               'B000JQ23EQ',
#               'B007HCCUXO',
#               'B00076VPUQ',
#               'B0099UO83M',
#               'B008744KGQ',
#               'B000A8BU88'],
#              119.0: ['B003ABQ3IO', 'B002SG7EWG', 'B001RCUNDY', 'B00628S9OI'],
#              33.06: ['B0076MP1FO'],
#              12.53: ['B00F9EXXMO'],
#              69.2: ['B004AN11X8'],
#              36.59: ['B000O1EPWE'],
#              49.79: ['B004EPXK3Q'],
#              8.56: ['B000AXG5ZQ', 'B000225ODY'],
#              6.95: ['B000F7DT6A',
#               'B006U3X918',
#               'B000QHEG48',
#               'B002TENEAI',
#               'B000G1IKU0',
#               'B000FRVV4W',
#               'B003BLSDRC',
#               'B003BCQ2JM',
#               'B004R6M63C',
#               'B003XNA4AW'],
#              21.93: ['B00GUTQN4M'],
#              16.99: ['B00KO3E9A0',
#               'B000MS8NSQ',
#               'B008225FNA',
#               'B00H1HYZ9C',
#               'B000P69N5C',
#               'B002BH56CC',
#               'B004KAQH6M',
#               'B005C7SOJ0',
#               'B001F51AB2',
#               'B00IPBNOYA',
#               'B00194F1B4',
#               'B006OCQXMC',
#               'B002DPQ47S',
#               'B00AZRHJI4',
#               'B00482X8RI',
#               'B0033WTGQQ',
#               'B003IUIUF6',
#               'B006NI3F82',
#               'B001HOEITM',
#               'B003PGQHPI',
#               'B00149YZ5M',
#               'B00322QDAY',
#               'B007V4SAE6',
#               'B000RPMW04',
#               'B007V4RKMO',
#               'B008ESH7EW',
#               'B003UERF38',
#               'B004XVB5E2',
#               'B004W7QRF4',
#               'B000H7LYXI',
#               'B000QV0L98',
#               'B00275A4MA',
#               'B004Z241MC',
#               'B001O6SHD6',
#               'B004ULGRPW',
#               'B003XSEKHA',
#               'B00451BG2G',
#               'B007X51GS0',
#               'B0079LXVY0',
#               'B004NSU7JE',
#               'B00J2BTH48',
#               'B005VDWL8U',
#               'B005J9T5BW',
#               'B005G0FR48'],
#              13.64: ['B0026RI1RY'],
#              6.49: ['B00GGC7V6M',
#               'B0049I1MP6',
#               'B0049PKFUM',
#               'B000VP7JDU',
#               'B0063K70FE',
#               'B000W8C9QS',
#               'B003I8J4QC'],
#              14.47: ['B0037LUO32', 'B0000TQFQ4'],
#              74.99: ['B00AKFSJZ8',
#               'B0046EC0ZO',
#               'B002PF1SH2',
#               'B0002HA7T0',
#               'B00G3NBMHS',
#               'B0036G1TIW',
#               'B0069WPGFC',
#               'B004J72BH0',
#               'B000NPU138',
#               'B000EDOQU8',
#               'B0007MHD1K',
#               'B00B6EKJC8',
#               'B000SONSCA'],
#              99.25: ['B001ACOOX6', 'B001W8XMZE'],
#              27.99: ['B0051S8T36',
#               'B002KF05IU',
#               'B00FW49P0U',
#               'B00H90KZS6',
#               'B008N8FWK4',
#               'B00CNYHKA4',
#               'B002VNQEBI',
#               'B003R2GID6',
#               'B003YFHHMW',
#               'B00C7M7QN8',
#               'B009FR73CW',
#               'B0033RSAJ0',
#               'B001FH1XSK',
#               'B004AIRX26',
#               'B00DLWOCVC',
#               'B00D68H6MS',
#               'B003981MKC',
#               'B0019QZI0Q',
#               'B0093WFVW8',
#               'B00013KAJW',
#               'B000P55SN4',
#               'B003ODAIBQ',
#               'B00J94627S',
#               'B00A5GN6Q4'],
#              22.65: ['B0001WW2GC'],
#              42.14: ['B008BGKV04'],
#              112.94: ['B0015WJROW'],
#              15.79: ['B000P69NCA', 'B002HPNDCS'],
#              15.92: ['B000NJGF7K'],
#              84.96: ['B00D45ZRZQ'],
#              203.04: ['B001AMMDQG'],
#              71.34: ['B00006C7HJ'],
#              7.77: ['B005MJWMYQ'],
#              7.16: ['B000BQUNFA'],
#              99.99: ['B007HQ0LKY',
#               'B009G8J670',
#               'B005UES5WG',
#               'B000JXAYNQ',
#               'B00FZ4Q6ZY',
#               'B004RMGB0K',
#               'B000GWED7I',
#               'B004CRZXJU',
#               'B0006Z3UQU',
#               'B008R3EZQ2',
#               'B004X5M52O',
#               'B009TWIRSC',
#               'B0039LEC1A',
#               'B005GOZJOC',
#               'B000NPSHCA',
#               'B00KO0S0U8',
#               'B0016L679A',
#               'B002S4SW6K',
#               'B0010SKQK0',
#               'B005PJ0VIC',
#               'B004HW88W4'],
#              21.7: ['B0073CQ8OU'],
#              57.59: ['B005DMI8KE'],
#              33.62: ['B004CKVZ4E'],
#              35.0: ['B001JKQKOA',
#               'B007RKT7P0',
#               'B007OWTTAO',
#               'B00BPXILMK',
#               'B005SB1PQ4',
#               'B009FR7368',
#               'B008RRFLYI',
#               'B00BLPU68Y',
#               'B0042LMV0U',
#               'B002GFAAMU',
#               'B0007689WS',
#               'B008RJZP6K',
#               'B001IAM9PK',
#               'B00643MKDW',
#               'B003QCJXGQ',
#               'B0002EYIVQ'],
#              5.51: ['B000H6CDUW', 'B00464VY2O'],
#              21.73: ['B00A3BNDC8'],
#              22.58: ['B0039VYB98'],
#              139.01: ['B004JJO6F8'],
#              5.69: ['B003UPRJWE'],
#              3.5: ['B00007E7OH', 'B002OS7T1E', 'B000050HDN'],
#              18.95: ['B002SC323K',
#               'B0018SNEF6',
#               'B001NFZDNA',
#               'B00BLY8B0U',
#               'B000J3MAHO',
#               'B004CCPXA4',
#               'B009XHRAMM',
#               'B00C19SDL6',
#               'B004TMOIZI',
#               'B0089O0W1G',
#               'B002IFV3WE',
#               'B002V18IBY'],
#              57.77: ['B001SMIO8E'],
#              23.0: ['B001AVIGTU',
#               'B00066XUOQ',
#               'B002DBS9KM',
#               'B001F51A1W',
#               'B000KFSOOO'],
#              30.77: ['B003U2SRZU', 'B003U2SRYG'],
#              7.39: ['B0007W7QBC', 'B0018OD8EW'],
#              143.99: ['B000NPU1TM', 'B002YQ53KK', 'B001AEJYVG'],
#              10.49: ['B008TLQH5O',
#               'B005EMQVKW',
#               'B000EON2W0',
#               'B000PZU26C',
#               'B007REFDCC',
#               'B00166BUUG',
#               'B006P97SLY'],
#              94.5: ['B0002KNRTO'],
#              45.0: ['B001HX4JK6',
#               'B001C7NB38',
#               'B0081HHXO0',
#               'B008LZLMGC',
#               'B003TV4NVY',
#               'B00CLX58HY'],
#              34.04: ['B000QD3EDG'],
#              11.95: ['B006NP1SMK',
#               'B000JTFSVS',
#               'B004QYCSK6',
#               'B0007LJIC8',
#               'B00A80N626',
#               'B0037QGRMO',
#               'B00CJYS7X2',
#               'B0001OHHDS',
#               'B001HOMZ2E',
#               'B004QSLBSM'],
#              122.08: ['B003RWTNY2'],
#              20.88: ['B004BDP64W'],
#              49.99: ['B0007CXQRK',
#               'B007TTF28K',
#               'B00E46LOWY',
#               'B002YI0IVM',
#               'B00DOZTKH2',
#               'B004SIEHS6',
#               'B003Y9AJB4',
#               'B0000BVGP6',
#               'B006U24WV0',
#               'B001KQ7VNW',
#               'B004SZA2IS',
#               'B002PEX9MA',
#               'B0071QGKUU',
#               'B000XKGT5M',
#               'B000HIV0LS',
#               'B002D47XO2',
#               'B0070SC47C',
#               'B005Q0EB04',
#               'B001KQ7W1I',
#               'B001QLEFXA',
#               'B000NPTVES',
#               'B00149YZSY',
#               'B00AHLROUG',
#               'B0038MEANA',
#               'B003XNGPE6',
#               'B002TUU2GG',
#               'B0082QJ9SS',
#               'B000Y8UC2E',
#               'B00032XK34',
#               'B00DVZ2VYE',
#               'B00559EM1Y'],
#              80.03: ['B00545RX7E'],
#              45.26: ['B002KAOOXM'],
#              25.0: ['B004GXAIDG',
#               'B0026S1KJ4',
#               'B008R52OEA',
#               'B00EXS3LMO',
#               'B003V4A6YC',
#               'B001F4UMP8',
#               'B00D3GQNLI',
#               'B00DWFWI78',
#               'B00GLXVFY0',
#               'B00E4T7452',
#               'B00CTI1E5G',
#               'B0042FM9MG',
#               'B0093G0B4W',
#               'B00F3K51JM',
#               'B005UFGLEE',
#               'B00AX29KFG',
#               'B00596PF5K',
#               'B004LLHEE4'],
#              65.49: ['B001281F1C'],
#              30.44: ['B004360OPS'],
#              20.99: ['B000YKH0AE',
#               'B00CJ26A42',
#               'B0008DJVBI',
#               'B003VWDOCK',
#               'B008TLB8PI',
#               'B008SS75HW',
#               'B004W36V6I',
#               'B003JQJVE8',
#               'B002UBS52W',
#               'B006YW4U5E',
#               'B0048YNW3Q',
#               'B001J486N4',
#               'B003VWDOD4',
#               'B00CXUACKI',
#               'B002K64PBM',
#               'B000KLSZUQ',
#               'B003JQJSZU',
#               'B000FGCVZQ'],
#              4.65: ['B001RO1N0E', 'B000YHOQZ4', 'B003M8GMZ4', 'B004NA016G'],
#              39.41: ['B0009WG350'],
#              22.63: ['B004L9HYSM'],
#              70.0: ['B0000E2OAS'],
#              11.99: ['B0046JG8WA',
#               'B005HT0OV4',
#               'B003D0746W',
#               'B000B6JC9S',
#               'B00JTSEENS',
#               'B002H9W9X8',
#               'B00CHDHC3G',
#               'B000V201N8',
#               'B002V9194Y',
#               'B003VRPYKK',
#               'B009G7R5HO',
#               'B004ZXL0KM',
#               'B0058U0T62',
#               'B006RVWHI4',
#               'B00IPBNM4W',
#               'B0000TQERE',
#               'B00I1JKKCA',
#               'B0067HFQQS',
#               'B0033RBSNK',
#               'B001MA84I2',
#               'B001R5TTVI',
#               'B008VJI3Z6',
#               'B00B2FZEKS',
#               'B007IQSO6Q',
#               'B00GBPDROY',
#               'B000QSF8B2',
#               'B004WCO7TM',
#               'B00112DW38',
#               'B003UEREJ8'],
#              22.59: ['B00DMKZ3SY'],
#              3.67: ['B000HMC2L6'],
#              12.49: ['B000JX0AFS', 'B002TSBXA2', 'B001MA9PEY', 'B00H2C3NUS'],
#              37.5: ['B00020JM8E', 'B0002KNPFU'],
#              6.25: ['B004280ENY'],
#              14.99: ['B00IY0J536',
#               'B0024AKCTS',
#               'B00FP73Q9A',
#               'B000V9JW9A',
#               'B008TKLHAK',
#               'B000NOPLDE',
#               'B007JCHA6E',
#               'B009H56ZRQ',
#               'B001BVQJ7A',
#               'B001EHGT5S',
#               'B00JF0FGPU',
#               'B00BGJMD36',
#               'B009LI9O0E',
#               'B005D2U9N8',
#               'B000SQNSKK',
#               'B00FKKDYI0',
#               'B004EBUFOC',
#               'B00824AMSG',
#               'B0058V9KMK',
#               'B00AXUO3A0',
#               'B0089Y8YV6',
#               'B0022TRWRG',
#               'B005BX039Y',
#               'B004HZYHQM',
#               'B001LJQQQQ',
#               'B002ZVXWYI',
#               'B003UEREFW',
#               'B00CKXSA48',
#               'B00BBHW76Q',
#               'B003WUXJ5I',
#               'B0046JB136',
#               'B0044SFIHY',
#               'B0019ULZYU',
#               'B002M3C2I6',
#               'B00DEF8KCI',
#               'B00DY4S402',
#               'B00451BNZ6',
#               'B004KKX9N6',
#               'B009LPPH80',
#               'B002DD217M',
#               'B006YC5L16',
#               'B009FR73XG',
#               'B001ET6INY',
#               'B003H2LZQ6',
#               'B004ZLAG54',
#               'B004LF8TSA',
#               'B008YKX75I',
#               'B00ACHLEBA',
#               'B000PAO5SS',
#               'B00AOB4MY0',
#               'B002UNLPZ4',
#               'B000FEDCNI',
#               'B000QGRY3Y',
#               'B0084XKRMG',
#               'B0067HFRV2',
#               'B001LU14KS',
#               'B0046JE9Z8',
#               'B001PQL52A',
#               'B003C1OL04',
#               'B004IW228O',
#               'B004EBUFOM',
#               'B001IWMNLS',
#               'B002J9HMT2',
#               'B009H4JLCS',
#               'B000KI31OY',
#               'B002M3XS98',
#               'B0037HQ1O2'],
#              199.0: ['B0009RSWM2', 'B000HS28AK'],
#              8.99: ['B002HMBVKM',
#               'B002DPMFLM',
#               'B001F51AMQ',
#               'B005EVJOIY',
#               'B004ZZKKD8',
#               'B009UWIY98',
#               'B000WVVJKC',
#               'B000227M3Y',
#               'B000095ZGF',
#               'B00BQLXWUM',
#               'B008SBPDQ4',
#               'B0083VW3X0',
#               'B002AHA18M',
#               'B002UBS2OS',
#               'B00307UU14',
#               'B00BLWEXKE',
#               'B00DPLVB4K',
#               'B009UWI78Q',
#               'B007Y4FR08',
#               'B0039A58HI',
#               'B0084Y0GO4',
#               'B000793236',
#               'B003L8OABS',
#               'B004MPRVME',
#               'B003BWD14G',
#               'B0026K09IK',
#               'B008BNIYVU',
#               'B000XAW2G2',
#               'B009UWEL9U',
#               'B00BM8KC3E',
#               'B00BSXS9NI',
#               'B007Y4FMIA',
#               'B000L1H7SG',
#               'B002K85UJQ',
#               'B000L1F2GU',
#               'B003V4A732',
#               'B009UWG7C4',
#               'B006L882NM'],
#              112.76: ['B002PY7PTI'],
#              18.86: ['B007JW4ETA'],
#              13.95: ['B00GNJUI18',
#               'B00B2A40P8',
#               'B000PSSVQW',
#               'B001D0TP84',
#               'B005DVCCJS',
#               'B0001VQIJU',
#               'B00DH2H5KG',
#               'B000F7DT5G',
#               'B002WRI6SM',
#               'B0041NFHVE',
#               'B002AQLYZW',
#               'B008ROE9OO',
#               'B000F7DT4M',
#               'B000BU7TSA'],
#              12.46: ['B007Y2SITW', 'B007EIJ25A', 'B000IF6SFI'],
#              47.0: ['B000SOYK72', 'B00005CETP'],
#              10.09: ['B0000X11R8', 'B0010XX7ZQ'],
#              15.99: ['B00BLPU8A0',
#               'B005VGIY6K',
#               'B0000TQEZ6',
#               'B002JM0RNC',
#               'B003I5J1MM',
#               'B0046JB1QI',
#               'B000LPEZU0',
#               'B0035Z9CYM',
#               'B00524UTKK',
#               'B0046JCCJI',
#               'B005GSR1BM',
#               'B0000CF517',
#               'B00BPD0V82',
#               'B008CPHHQK',
#               'B001EMS16S',
#               'B005VQ5HNS',
#               'B002V91A34',
#               'B0062Q8I3W',
#               'B00EIIFHGW',
#               'B009SZ2P7E',
#               'B0017L33IW',
#               'B000L1KN4G',
#               'B000MGGG0A',
#               'B000JKERWI',
#               'B006LIW9OU',
#               'B002LWPDTI',
#               'B000T8BMD2',
#               'B004GXAIGI',
#               'B004GXAJ2G'],
#              538.99: ['B00015EEQA'],
#              6.97: ['B005FL8BJG', 'B000KCJR48', 'B001I0AZN8', 'B005D6PYPM'],
#              46.99: ['B00GP4RBCU',
#               'B004VLVUVC',
#               'B002BA5F2A',
#               'B00EINBSEW',
#               'B004L9LXAC',
#               'B0088QW858'],
#              3.99: ['B00EU6HBDY',
#               'B000CCBEKG',
#               'B000VP9GDQ',
#               'B002NZPFZU',
#               'B000H6DO9G',
#               'B0010XUJZ2',
#               'B0007WQ4AQ',
#               'B003COGL7M',
#               'B005IGNGQG',
#               'B00002N636',
#               'B009ES4ZKU',
#               'B004IJGJW2',
#               'B000H0G85Y',
#               'B003WRBL56',
#               'B0088YRUKI'],
#              120.18: ['B003ADCHWS'],
#              10.99: ['B009GMOUGS',
#               'B000OAGD0C',
#               'B005EQIT08',
#               'B000URC36W',
#               'B0016PQ9Y4',
#               'B000Q6I7LM',
#               'B003J372OW',
#               'B004IR9VDS',
#               'B00F2LDJMI',
#               'B007B8RKIE',
#               'B005OQ10JA',
#               'B00EDSEHZ4',
#               'B002V919SA',
#               'B005MQXGPS',
#               'B00GBH0GF0',
#               'B005M4BFE4',
#               'B00DY0CSR6',
#               'B006Y79VWG',
#               'B0067HFSES',
#               'B009TDIAPG',
#               'B007Y4FMQW',
#               'B00013KAG0',
#               'B000S6M4KA',
#               'B00CAYRM7S',
#               'B002R0DR3I',
#               'B0049U8H52',
#               'B009ES5590',
#               'B008TLCX66',
#               'B009YZQ7TK',
#               'B003XAMI72',
#               'B004WPJP2S',
#               'B002P4OS66',
#               'B004FRZ7PC',
#               'B00028I1M4',
#               'B002IC1D40',
#               'B007Y2TEYA',
#               'B0067HFS1Q'],
#              34.95: ['B00408LLDS',
#               'B00BHUGWTK',
#               'B0002KNQ9A',
#               'B009VWPJEK',
#               'B003PWK2A8',
#               'B002JY7M4M',
#               'B002P4LY6I',
#               'B0017VSZWQ',
#               'B00IEOV4WW'],
#              28.26: ['B004VD4Z58'],
#              14.44: ['B000N9GZX4', 'B008KQ1BKO'],
#              39.99: ['B00C1EIXCU',
#               'B003M66486',
#               'B00FN9KBVQ',
#               'B0053O1PY8',
#               'B004982ZBG',
#               'B0067VJPH0',
#               'B0054PSX46',
#               'B0083NAPOC',
#               'B004ZIDXK2',
#               'B0007IS782',
#               'B00AGIES86',
#               'B0066YV22O',
#               'B005TOVUBA',
#               'B001F8L4OC',
#               'B0060BSQJK',
#               'B0026II1IW',
#               'B0031M9HIK',
#               'B0040GQXQK',
#               'B002JY7M38',
#               'B003981NO2',
#               'B0083ONH1Y',
#               'B0032CYG62',
#               'B004N80WV2',
#               'B0049AEIBO',
#               'B00EHP7OW6',
#               'B00BL6UE76',
#               'B003VP22PC',
#               'B003RRWRNG',
#               'B003IVU03K',
#               'B0040P5C9K',
#               'B004OSJ6SG',
#               'B000Y3NB68',
#               'B003WE91UG',
#               'B00ALRSXV0',
#               'B005TOXIYM',
#               'B007IUJZYM',
#               'B007CMYCHG',
#               'B004BDP67E',
#               'B00CAX9U4M',
#               'B00A26VJW0',
#               'B00632J7GW',
#               'B000UZPE10',
#               'B008MQ962W',
#               'B00B57Z4QW',
#               'B00IKNE5P0',
#               'B004EPXK5E'],
#              26.99: ['B001688C1O',
#               'B00DRK2YD6',
#               'B0052W0XEY',
#               'B001EWE9AK',
#               'B000TCVUA8',
#               'B008EXODVM',
#               'B009R64BDU',
#               'B00AT306ZM',
#               'B004GXAJ08',
#               'B008BNJ28E',
#               'B002ECXUOA',
#               'B008NB91GW',
#               'B000SONT8S',
#               'B004P1I6K6',
#               'B00AQ0NYFC',
#               'B007JCHAGY',
#               'B001T4ZBFK',
#               'B003E6IOAU',
#               'B008R4GPGE',
#               'B004G7PLHA'],
#              75.0: ['B003VQNM2I',
#               'B008BQO9Y8',
#               'B0073Z8WZA',
#               'B00B31RW4C',
#               'B0073ZFQZO',
#               'B006SD3E3S',
#               'B006SDCV6E'],
#              92.0: ['B000AU7KU8'],
#              8.96: ['B0041XXKAY'],
#              4.99: ['B000VPCD54',
#               'B001PZD63M',
#               'B001QD40R4',
#               'B002SZNXBI',
#               'B005C7STJ0',
#               'B001AXDC7E',
#               'B004L9L8QG',
#               'B008SOZZSC',
#               'B00E1XZSOK',
#               'B00004OCIZ',
#               'B000H6AEPS',
#               'B00B49Q2IA',
#               'B00004OCL2',
#               'B000WPCINA',
#               'B000I1X45O',
#               'B000KKTWDG',
#               'B003US4L4K',
#               'B000MIREPO',
#               'B00AA67WP0',
#               'B0014CRBSM'],
#              91.99: ['B000CN538O', 'B00GNJZT7Q'],
#              4.68: ['B001DTD7HK'],
#              89.99: ['B000KQ4T92',
#               'B000MI3HJQ',
#               'B0060OJ2DG',
#               'B006O0S0Q6',
#               'B002EQAYMW',
#               'B00F655P1S',
#               'B000ZQ6I96',
#               'B006O0S2SC',
#               'B0087P36VK',
#               'B004QIH7X0',
#               'B000NPOO6S',
#               'B0012AN2R0',
#               'B003ZE63HM',
#               'B001OVFRNY',
#               'B00E6HAHYW',
#               'B003UI6NEG'],
#              54.2: ['B001TZLAZE'],
#              27.98: ['B004RIFMXQ',
#               'B009T1ISP0',
#               'B0037QGRQ0',
#               'B0037NX61W',
#               'B000KDS4XC'],
#              7.45: ['B001YHTWFC', 'B002EVOAKE', 'B000BU7TSU'],
#              61.68: ['B00B2QJUPM'],
#              24.95: ['B000F7FXF0',
#               'B00CG4IX52',
#               'B007IMB8S6',
#               'B004BAPK0K',
#               'B00GEFSCIM',
#               'B003U4UNBY',
#               'B007MI23L2',
#               'B000PSPZ3E',
#               'B000BASTC0',
#               'B003UQ5C8Q',
#               'B001MVN9XG',
#               'B000ZKE0OC',
#               'B008SEXZ70',
#               'B001QTVXFK',
#               'B000BGPVAW',
#               'B002FJ5PW2',
#               'B004TGVH0S',
#               'B000RYKQ3U'],
#              69.99: ['B002FQJW4W',
#               'B0016G5VDS',
#               'B0031TUYS0',
#               'B000ZIVN9O',
#               'B000GWFHSW',
#               'B005DI5VUI',
#               'B001HBOK3Y',
#               'B000FHEUWC',
#               'B000VZHIW2',
#               'B000O5N6CU',
#               'B0088RN8GK',
#               'B002QG84HC',
#               'B0036WSA56',
#               'B004IYK1YY',
#               'B0032UOY8E',
#               'B005PFS43K',
#               'B005P5XTEY',
#               'B000VM6NEY',
#               'B00B6EKM70',
#               'B008O8FV2C',
#               'B000A8BU0G',
#               'B0049DJUHS',
#               'B0002DSVR4',
#               'B0059HGZU8',
#               'B0006HUE94',
#               'B0007LJO5Y',
#               'B00575T0KO',
#               'B00E6H9PQI',
#               'B0069U7198',
#               'B00A2CRX2E'],
#              10.87: ['B00012FFRU', 'B0009I3EYM', 'B008UOXJIS'],
#              102.99: ['B0088AHKJ8'],
#              11.64: ['B002MHHOSK'],
#              28.0: ['B0054G88HC', 'B005D51BOQ', 'B00DJ7MW6Q'],
#              79.99: ['B003OBY5EY',
#               'B001F5ST84',
#               'B004YB2HD4',
#               'B00BUETFTC',
#               'B0058V9GSI',
#               'B003RWTMNO',
#               'B0055DKP7K',
#               'B0019IULMY',
#               'B002YD8DZ0',
#               'B0002XD08Y',
#               'B0009U5NN0',
#               'B0049XCXHC',
#               'B007J2PAYI',
#               'B000BGZZ62',
#               'B001I3V4NA',
#               'B000COCECG',
#               'B00E0UEK6Q',
#               'B007A57IUI',
#               'B0058SOREO',
#               'B002C55KYC'],
#              33.49: ['B008POTJV4', 'B008EX63ME'],
#              4.59: ['B003WRAGQG'],
#              18.26: ['B005C7STKO', 'B002OJ7U0I'],
#              5.37: ['B0045OSHMK'],
#              23.87: ['B002AMW356'],
#              17.99: ['B000HNHPI0',
#               'B001B11ZV0',
#               'B009SRAVGE',
#               'B000VIS3C8',
#               'B0000CF7FZ',
#               'B000QCI3J2',
#               'B00HPRPAG0',
#               'B005GSS6YI',
#               'B000B1V2AU',
#               'B0052WG0EG',
#               'B004CCPXAO',
#               'B000M9NMJA',
#               'B00JEL09BG',
#               'B006XL1FN6',
#               'B002SCLFNE',
#               'B000G62YE8',
#               'B00066XUP0',
#               'B003E1U7Q4',
#               'B002OJHRCO',
#               'B00J2DLCVW',
#               'B005K6SQRS',
#               'B001G9CN9A',
#               'B00BFRDUS6',
#               'B008U4SGYA',
#               'B003I5J186',
#               'B003BWS9G6',
#               'B00310P99S',
#               'B008YYW9JO',
#               'B00AQ0OK2I',
#               'B007TKPVE4'],
#              9.97: ['B00114ZTBO',
#               'B00DSP9IN4',
#               'B000JD4CC0',
#               'B000KPUFZU',
#               'B004XK7KP6',
#               'B004BDP656',
#               'B0017TOHHU'],
#              18.88: ['B000VYHAQW'],
#              47.55: ['B007RVWQ98'],
#              159.99: ['B00F7MMPCW',
#               'B008I3WU22',
#               'B00FX89IY8',
#               'B003KKHC6C',
#               'B0049XCWIW',
#               'B0040QDYAI'],
#              23.99: ['B000LRBPAG',
#               'B00FK3VRCC',
#               'B002S0NJMQ',
#               'B000ROI2SG',
#               'B0052TGRJW',
#               'B007TSJLCE',
#               'B00GURDXOM',
#               'B003M8GMY0',
#               'B005H1FPW0',
#               'B004LDWP32',
#               'B005EVJNZ8',
#               'B001I18TLM',
#               'B006RHLH52',
#               'B003QA2MAC',
#               'B001330GNY',
#               'B0041EJX86',
#               'B0001Z8SB2',
#               'B002Q3Z22U',
#               'B003VVQ112',
#               'B00AWN4STO',
#               'B0026RI0CA'],
#              139.99: ['B003N5E2KI', 'B002S56JGE', 'B0099X6UVW'],
#              14.57: ['B001IDYHLQ', 'B0014XOHJC', 'B00A1WH9M4'],
#              34.14: ['B002P4PS3S'],
#              8.71: ['B003UHRVEI'],
#              14.48: ['B003O3I8IG'],
#              149.0: ['B00681IB8I',
#               'B006SCXGH8',
#               'B006SDG21O',
#               'B0073Z0LK4',
#               'B00740OWMG',
#               'B006SDFOM2',
#               'B006SDGHPU',
#               'B006SDJVCQ',
#               'B00681G60I',
#               'B00681JHUE',
#               'B006SD0SPA',
#               'B006SDGWQE',
#               'B006SDKHQA',
#               'B00681ED0I',
#               'B000TDKXA0',
#               'B006SDJ9H8',
#               'B006SDVA0W',
#               'B006SRV756',
#               'B006SDRY8Y',
#               'B006SD4AMW',
#               'B006SCHWTQ',
#               'B0073ZQGG2',
#               'B0063ZYPMU',
#               'B006SDT8MY',
#               'B006SDDKSM',
#               'B0069EQPIM',
#               'B006SRT7JO',
#               'B006SDX7VM'],
#              10.84: ['B003TMDE7M'],
#              429.99: ['B0099X78MC'],
#              17.8: ['B000RH7450', 'B005PLPH2K', 'B0083VHJ2U'],
#              15.0: ['B00313JQ8K',
#               'B004L5L2XE',
#               'B00066XUJQ',
#               'B004BN5OMG',
#               'B000JIOVFS',
#               'B0038RJE2M',
#               'B0061JQPBW',
#               'B00424KYRO',
#               'B0039ZH9CK',
#               'B007Q7SLYM',
#               'B009N83O1C',
#               'B0000TQENI',
#               'B000UO4KXY',
#               'B003UERFQ0'],
#              19.05: ['B004WT6Z54'],
#              56.42: ['B0012AL2A4'],
#              19.99: ['B0002O9HLC',
#               'B0051T94X4',
#               'B0079Q37MG',
#               'B005C7SPLC',
#               'B009GPU3CU',
#               'B000MF2RQI',
#               'B003PGQ1WM',
#               'B003FGWBL2',
#               'B0051S94NA',
#               'B003M8GMUO',
#               'B002AEOY42',
#               'B0037NX61M',
#               'B0078R3MQC',
#               'B0039RH4UK',
#               'B008HO60F0',
#               'B00CF30SRA',
#               'B0012OMHJA',
#               'B000I1UU56',
#               'B003FMVO46',
#               'B00451BG0S',
#               'B008KK7XES',
#               'B002H9X6TE',
#               'B0002RVMBC',
#               'B000U8456C',
#               'B00243GXHA',
#               'B000BIYQ4M',
#               'B004362I66',
#               'B000JLKOBK',
#               'B000MM7DEW',
#               'B00D8DXN50',
#               'B004AQLUHC',
#               'B008MWJWH0',
#               'B00BW5WU82',
#               'B00CWD3N5W',
#               'B00BED355E',
#               'B001IWMNFY',
#               'B004BOOWWS',
#               'B001D4AJL2',
#               'B002GP7TUQ',
#               'B00451BNPG',
#               'B0054PSXKK',
#               'B003M8GMYA',
#               'B001U8A06K',
#               'B00FKKGLDA',
#               'B00IPBNS4Q',
#               'B009A3HTXY',
#               'B002OL1HTQ',
#               'B004V7G1T2',
#               'B005K038KY',
#               'B005TOX9YQ',
#               'B005TP48IG',
#               'B00AR0BQ7E',
#               'B007JCHAGE',
#               'B004U99JJ0',
#               'B008HNFWZU',
#               'B00406U802',
#               'B0035Z5H96',
#               'B00CQ66PQY',
#               'B0056EPUQY',
#               'B001DEK82M',
#               'B000PI636W',
#               'B00CJDIF2Q',
#               'B0093G08Y0',
#               'B000RH6SBG',
#               'B009NF4UVS',
#               'B00DB51C9E',
#               'B0025VKLAQ',
#               'B000LRGNBC',
#               'B0083IZN2G',
#               'B002JLWYR0',
#               'B0033506JO',
#               'B002M39YZK',
#               'B008H2AA9E',
#               'B0053OQMSC',
#               'B004EPXKLS',
#               'B005XZG2FO',
#               'B003M8GMTA',
#               'B007SY8N6O',
#               'B0052WJ05M',
#               'B0067HJI3U',
#               'B0044F60M4',
#               'B008K2M4K4',
#               'B003M8GMYU',
#               'B005VQ5J04'],
#              7.1: ['B0079OBIQ0', 'B003DMMKR8'],
#              7.09: ['B0083ONY30'],
#              6.9: ['B000QUJ5N2', 'B0000V6Z12', 'B009LZZRDU'],
#              22.0: ['B0045OW4Q0',
#               'B002BNKO7S',
#               'B003VRRYDU',
#               'B002H9XA0Y',
#               'B00KCKJOT6',
#               'B004CEQ0QI',
#               'B00CDH6IJU'],
#              44.99: ['B007P9JGMM',
#               'B005TP7BFI',
#               'B00149YZZW',
#               'B00B4EXKKS',
#               'B006S3Y4A0',
#               'B00008URR8',
#               'B00102TRFG',
#               'B0049CNC5A',
#               'B00GZ6OI8S',
#               'B0040808PU',
#               'B002WEWLJU',
#               'B002PX9TXY',
#               'B0063MX3A8',
#               'B0071QLO2O',
#               'B008BM9PN2',
#               'B0018B0WEY'],
#              14.95: ['B0089E2WCI',
#               'B00597YTNI',
#               'B005FYB7Y4',
#               'B002P4BCT2',
#               'B001MWSQ1U',
#               'B004C37VS0',
#               'B005F5MC2Y',
#               'B002OL1HLE',
#               'B000E8O5U4',
#               'B0089MD85A',
#               'B000B7PNGS',
#               'B00AINBQRK',
#               'B00HO2U5Z2',
#               'B0047VL8PE'],
#              9.95: ['B000I1UXNA',
#               'B0077ATMAU',
#               'B002NWFS6Y',
#               'B004JKMSJS',
#               'B002BDUDRE',
#               'B0000CFPWJ',
#               'B008YQ4UGW',
#               'B000PSTGS4',
#               'B00G3BS6LK',
#               'B002C0ITRM',
#               'B003XO6LLM',
#               'B000BUDDTY',
#               'B0000CFROE',
#               'B009JUUP70',
#               'B00A8KBVXW',
#               'B002V91A3E',
#               'B0006V875S'],
#              11.54: ['B001CLRHZ2'],
#              20.49: ['B0007IS7A0', 'B004FJPY58', 'B002NGN9PW', 'B00A92ZRLG'],
#              66.89: ['B004CVKVJ8'],
#              13.99: ['B00ESIVBT4',
#               'B003FMVOB4',
#               'B00012FFPW',
#               'B004H3G63G',
#               'B00CS770HE',
#               'B0082XTQIY',
#               'B00FGCT328',
#               'B008KSGV9I',
#               'B0009VCB5M',
#               'B003UES046',
#               'B003LJY990',
#               'B004GXAIHW',
#               'B003UES0CI',
#               'B003XNIC4C',
#               'B004WGTB2G',
#               'B007U1I1US',
#               'B000WLZN4U',
#               'B002HRLOPE',
#               'B004Z8JAPY',
#               'B003LVY8C6',
#               'B00IES4Z4W',
#               'B002GEYZZY',
#               'B001F51ADA',
#               'B008225FBW',
#               'B002H9XB58',
#               'B0063KCWPM',
#               'B00BLWEWKA',
#               'B0026O1U7U',
#               'B00005V9E3'],
#              20.46: ['B00DML8OHU'],
#              15.13: ['B001F51ABC'],
#              94.99: ['B00ENRBD8O', 'B00474XBH4', 'B002S4Y8YU', 'B00F2EVSIC'],
#              27.5: ['B002IOEFXO'],
#              11.75: ['B004UXVMYQ'],
#              42.99: ['B001VXTU0G',
#               'B0084RXWLA',
#               'B004TNX08S',
#               'B0044GEW78',
#               'B003NXHKFY',
#               'B00428MOI2',
#               'B003TYJUA0',
#               'B002PCS0O4',
#               'B001IDYHOI'],
#              3.58: ['B000F7HW5E', 'B003SRH6FE', 'B004F3MQIM'],
#              7.85: ['B0007S5N8O',
#               'B000LNV09G',
#               'B00078ZJPG',
#               'B003W7AEOK',
#               'B001QVH0LO'],
#              23.52: ['B000VU9T74'],
#              14.8: ['B000YMTSMK', 'B000ZA47HM', 'B001037LGC'],
#              86.62: ['B003G2ZWFW'],
#              59.95: ['B000MF26ZU', 'B004NRP2SQ', 'B00FBMJJW2', 'B004RC3IR4'],
#              7.58: ['B004BC6V2E'],
#              138.9: ['B0045H3DEO'],
#              4.95: ['B003KQBLZE', 'B00008URRK', 'B002LGWKKO', 'B002BWUJ1U'],
#              8.9: ['B002V919Y4', 'B00AZW4WU2', 'B004HF777I'],
#              8.7: ['B0000YZJBQ', 'B0073TCIF6', 'B0029DDJEK'],
#              189.99: ['B0000BVOTQ',
#               'B00D3ZTBA4',
#               'B000SOM6GO',
#               'B0071HBVYE',
#               'B004QP9JVG'],
#              11.24: ['B006BY1AEY', 'B0056NY1M4', 'B003MNF5XE'],
#              141.95: ['B0064CT1WG'],
#              24.63: ['B004ZVN75U'],
#              53.98: ['B003V71PE4'],
#              135.99: ['B002S7H920'],
#              60.0: ['B000RL1WNQ',
#               'B005EQIWGE',
#               'B0039OCS2C',
#               'B002BA5F4I',
#               'B00AXT5H4M'],
#              11.45: ['B003J372PG'],
#              4.27: ['B001NG8BEM', 'B000HJ78ZY', 'B001UDH3RE', 'B005QDOB9C'],
#              6.55: ['B002LL4UQQ', 'B001F51AP8', 'B009ES66SE', 'B001KKYN2U'],
#              21.38: ['B001AX0QCS'],
#              29.9: ['B002ITMWHK', 'B0037KMSQE', 'B0037KMSRI'],
#              171.0: ['B001EQOLQI'],
#              24.99: ['B004GXAKR0',
#               'B000VNGWZS',
#               'B002S531V0',
#               'B001F51ADK',
#               'B004AE2IZM',
#               'B005VQ5EX6',
#               'B003FSSXYY',
#               'B000FGE5K0',
#               'B004LCF8DW',
#               'B003VL03YI',
#               'B003OBY5GW',
#               'B005CVXSOM',
#               'B000RGXNM4',
#               'B008N1X8IO',
#               'B0053O1O6W',
#               'B002L0WMNU',
#               'B00CUE7GFG',
#               'B001CRE4KM',
#               'B004TMMV2A',
#               'B00E9BOAKM',
#               'B000UZVBAI',
#               'B007XX5ZQ6',
#               'B005380KRM',
#               'B00B8I23XA',
#               'B004FPZWHW',
#               'B00932UTXE',
#               'B00381TBLC',
#               'B001K3YLBK',
#               'B00A3BYE4Y',
#               'B003YFHHAO',
#               'B008R12MTQ',
#               'B007P1HNXY',
#               'B0006GQ9VW',
#               'B00271TIH6',
#               'B00D2ZWM9M',
#               'B00DV4TSYQ',
#               'B000PQXIOO',
#               'B00BUIW82E',
#               'B00DELY41S',
#               'B009HVZU0I',
#               'B007N6I236',
#               'B00AQ0O49W',
#               'B00EO42WOU',
#               'B008N1YB3U',
#               'B0002XP8QQ',
#               'B000WQ6RBS',
#               'B0002O9HZ8',
#               'B002NGN9NY',
#               'B008MA16QC',
#               'B008S1KU9E',
#               'B0006HVVFK',
#               'B008CQY4RE',
#               'B000ZOHLYE',
#               'B0039JWJZI',
#               'B00DRI8BPS',
#               'B00629WC3Q',
#               'B006MON3XE',
#               'B0088BSPY6',
#               'B0040QVFCM',
#               'B008N1W5BA',
#               'B00GISGGH4',
#               'B00C6AHU82'],
#              33.29: ['B000FGCW00'],
#              16.65: ['B004GXAJ2Q', 'B000HMBWWQ'],
#              45.05: ['B005KPMBI4'],
#              66.48: ['B004YL2EDW', 'B003RWTMMU'],
#              22.6: ['B0029UCW5K'],
#              7.19: ['B007H4D6Q2'],
#              29.5: ['B002DQMVQ0', 'B0000X60LK', 'B005JCS4TS'],
#              7.48: ['B000W3ODZI', 'B006V32PNU'],
#              25.48: ['B005QLJL26'],
#              37.95: ['B00IHPX9DK',
#               'B0014B7TNU',
#               'B000HGFHP0',
#               'B0075O897A',
#               'B007MI2L1Y',
#               'B0043RXN3C'],
#              68.89: ['B000NPTYJA'],
#              24.0: ['B00BIYPEEO',
#               'B00DW3DGGM',
#               'B00139YGKM',
#               'B0083E8GXS',
#               'B00ATMLHZ6',
#               'B005HQ3R5C',
#               'B00AV4NS8Q',
#               'B000EWHLBA',
#               'B004FJOEMC'],
#              12.25: ['B005YNSRYY'],
#              127.7: ['B0026RH2X8'],
#              59.97: ['B009U1Q3UG'],
#              18.97: ['B00DDRDPS6',
#               'B0000ZKW6M',
#               'B003ATL7UA',
#               'B002JLRC2M',
#               'B003FGWB44'],
#              32.0: ['B000NQ95H0', 'B008F0DQLM', 'B0096JEBXI'],
#              23.3: ['B000ANKHBE', 'B0020Z7RHC'],
#              11.23: ['B003XHD4QO'],
#              85.0: ['B000SVKACE', 'B0014GM1J2', 'B004JLO3Z4'],
#              17.13: ['B001Y8QY5C', 'B001BCDIDW'],
#              6.82: ['B004WELHLG'],
#              34.78: ['B003981O32'],
#              239.0: ['B00CP53DCA'],
#              129.99: ['B001C8FL5S',
#               'B00IU1A0YW',
#               'B00FX0QL96',
#               'B0031M9HIA',
#               'B000NPQKUG',
#               'B002USUK3M',
#               'B005B7ZCVE',
#               'B003J371E8',
#               'B005QPBNVE',
#               'B000ZK2M4W',
#               'B0013LNKIY',
#               'B0049Y6A4S'],
#              30.96: ['B000H6NT32'],
#              54.99: ['B009CNHF68',
#               'B004EB94KI',
#               'B00405OA0M',
#               'B0040HE74Y',
#               'B005TOVVSC',
#               'B0071QNVKM',
#               'B002AQFM64',
#               'B0013TQ1H8',
#               'B000NTZYIQ',
#               'B005TOVZSS',
#               'B00A4NOQJO'],
#              65.29: ['B002EQAYM2'],
#              33.84: ['B000K3GK4M'],
#              133.93: ['B001MS6QNO'],
#              23.94: ['B003HEPHUE'],
#              30.61: ['B007ELALZC'],
#              129.0: ['B000NNGGG6',
#               'B00B7FM8I4',
#               'B005NRVO50',
#               'B00FZ3MFAA',
#               'B000Q8T2F0',
#               'B000NNT26C',
#               'B006S8N2PS'],
#              84.99: ['B0009NZQRU',
#               'B003QCJHGC',
#               'B00382SMVG',
#               'B002VECNSU',
#               'B004WT6ZEK',
#               'B00B6EKNYW',
#               'B008FJY6G2',
#               'B000VBRX26',
#               'B00AYCJUI2',
#               'B00GZ5BSBY',
#               'B008R3F0J8'],
#              10.95: ['B003URS28C',
#               'B008GODWZ2',
#               'B002BDUCWA',
#               'B007V6CH0C',
#               'B00BOS9CQU',
#               'B00772HUR0',
#               'B001928WRG',
#               'B003OYJ226',
#               'B009JOYNBA',
#               'B007V2L1BM',
#               'B006Y54QEQ'],
#              24.03: ['B007Y4FM6M'],
#              65.0: ['B004O6XC5Q',
#               'B00070ENH4',
#               'B000TDJ4DW',
#               'B004107WB0',
#               'B003G2ZWDE',
#               'B004SOQGVQ',
#               'B0044QKQQ4',
#               'B0087W31YK'],
#              3.42: ['B00B5ELNQK'],
#              8.65: ['B0000ZLB7G', 'B002CG39RG', 'B0000CFNAZ'],
#              80.0: ['B00155UWBG'],
#              30.99: ['B005TP51UK',
#               'B003UES2M6',
#               'B00406U7WQ',
#               'B003YFHHF4',
#               'B000TSWEDY',
#               'B003NTPTLA'],
#              53.16: ['B00F3YLN2W', 'B004BR1B60'],
#              47.99: ['B0085J6S0Y',
#               'B000JI1ORG',
#               'B005TPNIW8',
#               'B004PEIZDQ',
#               'B00E34YKCS'],
#              12.36: ['B001CF18IA'],
#              43.5: ['B000QSMZOA', 'B00A2WO9NU', 'B001QD5T4W'],
#              899.0: ['B003M1C7XW'],
#              5.45: ['B000H0SEP6'],
#              28.95: ['B004SIEPXI'],
#              17.37: ['B003ZYLP2K'],
#              39.0: ['B0017SXXIU', 'B00A7BU2M8'],
#              14.9: ['B000LNQF82',
#               'B0039GQYM0',
#               'B0002V37L6',
# ...
#              23.64: ['B0007X9FQK'],
#              16.21: ['B004TB9NFE'],
#              31.13: ['B002H9WKI2', 'B001F51A62'],
#              286.3: ['B00CYLYKJA'],
#              31.77: ['B0086KQR3U'],
#              29.04: ['B0010Z7S5O'],
#              49.0: ['B0092OT164'],
#              59.16: ['B007A2J36I'],
#              12.65: ['B000KIJN7S', 'B000R9XLU0'],
#              12.73: ['B004EPXK1S', 'B00007E7XY', 'B002LIZUQI', 'B0019TR8M4'],
#              52.95: ['B001L1R0SM'],
#              214.05: ['B002TSAEAC', 'B000V1V926'],
#              249.99: ['B00CHHDGI2', 'B0017373AO'],
#              49.72: ['B001EWEV1M'],
#              159.03: ['B0018SNJ38'],
#              23.56: ['B004Q03UAC', 'B001ECHPRE'],
#              56.68: ['B002OQCS1M'],
#              8.68: ['B0068R9D6Q'],
#              124.99: ['B007PTGIL4', 'B002WI6LB0'],
#              73.99: ['B001RCUN6G', 'B000G0OJ9C', 'B002TZF4GO'],
#              51.0: ['B002WGJHAO', 'B00FFJBTMY', 'B005G6TIQU'],
#              5.62: ['B000ON9HQ6'],
#              89.29: ['B0014QS1XC'],
#              16.98: ['B001SO53EK', 'B001J9U0AQ', 'B001FDZ48O'],
#              46.39: ['B009MQ3CX0'],
#              142.92: ['B0033YNW14'],
#              18.0: ['B0000TQHTY',
#               'B002C0CBVW',
#               'B004ZTAUWK',
#               'B001BV9MCY',
#               'B000BL50C6',
#               'B0009L8GI8',
#               'B002M3SP3W',
#               'B001D6K0BE',
#               'B002TSC3WE',
#               'B004AE2AZU'],
#              66.99: ['B003RWTN06', 'B002BA5F3O', 'B000O1CNX2'],
#              82.0: ['B001U88652'],
#              7.94: ['B0000CF5GX', 'B00A8MDPSO'],
#              68.0: ['B006MIPW70', 'B00847I7E2'],
#              179.39: ['B00843Z8LQ'],
#              6.19: ['B0085T88NY'],
#              11.09: ['B002C4UN4U', 'B000LNVXIY'],
#              11.9: ['B00810RDL0'],
#              16.13: ['B004P9J8XC'],
#              39.52: ['B009CNHF7C'],
#              98.29: ['B00BWC1UDG'],
#              67.51: ['B005132AT0'],
#              43.0: ['B003L117MK', 'B0063M45SM'],
#              1.86: ['B0032Z4V00'],
#              142.59: ['B001GJKHUW'],
#              7.34: ['B001005HQQ'],
#              5.16: ['B001308OGI', 'B000HJ99RO'],
#              283.04: ['B000X0A02A'],
#              32.56: ['B004WTE7WC'],
#              10.02: ['B0020VFM3C', 'B003RRX55K'],
#              25.19: ['B008JZV89U', 'B005Q66ENA'],
#              34.79: ['B000BPOOWO', 'B005VPZGGM'],
#              11.28: ['B000KJRRE8', 'B0065PVGC0'],
#              9.49: ['B0038N30OY', 'B00167YPC0'],
#              12.33: ['B0018QN64M'],
#              15.8: ['B003IYBD42', 'B002OEUINE'],
#              73.01: ['B000NPOMI8'],
#              9.43: ['B00011XIQQ', 'B003M6ANY2'],
#              12.47: ['B0007CXQQ6', 'B003DA5MPM', 'B000F5K3NY', 'B000A64AUU'],
#              106.37: ['B003RWTNB0'],
#              69.58: ['B003CFA154'],
#              36.12: ['B0083IYA98'],
#              67.3: ['B000G0JCX0'],
#              83.99: ['B002FYTRCQ', 'B003TV4PJY', 'B007N1355G', 'B008TZ2W5O'],
#              27.97: ['B001I0515K', 'B004AYEJM2'],
#              45.18: ['B005M03ER4'],
#              21.25: ['B003BRQ3LO', 'B001F51A4O'],
#              7.95: ['B003DMG4UW',
#               'B003KQIQRK',
#               'B000ROJQJ0',
#               'B00958N4GU',
#               'B007PSZ5PU',
#               'B008HQBE72',
#               'B00BOX7LXG',
#               'B000A82I8E'],
#              159.95: ['B006W1FUKG', 'B009L2062U', 'B0098QM4V0'],
#              126.25: ['B008UQKQ3C'],
#              35.3: ['B001EUI2RI', 'B0045SKUS0'],
#              75.79: ['B003IHU9Q2'],
#              5.97: ['B004P49HV0', 'B0000V09DC', 'B000095ZGC', 'B000LNRMH0'],
#              161.09: ['B003ZV87ZQ'],
#              64.36: ['B000TFKMJA'],
#              169.97: ['B000NBBMUI'],
#              6.35: ['B0076KNZG8'],
#              6.71: ['B000HMCE5U'],
#              114.99: ['B00H5ASZKU'],
#              10.3: ['B0001BFJ54', 'B0000CFQBR'],
#              6.62: ['B001BBRP64'],
#              5.04: ['B0000ZU2XU'],
#              16.96: ['B00006NWBG'],
#              4.45: ['B0001YJIGW'],
#              181.13: ['B0034JXL7S'],
#              61.14: ['B000L9Y8X0'],
#              93.49: ['B00575TFJA'],
#              112.32: ['B003FGWY0A'],
#              22.26: ['B009KB7Z5I'],
#              19.23: ['B0017000E8'],
#              141.99: ['B000NPQFLA'],
#              12.5: ['B0013FI0HG',
#               'B0054PSXBY',
#               'B001V9RA7U',
#               'B000IF8NRO',
#               'B008CMYBTY'],
#              99.95: ['B00A7BXFVI',
#               'B005AICIES',
#               'B002WN1QCO',
#               'B001CI6TTA',
#               'B002HWRFYI'],
#              26.49: ['B000VVXT5Q', 'B003TLOEQ8', 'B004Z83PZ0'],
#              114.75: ['B0009SV3I6'],
#              143.73: ['B002POGAEY'],
#              23.05: ['B004GXAII6'],
#              210.5: ['B005FP3TDA'],
#              16.5: ['B002E3KYWA', 'B0076LZYUM', 'B000CQXYCS', 'B001MA6BFA'],
#              3.19: ['B002EVP5S0', 'B000WZHWQI'],
#              18.25: ['B001HSNCBS'],
#              4.72: ['B003TMJ7EQ'],
#              78.84: ['B001FDX4UO'],
#              6.44: ['B000K1A91O'],
#              14.17: ['B004YDGHDS'],
#              12.24: ['B000PI9030', 'B007FGLBGO', 'B005DQVCS0'],
#              130.0: ['B004UC9PV4'],
#              40.19: ['B00DU1QRLW'],
#              5.68: ['B000BOCE18', 'B003U4MLNC'],
#              9.94: ['B0000V09X2', 'B003FIMO26', 'B008TL4FD0', 'B006UJW4NQ'],
#              414.08: ['B001E972K2'],
#              11.29: ['B00DIYKSQQ'],
#              30.46: ['B000062UH4'],
#              155.0: ['B006L7LKBO'],
#              23.63: ['B000YPIHK6'],
#              2.39: ['B000V5RSPO', 'B000CPMQ0K'],
#              7.42: ['B0098U9TXM'],
#              7.03: ['B009P0VSNY'],
#              86.87: ['B001JJBGPY'],
#              19.49: ['B008HPP672', 'B003981NYW', 'B002GX2V1U'],
#              118.06: ['B002USUJV0'],
#              274.05: ['B001KW0B8S'],
#              13.02: ['B003H232A8'],
#              63.5: ['B008U4QE8A', 'B003IFXDYY'],
#              4.42: ['B0091A9T9S', 'B005VTSG6U'],
#              28.8: ['B004GXAJ4O'],
#              7.01: ['B000COQT0Y', 'B000PSFOD0'],
#              5.95: ['B009P0VSKW',
#               'B004IK836G',
#               'B001340KF2',
#               'B000K4RWCU',
#               'B001LRMZFY',
#               'B0049H9ZUQ',
#               'B00FGCSHP2',
#               'B002MPPYU2',
#               'B0000DASDN',
#               'B000FKLALS'],
#              22.98: ['B002BXLMDS', 'B004Z9LEMA'],
#              259.99: ['B004G5YXSK', 'B0054UFSOO'],
#              10.91: ['B000QRCP4G'],
#              11.04: ['B000F5IB60', 'B007X4UYX4'],
#              40.91: ['B002XH0KLM'],
#              101.99: ['B004M85X8U', 'B004HW88WO'],
#              20.33: ['B002GP7TWE'],
#              17.09: ['B002ES1SRU'],
#              17.0: ['B0009VCB4S',
#               'B00CZFGOBW',
#               'B000NOPL48',
#               'B004XZG2UA',
#               'B0025VKLB0',
#               'B0001ZTHSU',
#               'B00FPOOJL2',
#               'B003YYV2S8',
#               'B00GGBEQCU',
#               'B002NYMDVU',
#               'B0094EJMEI'],
#              19.19: ['B007148MYE'],
#              11.0: ['B004MNV3B6',
#               'B000URHJXY',
#               'B007B8RKYI',
#               'B000256NPY',
#               'B000KFZE7Y'],
#              261.06: ['B00110HB50'],
#              35.08: ['B003UCBHES'],
#              45.32: ['B006239NXY'],
#              64.99: ['B002JLWV96',
#               'B008OG7K4G',
#               'B004RHKHM8',
#               'B007B796KU',
#               'B000O1CNVE',
#               'B000TTV2QS',
#               'B008H0X1Q0',
#               'B00BGE2ANE',
#               'B00HUZ1M0A',
#               'B001P6DMLC'],
#              1.25: ['B000P7AWO2'],
#              25.27: ['B004BDP642'],
#              5.74: ['B000GLPPLW'],
#              47.49: ['B000GPZB6W'],
#              29.88: ['B00EAZ10FU'],
#              21.46: ['B0014X7ARI'],
#              50.97: ['B000TDMU6A'],
#              45.25: ['B000IHJF60'],
#              156.5: ['B004VLW38Q'],
#              30.84: ['B000MGD8X8'],
#              27.75: ['B00EYQ7WVG'],
#              18.15: ['B00213L3MI'],
#              190.21: ['B00284ASX0'],
#              11.69: ['B008TLHUN2', 'B001F51AF8', 'B001C1F70O', 'B006UR18W6'],
#              198.62: ['B00280A4LA'],
#              71.54: ['B0055OC9OQ'],
#              28.45: ['B005EWT5E6'],
#              76.5: ['B0094G34YA', 'B005CTKTJG'],
#              17.33: ['B007IV4F9G'],
#              2.99: ['B0042IUL9G', 'B00423QDIE', 'B000ASIX8I', 'B000NE69EY'],
#              13.67: ['B000KKMN00', 'B001PF7K52'],
#              14.5: ['B008H5SXFE', 'B004GU9AE2'],
#              18.9: ['B004BM5NOQ', 'B0000TRTK0'],
#              8.02: ['B000X3H6AQ'],
#              14.18: ['B001V4VMRO'],
#              64.58: ['B001D4AJNA'],
#              179.94: ['B004SCEXX6'],
#              36.35: ['B00DHHFRYW'],
#              66.05: ['B0002I5QCC'],
#              77.95: ['B000TDMU8S'],
#              6.5: ['B005W9V5VM', 'B0036OQU1U', 'B0019HJMMK'],
#              6.0: ['B005HT0OKA',
#               'B003P70QAY',
#               'B0000TQGUE',
#               'B002TLSO1U',
#               'B002BDUCIY',
#               'B003DL437E',
#               'B002C01OIS'],
#              75.99: ['B001CUI65S', 'B00FY8N0G4', 'B000NPQHGS'],
#              58.49: ['B00EYN1NEG'],
#              13.3: ['B003WWUCOC'],
#              112.49: ['B000NNOG04'],
#              13.85: ['B000H5OWIO'],
#              38.95: ['B0009Y6G8C', 'B0051T8Y1W'],
#              244.47: ['B000OSIZ28'],
#              109.0: ['B003ICY3NW', 'B001KNLSUW', 'B00946R06I'],
#              465.0: ['B004FOMJA6'],
#              73.0: ['B00BLZEALS', 'B003FGRUNQ'],
#              31.0: ['B003G2ZKRC'],
#              8.36: ['B002KDERGS', 'B002PL5KG6'],
#              49.95: ['B004BACOYU',
#               'B000630P5G',
#               'B003IP32MW',
#               'B00269N5AA',
#               'B00CWQJSQW',
#               'B00005CDPH',
#               'B006X7Z1H6'],
#              38.9: ['B003VP5Y4I'],
#              19.86: ['B0027IS7UI'],
#              13.0: ['B00824AY5M',
#               'B0007U5GCA',
#               'B00166H9KG',
#               'B000V7251O',
#               'B003WE9854'],
#              35.37: ['B006MKF5WA'],
#              8.11: ['B000WEKLP8', 'B004BIWG7C'],
#              101.67: ['B003IB7592'],
#              176.13: ['B000NPTUPI'],
#              39.97: ['B00EJOYNAQ'],
#              9.89: ['B00132SPNI', 'B003UHYTZ2'],
#              237.02: ['B002CV6VSA'],
#              17.97: ['B005W2BXK2'],
#              41.97: ['B008J135CC', 'B0043CS1F2'],
#              119.45: ['B00C57AIGM'],
#              11.8: ['B0022TY080'],
#              7.84: ['B000VHFADY'],
#              21.89: ['B000ANHPJG', 'B0002HDVKM', 'B004FLK0H8'],
#              38.0: ['B009CKINXA', 'B005OLK55A'],
#              10.88: ['B003BQYQ96', 'B006CPEO6I'],
#              21.87: ['B007NIFUSY'],
#              52.9: ['B003H4QJAQ'],
#              20.79: ['B008TLJIG4'],
#              13.58: ['B004I749US'],
#              11.59: ['B003M19TN8', 'B001F51AHG'],
#              7.38: ['B00004XSF7', 'B0000CFNXV'],
#              9.01: ['B005POLEEC'],
#              7.79: ['B008TLFFX4', 'B000JLKNZC'],
#              599.0: ['B000WZTVRG'],
#              104.12: ['B0018SJQFS'],
#              157.86: ['B00B0NYGOC'],
#              23.31: ['B003H2GMIW'],
#              17.4: ['B001AFOP9G'],
#              31.99: ['B003ZYDAQ4',
#               'B00GHSR52K',
#               'B000B7BWGS',
#               'B003EQ3SYM',
#               'B000Q9X9TY',
#               'B0070O5UCW',
#               'B0070O5UNG',
#               'B001FXVJ1U',
#               'B002XISHF2',
#               'B008BOI676'],
#              25.82: ['B001JYMAA4'],
#              9.77: ['B000HMCEE6'],
#              9.42: ['B001HOIR44'],
#              295.64: ['B00EJQQLNQ'],
#              16.75: ['B00BD97PWI', 'B0017020K0'],
#              7.81: ['B000H8WOUY'],
#              168.34: ['B0009PQ79E'],
#              16.95: ['B009AMM5XO',
#               'B009AMM5X4',
#               'B002BWX23C',
#               'B0002Z12D2',
#               'B009AMUY5U',
#               'B006Q64KTE'],
#              13.73: ['B008CMYGWQ'],
#              169.95: ['B00008ZPN6', 'B000B76MEA'],
#              44.0: ['B00EFBCZZ8',
#               'B009MBU198',
#               'B005D0O684',
#               'B0089ME1K6',
#               'B0019WAD3W',
#               'B0002L8R70'],
#              20.71: ['B00472O4XG'],
#              197.1: ['B001KYMN1E'],
#              50.95: ['B0035L90FW'],
#              19.88: ['B0042SVXVQ', 'B004L9M1GM', 'B008NN75CW', 'B0030H37LY'],
#              114.6: ['B001CYD0JG'],
#              108.26: ['B002H0C16C'],
#              8.98: ['B005J9FNTK', 'B004368NG0'],
#              9.26: ['B005572EBQ'],
#              23.49: ['B0027I3FFA', 'B001D4F7NM', 'B005UFSL2E'],
#              2.0: ['B000GG1JLC', 'B008SW8VC6'],
#              48.99: ['B003U22XX2',
#               'B00008XL3A',
#               'B003H4QJBK',
#               'B005TOY6LQ',
#               'B001KQ9MNO',
#               'B004WT6ZFO',
#               'B008DZMYXU'],
#              5.55: ['B008TLKQ74', 'B00GUTQVJ4'],
#              43.25: ['B001BR48LI'],
#              8.52: ['B001ANXOFY'],
#              8.74: ['B002HRLL2U', 'B0055E2G8A', 'B003VRTWQM'],
#              6.94: ['B009ZGHNX2'],
#              16.82: ['B007GB3WGK'],
#              168.27: ['B001U8863O'],
#              19.0: ['B005AXQUN8',
#               'B00H3SS3V0',
#               'B003FMVOA0',
#               'B0038YY0XS',
#               'B008NN75EK',
#               'B0002EXY7K',
#               'B00006NWBE',
#               'B0061Q75EG',
#               'B005POFQBY',
#               'B003FMVOAU'],
#              3.55: ['B004BL9NGQ'],
#              399.99: ['B000UUBCNO'],
#              12.22: ['B002EIVMB2'],
#              30.49: ['B007YS4YC6', 'B000TSSY1U'],
#              28.2: ['B000GBK2WO'],
#              25.76: ['B006H1R450'],
#              179.95: ['B0037UPER4', 'B002R1MOOA', 'B0007P812C'],
#              76.0: ['B0002KNPWS', 'B0094G36TI'],
#              12.14: ['B004NJW59S', 'B000MSAHWG'],
#              25.45: ['B00167S1JI'],
#              16.44: ['B004T18NKU'],
#              27.68: ['B0030JSNNO'],
#              14.58: ['B0000TQGTA'],
#              14.49: ['B003OBY5JO',
#               'B002ZNJHZE',
#               'B000AKRTWM',
#               'B002OJFWBC',
#               'B00029QOW2'],
#              24.9: ['B00CD8GKAQ'],
#              10.31: ['B0002YVLDE', 'B001DTE5Q2'],
#              29.41: ['B000K9GAXM', 'B006322LD8'],
#              5.0: ['B001AO1VBW',
#               'B000FKHM1A',
#               'B006WC8994',
#               'B007B8RKJS',
#               'B005KJWPY0',
#               'B00029R8TK',
#               'B00E9CMQ9I',
#               'B00B8RZEYG'],
#              101.98: ['B0014Z5UMI'],
#              4.05: ['B00B2734LW'],
#              23.04: ['B0093OGTTK', 'B0037QGRPG'],
#              8.83: ['B008SOZZSM', 'B00EDN73Q4'],
#              109.99: ['B003GEN914',
#               'B003IHU9RG',
#               'B00CA5FFX0',
#               'B002YD8E5O',
#               'B000BI227A',
#               'B004CKC1R4'],
#              2.64: ['B0007WT9BC'],
#              32.21: ['B0088A7OCQ'],
#              153.17: ['B002PY7PSO'],
#              128.41: ['B001EQOM62'],
#              44.88: ['B00200KD6O'],
#              87.99: ['B001G0NNM0', 'B0010L3YN8'],
#              75.61: ['B002O2S9UU'],
#              79.11: ['B0087O6H1W'],
#              23.66: ['B0037LWSEK'],
#              40.87: ['B0073NIBW6'],
#              22.75: ['B00FN50NOA'],
#              9.85: ['B000QOP2U8'],
#              163.95: ['B002SSUKUC', 'B002TMX2YI'],
#              119.95: ['B0030GR4BY', 'B004FGNTYE'],
#              20.89: ['B000222DV0'],
#              14.32: ['B0001ZJMPI'],
#              136.47: ['B005TPILFC'],
#              122.35: ['B00CODGI0C'],
#              33.0: ['B000XMJ1X2', 'B00JQPPM1C', 'B000W6G61O', 'B002WGJHB8'],
#              5.52: ['B003G0IWD8'],
#              81.99: ['B007ACQOWY'],
#              84.95: ['B0094G35XA',
#               'B00CJUPCS4',
#               'B000ALB27O',
#               'B0049S0CFC',
#               'B0007LJO68'],
#              178.95: ['B0088AHJ76'],
#              61.8: ['B006LXOJC0'],
#              170.38: ['B001MS719M'],
#              153.9: ['B005ET9RWE'],
#              16.53: ['B000MULAES', 'B0010XP51U'],
#              31.76: ['B000ZA5VMM'],
#              14.68: ['B001NPDFFI'],
#              ...})

# %%
sales_list = list( reverse_price_asin.keys() )
sales_list.sort( reverse=True )
top10 = sales_list[:10]
last10 = sales_list[-10 : ]
top10
# Out:
# [924.99, 913.0, 899.0, 849.0, 839.0, 799.99, 799.97, 767.95, 699.0, 680.0]

# %%
top10data = {}
for entry in top10 :
    asins = reverse_price_asin[entry]
    for asin in asins :
        reviews = review_description_data[ asin ]['reviewBow']
        description = review_description_data[ asin ]['descriptionBow']
        top10data[ asin ] = {'price' : entry, 'reviewBow' : reviews, 'descriptionBow' : description}

# %%
last10data = {}
for entry in last10 :
    asins = reverse_price_asin[entry]
    for asin in asins :
        reviews = review_description_data[ asin ]['reviewBow']
        description = review_description_data[ asin ]['descriptionBow']
        last10data[ asin ] = {'price' : entry, 'reviewBow' : reviews, 'descriptionBow' : description}

# %%
def preprocess_level1(  data ) :
    reviewDoc = []; descDoc = []
    for asin in data :
        reviewStr = " ".join( data[asin]['reviewBow'] )
        descStr = " ".join( data[asin]['descriptionBow'] )
        reviewDoc.append( reviewStr )
        descDoc.append( descStr )
    return reviewDoc, descDoc

# %%
reviewDoc, descDoc = preprocess_level1( top10data )
reviewDoc[:3]
# Out:
# ['debated long time steelcase aeron end bought one quite satisfied nt lot fussy controls like steelcase automatically conforms current position body moves around preferable kicker arm broke couple years humanscale sent new arm free sent two new arms since new ones better old ones let see herman miller',
#  'model herman miller aeron chair work began telecommuting time knew upgrade home office chair ca nt think type adjustment want ca nt chair adjust height simple lever pull well arm height angle lumbar support far back forward seat back recline oh yes also adjust much pressure need put seat back reclinethe seat back open weave making cool comfortable chairi guess best measure good chair fact expensive sitting one work six years knew product worth costthe product came almost fully assembled got lumbar support option rather posturefit adjustment option lumbar support screw four screws probably took ten minutes assemble including opening package',
#  'better looks although may feel little harder beginning ones piling pillows old chairs really comfortable bad effects lower back regardless sitting many hoursmake sure get back supportan excellent chair sitting part get flat time happens usually chairs stars expensive half price would competition categorythen instead changing chair every months better buy one built last give exact support timeinstallation easy']

# %%
def preprocess_level2( documents, no_features = 10) :
    # LDA can only use raw term counts for LDA because it is a probabilistic graphical model
    tf_vectorizer = CountVectorizer(input='content', max_df=1.0, min_df=0.0,max_features=no_features, stop_words='english')
    tf = tf_vectorizer.fit_transform(documents)
    return tf, tf_vectorizer

# %%
tf, tf_vectorizer = preprocess_level2( reviewDoc )
tf
# Out:
# <10x10 sparse matrix of type '<class 'numpy.int64'>'
# 	with 31 stored elements in Compressed Sparse Row format>

# %%
no_topics = 5
# Run LDA
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=5,
                                learning_method='online', learning_offset=50.,random_state=0)

lda.fit(tf)
tf_feature_names = tf_vectorizer.get_feature_names()
tf_feature_names
# Out:
# ['bed',
#  'chair',
#  'firm',
#  'good',
#  'mattress',
#  'new',
#  'nt',
#  'product',
#  'support',
#  'time']

# %%
import wordcloud
import math
import matplotlib.pyplot as plt
for i in range ( no_topics ):
    termsInTopic = lda.components_[i].argsort()#[:-50-1:-1]
    termsAndCounts = []
    for term in termsInTopic:
        termsAndCounts.append((str(tf_feature_names[term].strip()),math.ceil(lda.components_[i][term]*1000)))

    
    termsAndCountsDict = {}
    for product,count in termsAndCounts :
        termsAndCountsDict[ product ] = count
    cloud = wordcloud.WordCloud(background_color="white")
    cloud.generate_from_frequencies(termsAndCountsDict)
    plt.imshow(cloud)
    plt.axis("off")
    plt.savefig(str(i))
    plt.show()

# %%
reviewDoc, descDoc = preprocess_level1( last10data )
reviewDoc[:3]
# Out:
# ['several vinturi well brands aerators one favorite pour wine job find perfect attach easily bottles unlike brands hold use stand put straw bottle make almost noise unlike brands slurp burble loudly enough disrupt shows conversations spout makes drip splash free even rushed pouring quickly bunch people finally really precise much pour pour slowed exacting amount really handy pouring tastingsi probably buy even ready give away old aeratorsoh doubt handy piece job good decanter think poured beforeafter afterbefore comparisons many wines distinct difference easy noticethe thing could possibly improve would built air tight stopper attachment',
#  'got shoe sin fit organized perfectly tried zipping bag put bed mistake zipper broke moved inch bag overstuffed flip flops smaller shoes inside tons extra room th etop broken easily tried using zipper provided inches zipper tore side plastic zipper broke side well promise pull hard thing cheap pain return ept shoved bed plastic draped top keeping inside ok zip depending storing may need better one actually zips doesnt break two seconds would buy ever',
#  'using cleaner years hard find stores fabric stores probably carry regular shopping place cleans iron quickly easily']

# %%
tf, tf_vectorizer = preprocess_level2( reviewDoc )
tf
# Out:
# <14x10 sparse matrix of type '<class 'numpy.int64'>'
# 	with 34 stored elements in Compressed Sparse Row format>

# %%
# Run LDA
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=5,
                                learning_method='online', learning_offset=50.,random_state=0)

lda.fit(tf)
tf_feature_names = tf_vectorizer.get_feature_names()
tf_feature_names
# Out:
# ['buy',
#  'cut',
#  'easy',
#  'filter',
#  'fridge',
#  'nt',
#  'plastic',
#  'price',
#  'size',
#  'use']

# %%
for i in range ( no_topics ):
    termsInTopic = lda.components_[i].argsort()#[:-50-1:-1]
    termsAndCounts = []
    for term in termsInTopic:
        termsAndCounts.append((str(tf_feature_names[term].strip()),math.ceil(lda.components_[i][term]*1000)))

    
    termsAndCountsDict = {}
    for product,count in termsAndCounts :
        termsAndCountsDict[ product ] = count
    cloud = wordcloud.WordCloud(background_color="white")
    cloud.generate_from_frequencies(termsAndCountsDict)
    plt.imshow(cloud)
    plt.axis("off")
    plt.savefig(str(i))
    plt.show()

# %%
json_data_all = open('./out/385sampleDict.json').read()
all_sales_data = json.loads(json_data_all)
all_sales_data [ list(all_sales_data.keys())[0] ]
# Out:
# {'descriptionPoliteness': 0.7670823547276673,
#  'descriptionSentimentCom': 0.0,
#  'descriptionSentimentNeg': 0.0,
#  'descriptionSentimentNeu': 1.0,
#  'descriptionSentimentPos': 0.0,
#  'empath_description_achievement': 0.0,
#  'empath_description_affection': 0.0,
#  'empath_description_aggression': 0.0,
#  'empath_description_air_travel': 0.0,
#  'empath_description_alcohol': 0.0,
#  'empath_description_ancient': 0.0,
#  'empath_description_anger': 0.0,
#  'empath_description_animal': 0.0,
#  'empath_description_anonymity': 0.0,
#  'empath_description_anticipation': 0.0,
#  'empath_description_appearance': 0.0,
#  'empath_description_art': 0.038461538461538464,
#  'empath_description_attractive': 0.0,
#  'empath_description_banking': 0.0,
#  'empath_description_beach': 0.0,
#  'empath_description_beauty': 0.0,
#  'empath_description_blue_collar_job': 0.0,
#  'empath_description_body': 0.038461538461538464,
#  'empath_description_breaking': 0.0,
#  'empath_description_business': 0.038461538461538464,
#  'empath_description_car': 0.0,
#  'empath_description_celebration': 0.038461538461538464,
#  'empath_description_cheerfulness': 0.0,
#  'empath_description_childish': 0.0,
#  'empath_description_children': 0.0,
#  'empath_description_cleaning': 0.0,
#  'empath_description_clothing': 0.0,
#  'empath_description_cold': 0.038461538461538464,
#  'empath_description_college': 0.0,
#  'empath_description_communication': 0.07692307692307693,
#  'empath_description_competing': 0.0,
#  'empath_description_computer': 0.0,
#  'empath_description_confusion': 0.0,
#  'empath_description_contentment': 0.0,
#  'empath_description_cooking': 0.0,
#  'empath_description_crime': 0.0,
#  'empath_description_dance': 0.0,
#  'empath_description_death': 0.038461538461538464,
#  'empath_description_deception': 0.0,
#  'empath_description_disappointment': 0.0,
#  'empath_description_disgust': 0.0,
#  'empath_description_dispute': 0.0,
#  'empath_description_divine': 0.0,
#  'empath_description_domestic_work': 0.07692307692307693,
#  'empath_description_dominant_heirarchical': 0.0,
#  'empath_description_dominant_personality': 0.0,
#  'empath_description_driving': 0.0,
#  'empath_description_eating': 0.0,
#  'empath_description_economics': 0.0,
#  'empath_description_emotional': 0.0,
#  'empath_description_envy': 0.0,
#  'empath_description_exasperation': 0.0,
#  'empath_description_exercise': 0.0,
#  'empath_description_exotic': 0.0,
#  'empath_description_fabric': 0.0,
#  'empath_description_family': 0.038461538461538464,
#  'empath_description_farming': 0.038461538461538464,
#  'empath_description_fashion': 0.0,
#  'empath_description_fear': 0.0,
#  'empath_description_feminine': 0.0,
#  'empath_description_fight': 0.0,
#  'empath_description_fire': 0.0,
#  'empath_description_friends': 0.0,
#  'empath_description_fun': 0.0,
#  'empath_description_furniture': 0.0,
#  'empath_description_gain': 0.0,
#  'empath_description_giving': 0.0,
#  'empath_description_government': 0.0,
#  'empath_description_hate': 0.0,
#  'empath_description_healing': 0.0,
#  'empath_description_health': 0.0,
#  'empath_description_hearing': 0.0,
#  'empath_description_help': 0.0,
#  'empath_description_heroic': 0.0,
#  'empath_description_hiking': 0.0,
#  'empath_description_hipster': 0.038461538461538464,
#  'empath_description_home': 0.038461538461538464,
#  'empath_description_horror': 0.0,
#  'empath_description_hygiene': 0.0,
#  'empath_description_independence': 0.0,
#  'empath_description_injury': 0.0,
#  'empath_description_internet': 0.0,
#  'empath_description_irritability': 0.0,
#  'empath_description_journalism': 0.0,
#  'empath_description_joy': 0.0,
#  'empath_description_kill': 0.0,
#  'empath_description_law': 0.0,
#  'empath_description_leader': 0.0,
#  'empath_description_legend': 0.0,
#  'empath_description_leisure': 0.0,
#  'empath_description_liquid': 0.0,
#  'empath_description_listen': 0.0,
#  'empath_description_love': 0.0,
#  'empath_description_lust': 0.0,
#  'empath_description_magic': 0.0,
#  'empath_description_masculine': 0.0,
#  'empath_description_medical_emergency': 0.0,
#  'empath_description_medieval': 0.0,
#  'empath_description_meeting': 0.0,
#  'empath_description_messaging': 0.07692307692307693,
#  'empath_description_military': 0.0,
#  'empath_description_money': 0.0,
#  'empath_description_monster': 0.0,
#  'empath_description_morning': 0.0,
#  'empath_description_movement': 0.0,
#  'empath_description_music': 0.0,
#  'empath_description_musical': 0.0,
#  'empath_description_negative_emotion': 0.0,
#  'empath_description_neglect': 0.0,
#  'empath_description_negotiate': 0.0,
#  'empath_description_nervousness': 0.0,
#  'empath_description_night': 0.0,
#  'empath_description_noise': 0.0,
#  'empath_description_occupation': 0.0,
#  'empath_description_ocean': 0.0,
#  'empath_description_office': 0.038461538461538464,
#  'empath_description_optimism': 0.0,
#  'empath_description_order': 0.0,
#  'empath_description_pain': 0.0,
#  'empath_description_party': 0.0,
#  'empath_description_payment': 0.0,
#  'empath_description_pet': 0.0,
#  'empath_description_philosophy': 0.0,
#  'empath_description_phone': 0.0,
#  'empath_description_plant': 0.0,
#  'empath_description_play': 0.0,
#  'empath_description_politeness': 0.0,
#  'empath_description_politics': 0.0,
#  'empath_description_poor': 0.0,
#  'empath_description_positive_emotion': 0.038461538461538464,
#  'empath_description_power': 0.0,
#  'empath_description_pride': 0.0,
#  'empath_description_prison': 0.0,
#  'empath_description_programming': 0.0,
#  'empath_description_rage': 0.0,
#  'empath_description_reading': 0.0,
#  'empath_description_real_estate': 0.0,
#  'empath_description_religion': 0.0,
#  'empath_description_restaurant': 0.0,
#  'empath_description_ridicule': 0.0,
#  'empath_description_royalty': 0.0,
#  'empath_description_rural': 0.0,
#  'empath_description_sadness': 0.0,
#  'empath_description_sailing': 0.0,
#  'empath_description_school': 0.0,
#  'empath_description_science': 0.0,
#  'empath_description_sexual': 0.0,
#  'empath_description_shame': 0.0,
#  'empath_description_shape_and_size': 0.0,
#  'empath_description_ship': 0.0,
#  'empath_description_shopping': 0.0,
#  'empath_description_sleep': 0.0,
#  'empath_description_smell': 0.0,
#  'empath_description_social_media': 0.0,
#  'empath_description_sound': 0.0,
#  'empath_description_speaking': 0.0,
#  'empath_description_sports': 0.0,
#  'empath_description_stealing': 0.0,
#  'empath_description_strength': 0.038461538461538464,
#  'empath_description_suffering': 0.0,
#  'empath_description_superhero': 0.0,
#  'empath_description_surprise': 0.0,
#  'empath_description_swearing_terms': 0.0,
#  'empath_description_swimming': 0.0,
#  'empath_description_sympathy': 0.0,
#  'empath_description_technology': 0.0,
#  'empath_description_terrorism': 0.0,
#  'empath_description_timidity': 0.0,
#  'empath_description_tool': 0.0,
#  'empath_description_torment': 0.0,
#  'empath_description_tourism': 0.038461538461538464,
#  'empath_description_toy': 0.0,
#  'empath_description_traveling': 0.0,
#  'empath_description_trust': 0.0,
#  'empath_description_ugliness': 0.0,
#  'empath_description_urban': 0.038461538461538464,
#  'empath_description_vacation': 0.038461538461538464,
#  'empath_description_valuable': 0.0,
#  'empath_description_vehicle': 0.0,
#  'empath_description_violence': 0.0,
#  'empath_description_war': 0.0,
#  'empath_description_warmth': 0.0,
#  'empath_description_water': 0.0,
#  'empath_description_weakness': 0.0,
#  'empath_description_wealthy': 0.0,
#  'empath_description_weapon': 0.0,
#  'empath_description_weather': 0.0,
#  'empath_description_wedding': 0.0,
#  'empath_description_white_collar_job': 0.0,
#  'empath_description_work': 0.0,
#  'empath_description_worship': 0.0,
#  'empath_description_writing': 0.038461538461538464,
#  'empath_description_youth': 0.0,
#  'empath_description_zest': 0.0,
#  'empath_review_achievement': 0.0,
#  'empath_review_affection': 0.0,
#  'empath_review_aggression': 0.0,
#  'empath_review_air_travel': 0.0,
#  'empath_review_alcohol': 0.0,
#  'empath_review_ancient': 0.0,
#  'empath_review_anger': 0.0,
#  'empath_review_animal': 0.0,
#  'empath_review_anonymity': 0.0,
#  'empath_review_anticipation': 0.0,
#  'empath_review_appearance': 0.0,
#  'empath_review_art': 0.0,
#  'empath_review_attractive': 0.0,
#  'empath_review_banking': 0.0,
#  'empath_review_beach': 0.0,
#  'empath_review_beauty': 0.0,
#  'empath_review_blue_collar_job': 0.0,
#  'empath_review_body': 0.0,
#  'empath_review_breaking': 0.0,
#  'empath_review_business': 0.04,
#  'empath_review_car': 0.04,
#  'empath_review_celebration': 0.0,
#  'empath_review_cheerfulness': 0.0,
#  'empath_review_childish': 0.0,
#  'empath_review_children': 0.0,
#  'empath_review_cleaning': 0.0,
#  'empath_review_clothing': 0.0,
#  'empath_review_cold': 0.0,
#  'empath_review_college': 0.0,
#  'empath_review_communication': 0.12,
#  'empath_review_competing': 0.0,
#  'empath_review_computer': 0.04,
#  'empath_review_confusion': 0.0,
#  'empath_review_contentment': 0.0,
#  'empath_review_cooking': 0.0,
#  'empath_review_crime': 0.0,
#  'empath_review_dance': 0.0,
#  'empath_review_death': 0.0,
#  'empath_review_deception': 0.0,
#  'empath_review_disappointment': 0.0,
#  'empath_review_disgust': 0.0,
#  'empath_review_dispute': 0.0,
#  'empath_review_divine': 0.0,
#  'empath_review_domestic_work': 0.0,
#  'empath_review_dominant_heirarchical': 0.0,
#  'empath_review_dominant_personality': 0.0,
#  'empath_review_driving': 0.04,
#  'empath_review_eating': 0.0,
#  'empath_review_economics': 0.0,
#  'empath_review_emotional': 0.0,
#  'empath_review_envy': 0.0,
#  'empath_review_exasperation': 0.0,
#  'empath_review_exercise': 0.0,
#  'empath_review_exotic': 0.0,
#  'empath_review_fabric': 0.0,
#  'empath_review_family': 0.0,
#  'empath_review_farming': 0.0,
#  'empath_review_fashion': 0.04,
#  'empath_review_fear': 0.0,
#  'empath_review_feminine': 0.0,
#  'empath_review_fight': 0.0,
#  'empath_review_fire': 0.0,
#  'empath_review_friends': 0.0,
#  'empath_review_fun': 0.0,
#  'empath_review_furniture': 0.08,
#  'empath_review_gain': 0.0,
#  'empath_review_giving': 0.0,
#  'empath_review_government': 0.0,
#  'empath_review_hate': 0.0,
#  'empath_review_healing': 0.0,
#  'empath_review_health': 0.0,
#  'empath_review_hearing': 0.0,
#  'empath_review_help': 0.0,
#  'empath_review_heroic': 0.0,
#  'empath_review_hiking': 0.0,
#  'empath_review_hipster': 0.0,
#  'empath_review_home': 0.0,
#  'empath_review_horror': 0.0,
#  'empath_review_hygiene': 0.0,
#  'empath_review_independence': 0.0,
#  'empath_review_injury': 0.0,
#  'empath_review_internet': 0.0,
#  'empath_review_irritability': 0.0,
#  'empath_review_journalism': 0.0,
#  'empath_review_joy': 0.0,
#  'empath_review_kill': 0.0,
#  'empath_review_law': 0.0,
#  'empath_review_leader': 0.0,
#  'empath_review_legend': 0.0,
#  'empath_review_leisure': 0.0,
#  'empath_review_liquid': 0.0,
#  'empath_review_listen': 0.0,
#  'empath_review_love': 0.0,
#  'empath_review_lust': 0.0,
#  'empath_review_magic': 0.0,
#  'empath_review_masculine': 0.0,
#  'empath_review_medical_emergency': 0.0,
#  'empath_review_medieval': 0.0,
#  'empath_review_meeting': 0.0,
#  'empath_review_messaging': 0.12,
#  'empath_review_military': 0.0,
#  'empath_review_money': 0.0,
#  'empath_review_monster': 0.0,
#  'empath_review_morning': 0.0,
#  'empath_review_movement': 0.08,
#  'empath_review_music': 0.0,
#  'empath_review_musical': 0.0,
#  'empath_review_negative_emotion': 0.04,
#  'empath_review_neglect': 0.0,
#  'empath_review_negotiate': 0.0,
#  'empath_review_nervousness': 0.0,
#  'empath_review_night': 0.0,
#  'empath_review_noise': 0.0,
#  'empath_review_occupation': 0.04,
#  'empath_review_ocean': 0.0,
#  'empath_review_office': 0.12,
#  'empath_review_optimism': 0.0,
#  'empath_review_order': 0.0,
#  'empath_review_pain': 0.0,
#  'empath_review_party': 0.0,
#  'empath_review_payment': 0.0,
#  'empath_review_pet': 0.0,
#  'empath_review_philosophy': 0.0,
#  'empath_review_phone': 0.0,
#  'empath_review_plant': 0.0,
#  'empath_review_play': 0.0,
#  'empath_review_politeness': 0.0,
#  'empath_review_politics': 0.0,
#  'empath_review_poor': 0.0,
#  'empath_review_positive_emotion': 0.0,
#  'empath_review_power': 0.0,
#  'empath_review_pride': 0.0,
#  'empath_review_prison': 0.0,
#  'empath_review_programming': 0.0,
#  'empath_review_rage': 0.0,
#  'empath_review_reading': 0.0,
#  'empath_review_real_estate': 0.0,
#  'empath_review_religion': 0.0,
#  'empath_review_restaurant': 0.0,
#  'empath_review_ridicule': 0.0,
#  'empath_review_royalty': 0.0,
#  'empath_review_rural': 0.0,
#  'empath_review_sadness': 0.0,
#  'empath_review_sailing': 0.0,
#  'empath_review_school': 0.0,
#  'empath_review_science': 0.0,
#  'empath_review_sexual': 0.0,
#  'empath_review_shame': 0.0,
#  'empath_review_shape_and_size': 0.0,
#  'empath_review_ship': 0.0,
#  'empath_review_shopping': 0.0,
#  'empath_review_sleep': 0.0,
#  'empath_review_smell': 0.0,
#  'empath_review_social_media': 0.0,
#  'empath_review_sound': 0.0,
#  'empath_review_speaking': 0.0,
#  'empath_review_sports': 0.0,
#  'empath_review_stealing': 0.0,
#  'empath_review_strength': 0.0,
#  'empath_review_suffering': 0.0,
#  'empath_review_superhero': 0.0,
#  'empath_review_surprise': 0.0,
#  'empath_review_swearing_terms': 0.0,
#  'empath_review_swimming': 0.0,
#  'empath_review_sympathy': 0.0,
#  'empath_review_technology': 0.0,
#  'empath_review_terrorism': 0.0,
#  'empath_review_timidity': 0.0,
#  'empath_review_tool': 0.0,
#  'empath_review_torment': 0.0,
#  'empath_review_tourism': 0.0,
#  'empath_review_toy': 0.0,
#  'empath_review_traveling': 0.04,
#  'empath_review_trust': 0.0,
#  'empath_review_ugliness': 0.0,
#  'empath_review_urban': 0.0,
#  'empath_review_vacation': 0.0,
#  'empath_review_valuable': 0.0,
#  'empath_review_vehicle': 0.0,
#  'empath_review_violence': 0.0,
#  'empath_review_war': 0.0,
#  'empath_review_warmth': 0.0,
#  'empath_review_water': 0.0,
#  'empath_review_weakness': 0.0,
#  'empath_review_wealthy': 0.0,
#  'empath_review_weapon': 0.0,
#  'empath_review_weather': 0.0,
#  'empath_review_wedding': 0.0,
#  'empath_review_white_collar_job': 0.0,
#  'empath_review_work': 0.08,
#  'empath_review_worship': 0.0,
#  'empath_review_writing': 0.0,
#  'empath_review_youth': 0.0,
#  'empath_review_zest': 0.0,
#  'readabilityIndexDescription': 73.88,
#  'readabilityIndexReview': 74.39,
#  'reviewPoliteness': 0.24632349805753964,
#  'reviewSentimentCom': -0.5719,
#  'reviewSentimentNeg': 0.17,
#  'reviewSentimentNeu': 0.83,
#  'reviewSentimentPos': 0.0,
#  'sales': 1290}

# %%
reverse_price_asin = reverse_asin_price_function( all_sales_data )

# %%
sales_list = list( reverse_price_asin.keys() )
sales_list.sort( reverse=True )
top10 = sales_list[:10]
last10 = sales_list[-10 : ]
last10
# Out:
# [28, 26, 21, 19, 14, 13, 11, 9, 7, 5]

# %%
top10data = {}
for entry in top10 :
    asins = reverse_price_asin[entry]
    for asin in asins :
        reviews = review_description_data[ asin ]['reviewBow']
        description = review_description_data[ asin ]['descriptionBow']
        top10data[ asin ] = {'price' : entry, 'reviewBow' : reviews, 'descriptionBow' : description}

# %%
last10data = {}
for entry in last10 :
    asins = reverse_price_asin[entry]
    for asin in asins :
        reviews = review_description_data[ asin ]['reviewBow']
        description = review_description_data[ asin ]['descriptionBow']
        last10data[ asin ] = {'price' : entry, 'reviewBow' : reviews, 'descriptionBow' : description}

# %%
reviewDoc, descDoc = preprocess_level1( top10data )
reviewDoc[:3]
# Out:
# ['thing works exactly described past years used recycled grocery bags instead trash bags holder perfect storing mounts anywhere stick attach two screws super easy stuff top easy get bag mine mounted door sink convenient',
#  'seems irons vaccum cleaner catergory never seem last perform consistently far good panasonic ergonomically fit performance excellent',
#  'made thin hollow tubbing seems aluminum really thin steel base sides thin plastic rigid men hold pairs unless stack']

# %%
tf, tf_vectorizer = preprocess_level2( reviewDoc )
tf
# Out:
# <10x10 sparse matrix of type '<class 'numpy.int64'>'
# 	with 19 stored elements in Compressed Sparse Row format>

# %%
no_topics = 5
# Run LDA
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=5,
                                learning_method='online', learning_offset=50.,random_state=0)

lda.fit(tf)
tf_feature_names = tf_vectorizer.get_feature_names()
tf_feature_names
# Out:
# ['brush',
#  'easy',
#  'holder',
#  'kitchen',
#  'like',
#  'love',
#  'nt',
#  'price',
#  'quickly',
#  'stick']

# %%
for i in range ( no_topics ):
    termsInTopic = lda.components_[i].argsort()#[:-50-1:-1]
    termsAndCounts = []
    for term in termsInTopic:
        termsAndCounts.append((str(tf_feature_names[term].strip()),math.ceil(lda.components_[i][term]*1000)))

    
    termsAndCountsDict = {}
    for product,count in termsAndCounts :
        termsAndCountsDict[ product ] = count
    cloud = wordcloud.WordCloud(background_color="white")
    cloud.generate_from_frequencies(termsAndCountsDict)
    plt.imshow(cloud)
    plt.axis("off")
    plt.savefig(str(i))
    plt.show()

# %%
reviewDoc, descDoc = preprocess_level1( last10data )
reviewDoc[:3]
# Out:
# ['like rack storing plates cups saucers etc cabinet takes little space real spacesaver',
#  'bit flimsy set mostly plastic stuff still falls probably ordered undersink sliding drawer nt going go trouble sending back give much space vanity sink',
#  'strong made well much stronger thought would holds year old ironing board heavy iron easy slid spectrum door iron ironing board holder standard sized interior door put small bungee cord around top ironing board wrapped around ironing board holder keeps ironing board trying come openi believe much room ironing board holder freed utility room']

# %%
tf, tf_vectorizer = preprocess_level2( reviewDoc )
tf
# Out:
# <12x10 sparse matrix of type '<class 'numpy.int64'>'
# 	with 27 stored elements in Compressed Sparse Row format>

# %%
# Run LDA
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=5,
                                learning_method='online', learning_offset=50.,random_state=0)

lda.fit(tf)
tf_feature_names = tf_vectorizer.get_feature_names()
tf_feature_names
# Out:
# ['board',
#  'cabinet',
#  'easy',
#  'heavy',
#  'holder',
#  'ironing',
#  'lids',
#  'nt',
#  'space',
#  'work']

# %%
for i in range ( no_topics ):
    termsInTopic = lda.components_[i].argsort()#[:-50-1:-1]
    termsAndCounts = []
    for term in termsInTopic:
        termsAndCounts.append((str(tf_feature_names[term].strip()),math.ceil(lda.components_[i][term]*1000)))

    
    termsAndCountsDict = {}
    for product,count in termsAndCounts :
        termsAndCountsDict[ product ] = count
    cloud = wordcloud.WordCloud(background_color="white")
    cloud.generate_from_frequencies(termsAndCountsDict)
    plt.imshow(cloud)
    plt.axis("off")
    plt.savefig(str(i))
    plt.show()
